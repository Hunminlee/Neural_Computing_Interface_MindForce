# %%
import config
import Transfer_Learning
import numpy as np

if __name__ == "__main__":
    baseline1_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_1data.csv'
    baseline2_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_10data.csv'
    baseline3_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_14data.csv'
    baseline4_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_18data.csv'
    baselines = [baseline1_csv_path, baseline2_csv_path,  baseline3_csv_path,  baseline4_csv_path]
    baseline_K = ['1', '10', '14', '18']

    tl_trainer = Transfer_Learning.TransferLearningTrainer(config, subject="Hunmin", increment_true_false="True")
    Init_acc_all, Prev_acc_all, Trained_acc_all = tl_trainer.run(plot_learning_curve=False)   #True if want to see convergence for each session round
    tl_trainer.plot_results(baselines, baseline_K)

    for idx, x in enumerate([Init_acc_all, Prev_acc_all, Trained_acc_all]):
        if idx==0:
            print(f"Average of acc without training this data (init; unseen) - incrementally trained model with previous datasets: {np.mean(x)*100:.2f}%")
        elif idx==1:
            print(f"Average of acc using previous test data after training (with increment): {np.mean(x)*100:.2f}%")
        elif idx==2:
            print(f"Average of acc using current test data after training (with increment): {np.mean(x)*100:.2f}%")
# Out:
# ===========================================
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 82.86%
# Maximum validation accuracy : 92.4%
#
# ===========================================
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 83.53%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 79.93%
# Maximum validation accuracy : 83.88%
# Accuracy Improvement: 0.35%
# 	 ===> Positive
#
# ===========================================
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 80.51%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 74.8%
# Maximum validation accuracy : 81.18%
# Accuracy Improvement: 0.68%
# 	 ===> Positive
#
# ===========================================
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 85.86%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 78.4%
# Maximum validation accuracy : 86.77%
# Accuracy Improvement: 0.91%
# 	 ===> Positive
#
# ===========================================
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.98%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 77.32%
# Maximum validation accuracy : 87.98%
# Accuracy Improvement: 0.00%
# 	 ===> Negative
#
# ===========================================
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 71.45%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 66.4%
# Maximum validation accuracy : 71.96%
# Accuracy Improvement: 0.51%
# 	 ===> Positive
#
# ===========================================
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 72.48%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 70.15%
# Maximum validation accuracy : 74.62%
# Accuracy Improvement: 2.14%
# 	 ===> Positive
#
# ===========================================
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 78.92%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 74.66%
# Maximum validation accuracy : 79.22%
# Accuracy Improvement: 0.30%
# 	 ===> Positive
#
# ===========================================
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 75.78%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 73.97%
# Maximum validation accuracy : 76.71%
# Accuracy Improvement: 0.93%
# 	 ===> Positive
#
# ===========================================
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 77.78%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 73.51%
# Maximum validation accuracy : 77.96%
# Accuracy Improvement: 0.19%
# 	 ===> Positive
#
# ===========================================
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 82.46%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 75.72%
# Maximum validation accuracy : 82.71%
# Accuracy Improvement: 0.26%
# 	 ===> Positive
#
# ===========================================
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 79.70%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 74.52%
# Maximum validation accuracy : 79.98%
# Accuracy Improvement: 0.28%
# 	 ===> Positive
#
# ===========================================
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 80.53%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 75.21%
# Maximum validation accuracy : 80.44%
# Accuracy Improvement: -0.09%
# 	 ===> Negative
#
# ===========================================
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 79.86%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 74.72%
# Maximum validation accuracy : 79.98%
# Accuracy Improvement: 0.12%
# 	 ===> Positive
#
# ===========================================
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.74%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 79.52%
# Maximum validation accuracy : 88.09%
# Accuracy Improvement: 0.35%
# 	 ===> Positive
#
# ===========================================
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 88.88%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 78.65%
# Maximum validation accuracy : 88.9%
# Accuracy Improvement: 0.02%
# 	 ===> Positive
#
# ===========================================
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 88.24%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.75%
# Maximum validation accuracy : 88.08%
# Accuracy Improvement: -0.16%
# 	 ===> Negative
#
# ===========================================
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 88.61%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.34%
# Maximum validation accuracy : 88.44%
# Accuracy Improvement: -0.17%
# 	 ===> Negative
#
# ===========================================
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.70%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.05%
# Maximum validation accuracy : 89.27%
# Accuracy Improvement: 2.57%
# 	 ===> Positive
#
# ===========================================
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 89.28%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.79%
# Maximum validation accuracy : 89.42%
# Accuracy Improvement: 0.14%
# 	 ===> Positive
#
# ===========================================
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 84.03%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.0%
# Maximum validation accuracy : 85.7%
# Accuracy Improvement: 1.67%
# 	 ===> Positive
#
# ===========================================
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 85.48%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.81%
# Maximum validation accuracy : 85.48%
# Accuracy Improvement: 0.00%
# 	 ===> Negative
#
# ===========================================
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.78%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.55%
# Maximum validation accuracy : 86.97%
# Accuracy Improvement: 0.19%
# 	 ===> Positive
#
# ===========================================
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 85.52%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.02%
# Maximum validation accuracy : 85.47%
# Accuracy Improvement: -0.05%
# 	 ===> Negative
#
# ===========================================
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ===========================================
# There is more than one dataset - check
#
# Initial Test Accuracy: 87.48%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 83.13%
# Maximum validation accuracy : 87.45%
# Accuracy Improvement: -0.02%
# 	 ===> Negative
#
# ===========================================
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.62%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.69%
# Maximum validation accuracy : 86.48%
# Accuracy Improvement: -0.14%
# 	 ===> Negative
#
# ===========================================
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 83.40%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 78.42%
# Maximum validation accuracy : 84.25%
# Accuracy Improvement: 0.85%
# 	 ===> Positive
#
# ===========================================
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.25%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.57%
# Maximum validation accuracy : 86.57%
# Accuracy Improvement: 0.33%
# 	 ===> Positive
#
# ===========================================
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.78%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 82.91%
# Maximum validation accuracy : 87.95%
# Accuracy Improvement: 0.17%
# 	 ===> Positive
#
# ===========================================
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.99%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 83.34%
# Maximum validation accuracy : 87.18%
# Accuracy Improvement: 0.19%
# 	 ===> Positive
# Average of acc without training this data (init; unseen) - incrementally trained model with previous datasets: 81.55%
# Average of acc using previous test data after training (with increment): 84.38%
# Average of acc using current test data after training (with increment): 82.12%

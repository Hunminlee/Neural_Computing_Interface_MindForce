# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import scipy

# %%
import os
import h5py
import numpy as np

path = 'D:/Dataset/The dataset/2020-10-12 Human Trial [21]/Data/'
f_lst = os.listdir(path)

for f in f_lst[:10]:
    file_path = os.path.join(path, f)
    print(f"\n--- {f} ---")

    with h5py.File(file_path, 'r') as mat:
        #print("Keys:", list(mat.keys()))

        def load_hdf5(obj):
            if isinstance(obj, h5py.Dataset):
                return obj[()]
            elif isinstance(obj, h5py.Group):
                out = {}
                for k, v in obj.items():
                    out[k] = load_hdf5(v)
                return out

        data = {k: load_hdf5(v) for k, v in mat.items()}

        plt.figure(figsize=(12, 4))
        plt.plot(data['Data_ADC0'].T[1000:])
        plt.show()

    #print("Loaded variables:", list(data.keys()))
# Out:
# --- Data_20201013_094716.mat ---
# --- Data_20201013_095350.mat ---
# --- Data_20201013_100054.mat ---
# --- Data_20201013_100258.mat ---
# --- Data_20201013_101653.mat ---
# --- Data_20201013_102104.mat ---
# --- Data_20201013_102314.mat ---
# --- Data_20201013_102512.mat ---
# --- Data_20201013_102906.mat ---
# --- Data_20201013_103318.mat ---

# %%
for i in list(data.keys()):
    try:
        print(f"{i}", data[i].shape)
    except:
        print(f"{i} is missing")
        pass
# Out:
# #refs# is missing
# DG_Calib (14, 2)
# DG_ClsList (5, 1)
# DG_Data (14, 10012)
# DG_DataAry (14, 10012)
# DG_DataPeriod (1, 10012)
# DG_Fs (1, 1)
# DG_MapDOF (14, 1)
# DG_Repeat (1, 1)
# DG_SegLength (1, 1)
# Data_ADC0 (16, 2005770)
# Data_Byte (2, 32088321)
# Data_Fea (10229, 224)
# Dev_DecRatio (1, 1)
# Dev_Fs (1, 1)
# Dev_G1 (1, 1)
# Dev_G2 (1, 1)
# Dev_Gain (1, 1)
# Dev_LSB (1, 1)
# Dev_Serial (4, 1)
# Fil_Fc (2, 1)
# MD_ClsProb (14, 1)
# MD_DataAry (14, 1)
# MD_FeaDim (3, 1)
# MD_FeaStep (1, 1)
# MD_FeaWin (1, 1)
# MD_Fs (1, 1)
# MD_Timestamp (1, 1)
# Notes (2,)
# Timer_Clock (6, 1)

# %%
for f in f_lst[10:-1]:
    file_path = os.path.join(path, f)
    print(f"\n--- {f} ---")

    with h5py.File(file_path, 'r') as mat:
        #print("Keys:", list(mat.keys()))

        def load_hdf5(obj):
            if isinstance(obj, h5py.Dataset):
                return obj[()]
            elif isinstance(obj, h5py.Group):
                out = {}
                for k, v in obj.items():
                    out[k] = load_hdf5(v)
                return out

        data = {k: load_hdf5(v) for k, v in mat.items()}

        plt.figure(figsize=(12, 4))
        plt.plot(data['Data_ADC0'].T[1000:])
        plt.show()

    #print("Loaded variables:", list(data.keys()))
# Out:
# --- Data_20201013_103544.mat ---
# --- Data_20201013_103735.mat ---
# --- Data_20201013_103935.mat ---
# --- Data_20201013_104352.mat ---
# --- Data_20201013_104548.mat ---
# --- Data_20201013_104738.mat ---
# --- Data_20201013_105106.mat ---
# --- Data_20201013_105526.mat ---
# --- Data_20201013_110117.mat ---
# --- Data_20201013_110311.mat ---
# --- Data_20201013_161150.mat ---
# --- Data_20201013_161611.mat ---
# --- Data_20201013_161839.mat ---
# --- Data_20201013_162057.mat ---
# --- Data_20201013_162506.mat ---
# --- Data_20201013_162647.mat ---
# --- Data_20201013_165709.mat ---
# --- Data_20201013_170102.mat ---
# --- Data_20201013_170316.mat ---
# --- Data_20201013_170530.mat ---
# --- Data_20201013_170923.mat ---
# --- Data_20201013_171107.mat ---
# --- Data_20201013_171320.mat ---
# --- Data_20201013_171706.mat ---
# --- Data_20201013_171847.mat ---
# --- Data_20201015_141844.mat ---
# --- Data_20201015_142452.mat ---
# --- Data_20201015_143153.mat ---
# --- Data_20201015_144416.mat ---
# --- Data_20201015_145655.mat ---
# --- Data_20201016_113151.mat ---
# --- Data_20201016_113448.mat ---

# %%
import config
import numpy as np

baseline1_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_1data.csv'
baseline2_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_10data.csv'
baseline3_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_14data.csv'
baseline4_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_18data.csv'
baseline5_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_22data.csv'

baseline_K = ['1', '10', '14', '18', '22']
baselines = [baseline1_csv_path, baseline2_csv_path,  baseline3_csv_path,  baseline4_csv_path, baseline5_csv_path]

# %% [markdown]
# # Baseline: Training datasets and store
# - Time 1 (1 day)
# - Time 10 (3 days)
# - Time 14 (4 days)
# - Time 18 (5 days)
# - Time 22 (6 days)

# %%
import Test_without_Training

if __name__ == "__main__":
    for K in [1, 10, 14, 18, 22]:
        trainer = Test_without_Training.TremorModelTrainer(config, subject="Hunmin")
        trainer.run_all_sessions_training_K_data(K)
        df = trainer.save_results(f'../Results/Baseline_results_train_with_{K}data.csv')
# Out:
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.45%
# Maximum validation accuracy : 94.19%
# Accuracy of test dataset using model V0: 94.1860%
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.2007%
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.4073%
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.1160%
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 67.4082%
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 74.8428%
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.4447%
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 73.2799%
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 71.9439%
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 73.7764%
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 70.3196%
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 73.1305%
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.3796%
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.1822%
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.4368%
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.9600%
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.6022%
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.6602%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.5532%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.2812%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.6238%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.0098%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.9328%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 87.3727%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.8083%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 78.6591%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.2804%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.7718%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.1629%
# Results saved to ../Results/Baseline_results_train_with_1data.csv
#
#
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,)
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,)
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,)
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,)
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,)
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,)
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,)
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,)
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,)
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 87.97%
# Maximum validation accuracy : 90.83%
# Accuracy of test dataset using model V0: 90.8343%
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.4818%
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.4260%
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.5217%
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.1911%
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4578%
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3296%
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.8245%
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.1596%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.4245%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8732%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.2954%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7132%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.7914%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 91.1690%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0763%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.7158%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.9145%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.1631%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9859%
# Results saved to ../Results/Baseline_results_train_with_10data.csv
#
#
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,)
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,)
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,)
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,)
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,)
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,)
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,)
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,)
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,)
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,)
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# (101296, 4, 14, 1) (101296,)
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# (109756, 4, 14, 1) (109756,)
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# (118143, 4, 14, 1) (118143,)
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.86%
# Maximum validation accuracy : 92.53%
# Accuracy of test dataset using model V0: 92.5336%
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.1425%
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.6439%
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3195%
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.9729%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0160%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.4195%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 95.0122%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2012%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6408%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 91.2500%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.9832%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.4240%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.8098%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.7470%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.0562%
# Results saved to ../Results/Baseline_results_train_with_14data.csv
#
#
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,)
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,)
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,)
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,)
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,)
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,)
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,)
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,)
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,)
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,)
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# (101296, 4, 14, 1) (101296,)
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# (109756, 4, 14, 1) (109756,)
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# (118143, 4, 14, 1) (118143,)
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# (126634, 4, 14, 1) (126634,)
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# (135110, 4, 14, 1) (135110,)
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# (143628, 4, 14, 1) (143628,)
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# (151851, 4, 14, 1) (151851,)
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 90.68%
# Maximum validation accuracy : 91.98%
# Accuracy of test dataset using model V0: 91.7808%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2883%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.6753%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 95.3486%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.2609%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4519%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 92.4537%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6114%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2351%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.9267%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 95.0071%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.1107%
# Results saved to ../Results/Baseline_results_train_with_18data.csv
#
#
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,)
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,)
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,)
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,)
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,)
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,)
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,)
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,)
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,)
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,)
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# (101296, 4, 14, 1) (101296,)
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# (109756, 4, 14, 1) (109756,)
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# (118143, 4, 14, 1) (118143,)
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# (126634, 4, 14, 1) (126634,)
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# (135110, 4, 14, 1) (135110,)
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# (143628, 4, 14, 1) (143628,)
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# (151851, 4, 14, 1) (151851,)
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# (160338, 4, 14, 1) (160338,)
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# (168819, 4, 14, 1) (168819,)
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# (177334, 4, 14, 1) (177334,)
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# (185869, 4, 14, 1) (185869,)
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 90.86%
# Maximum validation accuracy : 93.07%
# Accuracy of test dataset using model V0: 92.9142%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7416%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 92.8588%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.1931%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.3447%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.6713%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 95.0547%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.1224%
# Results saved to ../Results/Baseline_results_train_with_22data.csv

# %% [markdown]
# # Training from scratch in every data
# - Performance should be high
# - Objective

# %%
import Training_from_scratch

if __name__ == "__main__":
    prog_trainer = Training_from_scratch.ProgressiveTrainer(config, subject="Hunmin")
    Init_acc_all, Prev_acc_all, Trained_acc_all = prog_trainer.run(plot_learning_curve=False)
    prog_trainer.plot_results(baselines, baseline_K)

    for idx, x in enumerate([Init_acc_all, Prev_acc_all, Trained_acc_all]):
        if idx==0:
            print(f"Average of acc without training anything (should be random): {np.mean(x)*100:.2f}%")
        elif idx==1:
            print(f"Average of acc using previous test data after training: {np.mean(x)*100:.2f}%")
        elif idx==2:
            print(f"Average of acc using current test data after training: {np.mean(x)*100:.2f}%")
# Out:
# ===========================================
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.83%
# Maximum validation accuracy : 93.28%
#
# ===========================================
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.1%
# Maximum validation accuracy : 90.77%
#
# ===========================================
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.96%
# Maximum validation accuracy : 91.57%
#
# ===========================================
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.86%
# Maximum validation accuracy : 91.36%
#
# ===========================================
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.82%
# Maximum validation accuracy : 91.18%
#
# ===========================================
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.93%
# Maximum validation accuracy : 86.67%
#
# ===========================================
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.33%
# Maximum validation accuracy : 94.58%
#
# ===========================================
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.38%
# Maximum validation accuracy : 87.33%
#
# ===========================================
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.17%
# Maximum validation accuracy : 87.26%
#
# ===========================================
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.13%
# Maximum validation accuracy : 93.9%

# %% [markdown]
# # Transfer Learning - Incremental : Model is cumulatively updated

# %%
import Transfer_Learning

if __name__ == "__main__":
    tl_trainer = Transfer_Learning.TransferLearningTrainer(config, subject="Hunmin", increment_true_false="True")
    Init_acc_all, Prev_acc_all, Trained_acc_all = tl_trainer.run(plot_learning_curve=False)   #True if want to see convergence for each session round
    tl_trainer.plot_results(baselines, baseline_K)

    for idx, x in enumerate([Init_acc_all, Prev_acc_all, Trained_acc_all]):
        if idx==0:
            print(f"Average of acc without training this data (init; unseen) - incrementally trained model with previous datasets: {np.mean(x)*100:.2f}%")
        elif idx==1:
            print(f"Average of acc using previous test data after training (with increment): {np.mean(x)*100:.2f}%")
        elif idx==2:
            print(f"Average of acc using current test data after training (with increment): {np.mean(x)*100:.2f}%")

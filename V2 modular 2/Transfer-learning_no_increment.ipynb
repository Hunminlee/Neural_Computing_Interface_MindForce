# %%
import config
import Transfer_Learning
import numpy as np

if __name__ == "__main__":
    baseline1_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_1data.csv'
    baseline2_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_10data.csv'
    baseline3_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_14data.csv'
    baseline4_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_18data.csv'
    baselines = [baseline1_csv_path, baseline2_csv_path,  baseline3_csv_path,  baseline4_csv_path]
    baseline_K = ['1', '10', '14', '18']

    tl_trainer = Transfer_Learning.TransferLearningTrainer(config, subject="Hunmin", increment_true_false="False")
    Init_acc_all, Prev_acc_all, Trained_acc_all = tl_trainer.run(plot_learning_curve=False)   #True if want to see convergence for each session round
    tl_trainer.plot_results(baselines, baseline_K)

    for idx, x in enumerate([Init_acc_all, Prev_acc_all, Trained_acc_all]):
        if idx==0:
            print(f"Average of acc without training this data (init; unseen) - init model trained with very first data: {np.mean(x)*100:.2f}%")
        elif idx==1:
            print(f"Average of acc using previous test data after training (No increment): {np.mean(x)*100:.2f}%")
        elif idx==2:
            print(f"Average of acc using current test data after training (No increment): {np.mean(x)*100:.2f}%")
# Out:
# ===========================================
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 83.05%
# Maximum validation accuracy : 92.33%
#
# ===========================================
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.22%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.32%
# Maximum validation accuracy : 88.05%
# Accuracy Improvement: 1.83%
# 	 ===> Positive
#
# ===========================================
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 81.63%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 74.78%
# Maximum validation accuracy : 82.93%
# Accuracy Improvement: 1.30%
# 	 ===> Positive
#
# ===========================================
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.42%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 79.73%
# Maximum validation accuracy : 88.95%
# Accuracy Improvement: 1.53%
# 	 ===> Positive
#
# ===========================================
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.63%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 77.65%
# Maximum validation accuracy : 86.34%
# Accuracy Improvement: -0.29%
# 	 ===> Negative
#
# ===========================================
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 69.39%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 65.62%
# Maximum validation accuracy : 69.34%
# Accuracy Improvement: -0.05%
# 	 ===> Negative
#
# ===========================================
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 74.39%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 71.15%
# Maximum validation accuracy : 74.23%
# Accuracy Improvement: -0.16%
# 	 ===> Negative
#
# ===========================================
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 78.36%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 74.11%
# Maximum validation accuracy : 80.17%
# Accuracy Improvement: 1.81%
# 	 ===> Positive
#
# ===========================================
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 72.76%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 71.06%
# Maximum validation accuracy : 76.75%
# Accuracy Improvement: 4.00%
# 	 ===> Positive
#
# ===========================================
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 77.13%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 71.24%
# Maximum validation accuracy : 77.11%
# Accuracy Improvement: -0.02%
# 	 ===> Negative
#
# ===========================================
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 76.17%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 72.66%
# Maximum validation accuracy : 77.48%
# Accuracy Improvement: 1.31%
# 	 ===> Positive
#
# ===========================================
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 74.57%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 70.59%
# Maximum validation accuracy : 74.62%
# Accuracy Improvement: 0.05%
# 	 ===> Positive
#
# ===========================================
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 78.07%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 72.33%
# Maximum validation accuracy : 78.17%
# Accuracy Improvement: 0.09%
# 	 ===> Positive
#
# ===========================================
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 78.33%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 70.77%
# Maximum validation accuracy : 78.07%
# Accuracy Improvement: -0.26%
# 	 ===> Negative
#
# ===========================================
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.55%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 77.89%
# Maximum validation accuracy : 87.01%
# Accuracy Improvement: 0.47%
# 	 ===> Positive
#
# ===========================================
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.55%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 78.04%
# Maximum validation accuracy : 87.06%
# Accuracy Improvement: 0.51%
# 	 ===> Positive
#
# ===========================================
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 89.05%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.54%
# Maximum validation accuracy : 89.24%
# Accuracy Improvement: 0.19%
# 	 ===> Positive
#
# ===========================================
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 89.43%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.54%
# Maximum validation accuracy : 89.53%
# Accuracy Improvement: 0.10%
# 	 ===> Positive
#
# ===========================================
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 85.75%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 78.58%
# Maximum validation accuracy : 86.59%
# Accuracy Improvement: 0.84%
# 	 ===> Positive
#
# ===========================================
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.84%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 79.34%
# Maximum validation accuracy : 87.84%
# Accuracy Improvement: 0.00%
# 	 ===> Negative
#
# ===========================================
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 83.82%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 79.79%
# Maximum validation accuracy : 86.19%
# Accuracy Improvement: 2.37%
# 	 ===> Positive
#
# ===========================================
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.80%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.19%
# Maximum validation accuracy : 87.78%
# Accuracy Improvement: -0.02%
# 	 ===> Negative
#
# ===========================================
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.38%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.98%
# Maximum validation accuracy : 87.47%
# Accuracy Improvement: 0.10%
# 	 ===> Positive
#
# ===========================================
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 86.72%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 80.02%
# Maximum validation accuracy : 86.84%
# Accuracy Improvement: 0.12%
# 	 ===> Positive
#
# ===========================================
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ===========================================
# There is more than one dataset - check
#
# Initial Test Accuracy: 89.47%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 84.38%
# Maximum validation accuracy : 89.51%
# Accuracy Improvement: 0.05%
# 	 ===> Positive
#
# ===========================================
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 87.09%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 82.81%
# Maximum validation accuracy : 86.97%
# Accuracy Improvement: -0.12%
# 	 ===> Negative
#
# ===========================================
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 82.96%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 77.71%
# Maximum validation accuracy : 84.44%
# Accuracy Improvement: 1.49%
# 	 ===> Positive
#
# ===========================================
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 88.36%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 81.2%
# Maximum validation accuracy : 88.5%
# Accuracy Improvement: 0.14%
# 	 ===> Positive
#
# ===========================================
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 88.40%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 82.72%
# Maximum validation accuracy : 88.87%
# Accuracy Improvement: 0.48%
# 	 ===> Positive
#
# ===========================================
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ===========================================
#
# Initial Test Accuracy: 85.94%
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 83.53%
# Maximum validation accuracy : 86.34%
# Accuracy Improvement: 0.40%
# 	 ===> Positive
# Average of acc without training this data (init; unseen) - init model trained with very first data: 81.14%
# Average of acc using previous test data after training (No increment): 84.16%
# Average of acc using current test data after training (No increment): 82.56%

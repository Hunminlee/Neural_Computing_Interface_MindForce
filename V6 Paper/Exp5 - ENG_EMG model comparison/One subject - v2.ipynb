# %% [markdown]
# # "One Subject.ipynb" 파일과 차이점
#
# - 몇가지 실험을 돌려보니 원래 내가 manually feature 추출을 했었는데 보니깐 잘안되는 거였음
# - 여기는 matlab에 있는 Data['Fea'] 를 사용함 => 이게 주요 차이점

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import scipy, os
from sklearn.metrics import confusion_matrix
import seaborn as sns

import sys
sys.path.append('../../Share/')
sys.path.append('../../Share/Manual_processing/')
sys.path.append('../Exp6 - iENG vs sENG')
import baseline, config, Model, utils, Same_with_MATLAB, Feature_info, shared_iENG_sENG

import warnings
warnings.filterwarnings('ignore')

def run_experiment(subject):
    X_train_EMG, y_train_EMG = shared_iENG_sENG.X_y_from_matfile(path = base_path+f'{subject}/', balance=True, modality='EMG', session='v1')
    X_test_EMG, y_test_EMG = shared_iENG_sENG.X_y_from_matfile(path = base_path+f'{subject}/', balance=True, modality='EMG', session='v2')

    X_train_ENG, y_train_ENG = shared_iENG_sENG.X_y_from_matfile(path = base_path+f'{subject}/', balance=True, modality='ENG', session='v1')
    X_test_ENG, y_test_ENG = shared_iENG_sENG.X_y_from_matfile(path = base_path+f'{subject}/', balance=True, modality='ENG', session='v2')

    print(X_train_EMG.shape, y_train_EMG.shape, X_test_EMG.shape, y_test_EMG.shape)
    print(X_train_ENG.shape, y_train_ENG.shape, X_test_ENG.shape, y_test_ENG.shape)

    Heatmap_B = False
    history_EMG1 = shared_iENG_sENG.train_model(X_train_EMG, y_train_EMG, X_test_EMG, y_test_EMG, heatmap_bool=Heatmap_B, draw_learning_curve=False)
    history_EMG2 = shared_iENG_sENG.train_model(X_test_EMG, y_test_EMG, X_train_EMG, y_train_EMG, heatmap_bool=Heatmap_B, draw_learning_curve=False)

    history_ENG1 = shared_iENG_sENG.train_model(X_train_ENG, y_train_ENG, X_test_ENG, y_test_ENG, heatmap_bool=Heatmap_B, draw_learning_curve=False)
    history_ENG2 = shared_iENG_sENG.train_model(X_test_ENG, y_test_ENG, X_train_ENG, y_train_ENG, heatmap_bool=Heatmap_B, draw_learning_curve=False)

    return [history_EMG1, history_EMG2, history_ENG1, history_ENG2]

# %%
base_path = 'C:/Users/hml76/PycharmProjects/MindForce/data/EMG_ENG/'

HM = run_experiment(subject = "Hunmin")
# Out:
# (1806, 4, 14, 1) (1806,) (1896, 4, 14, 1) (1896,)
# (1584, 4, 14, 1) (1584,) (1356, 4, 14, 1) (1356,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 44.74%
# Maximum validation accuracy : 40.24%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 53.27%
# Maximum validation accuracy : 45.51%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 62.18%
# Maximum validation accuracy : 54.42%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 50.29%
# Maximum validation accuracy : 50.95%

# %%
BY = run_experiment(subject = "Byeongchan")
# Out:
# (2646, 4, 14, 1) (2646,) (2760, 4, 14, 1) (2760,)
# (2232, 4, 14, 1) (2232,) (2160, 4, 14, 1) (2160,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 61.9%
# Maximum validation accuracy : 35.94%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 49.35%
# Maximum validation accuracy : 30.27%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 73.75%
# Maximum validation accuracy : 59.68%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 64.81%
# Maximum validation accuracy : 61.34%

# %%
HJ = run_experiment(subject = "Hongjun")
# Out:
# (2274, 4, 14, 1) (2274,) (2034, 4, 14, 1) (2034,)
# (2088, 4, 14, 1) (2088,) (1812, 4, 14, 1) (1812,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 54.79%
# Maximum validation accuracy : 39.13%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 49.8%
# Maximum validation accuracy : 32.67%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 64.99%
# Maximum validation accuracy : 53.81%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 58.17%
# Maximum validation accuracy : 55.27%

# %%
JI = run_experiment(subject = "Jongin")
# Out:
# (2870, 4, 14, 1) (2870,) (3384, 4, 14, 1) (3384,)
# (3156, 4, 14, 1) (3156,) (3432, 4, 14, 1) (3432,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 71.18%
# Maximum validation accuracy : 59.37%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 64.75%
# Maximum validation accuracy : 62.75%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 82.22%
# Maximum validation accuracy : 75.06%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 79.69%
# Maximum validation accuracy : 76.81%

# %%
YC = run_experiment(subject = "Youngchul")
# Out:
# (2808, 4, 14, 1) (2808,) (2646, 4, 14, 1) (2646,)
# (2352, 4, 14, 1) (2352,) (2052, 4, 14, 1) (2052,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 61.43%
# Maximum validation accuracy : 46.86%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 53.85%
# Maximum validation accuracy : 53.53%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 58.33%
# Maximum validation accuracy : 45.37%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 43.32%
# Maximum validation accuracy : 45.75%

# %%
HR = run_experiment(subject = "Harold")
# Out:
# (2142, 4, 14, 1) (2142,) (2166, 4, 14, 1) (2166,)
# (2322, 4, 14, 1) (2322,) (2124, 4, 14, 1) (2124,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 66.43%
# Maximum validation accuracy : 58.49%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 67.64%
# Maximum validation accuracy : 61.62%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 58.05%
# Maximum validation accuracy : 57.63%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 73.16%
# Maximum validation accuracy : 45.95%

# %%
CS = run_experiment(subject = "Carlson")
# Out:
# (2988, 4, 14, 1) (2988,) (2994, 4, 14, 1) (2994,)
# (2670, 4, 14, 1) (2670,) (2940, 4, 14, 1) (2940,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 63.79%
# Maximum validation accuracy : 55.91%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 60.45%
# Maximum validation accuracy : 49.97%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 63.78%
# Maximum validation accuracy : 56.9%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 63.27%
# Maximum validation accuracy : 55.51%

# %%
MJ = run_experiment(subject = "Minjeong")
# Out:
# (2316, 4, 14, 1) (2316,) (2130, 4, 14, 1) (2130,)
# (2004, 4, 14, 1) (2004,) (1884, 4, 14, 1) (1884,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 51.21%
# Maximum validation accuracy : 48.78%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 57.51%
# Maximum validation accuracy : 57.3%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 56.69%
# Maximum validation accuracy : 55.15%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 60.83%
# Maximum validation accuracy : 57.14%

# %%
XY = run_experiment(subject = "Xianyu")
# Out:
# (2094, 4, 14, 1) (2094,) (2118, 4, 14, 1) (2118,)
# (2832, 4, 14, 1) (2832,) (1746, 4, 14, 1) (1746,)
# Start Training (total epochs: 100)...
# Maximum training accuracy : 60.98%
# Maximum validation accuracy : 69.83%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 67.52%
# Maximum validation accuracy : 59.26%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 55.9%
# Maximum validation accuracy : 42.78%
# Start Training (total epochs: 100)...
# Maximum training accuracy : 51.03%
# Maximum validation accuracy : 41.63%

# %%
BR = run_experiment(subject = "Brian")

# %%
emg_m = [float(x) for x in EMG_result_mean]
eng_m = [float(x) for x in ENG_result_mean]

emg_st = [float(x) for x in EMG_result_std]
eng_st = [float(x) for x in ENG_result_std]
emg_m, eng_m, emg_st, eng_st
# Out:
# ([0.42878782749176025,
#   0.3310706913471222,
#   0.35904206335544586,
#   0.6106011271476746,
#   0.5019441395998001,
#   0.6005978584289551,
#   0.5293917655944824,
#   0.5303820222616196,
#   0.6454729735851288,
#   0.5041433854235543],
#  [0.5268587470054626,
#   0.6050552427768707,
#   0.545380711555481,
#   0.7593218088150024,
#   0.4555933475494385,
#   0.5178944170475006,
#   0.5620518922805786,
#   0.5614217519760132,
#   0.4220743030309677,
#   0.5506280246708128],
#  [0.026361674070358276,
#   0.028349608182907104,
#   0.032305046916007996,
#   0.01692497730255127,
#   0.033312246203422546,
#   0.01564866304397583,
#   0.02972644567489624,
#   0.04258860647678375,
#   0.05282732844352722,
#   0.10468394936094144],
#  [0.01738905906677246,
#   0.008295983076095581,
#   0.007301270961761475,
#   0.008739054203033447,
#   0.001889646053314209,
#   0.05837675929069519,
#   0.006995737552642822,
#   0.009935557842254639,
#   0.005760744214057922,
#   0.09066671448418406])

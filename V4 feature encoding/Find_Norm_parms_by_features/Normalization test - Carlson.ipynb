# %%
import sys
sys.path.append("../../Share")
sys.path.append("../")

import config, Processing_same_with_MATLAB, Feature_info
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

SUBJECT = "Carlson"

# %%
fs, lower_cutoff, upper_cutoff = Feature_info.fs, Feature_info.lower_cutoff, Feature_info.upper_cutoff
filter_b, filter_a = Processing_same_with_MATLAB.cheby2(4, 30, [lower_cutoff / (fs/2), upper_cutoff / (fs/2)], btype='bandpass')

import Train_and_test_one_feature_with_norm_param

Trainer_feature_wise = Train_and_test_one_feature_with_norm_param.main(filter_a,
                                                          filter_b,
                                                          data_files = config.dataset_sub_C,
                                                          default_path = config.default_path_sub_C,
                                                          SUBJECT = SUBJECT,
                                                          K = 4) #K : K 이전 데이터 학습, K이후 데이터 테스트

Normalization_TF = True


def get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT):
    All_acc, All_param = [], []

    for M in mean_list:
        for S in std_list:
            test_acc, X_train_stacked, y_train_stacked, X_test_stacked, y_test_stacked = Trainer_feature_wise.Train_and_test(
                Normalization_TF, M, S, num_feature_set=14, target_feat_idx=feature_idx
            )
            All_acc.append(np.mean(test_acc))
            All_param.append([M, S])

    # Find best param
    best_idx = np.argmax(All_acc)
    best_param = All_param[best_idx]
    best_acc = All_acc[best_idx]

    # Create DataFrame
    df = pd.DataFrame(All_param, columns=["Mean", "Std"])
    df["Accuracy"] = All_acc

    # Pivot for heatmap
    heatmap_data = df.pivot(index="Mean", columns="Std", values="Accuracy")

    # Plot
    plt.figure(figsize=(8, 6))
    sns.heatmap(heatmap_data, annot=True, fmt=".4f", cmap="viridis", cbar_kws={'label': 'Accuracy'})
    plt.title(f'Grid Search Accuracy - {Feature_info.feature_names[feature_idx]}')
    plt.xlabel("Std")
    plt.ylabel("Mean")
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.grid(False)
    plt.savefig(f'./GridSearchPlot_{Feature_info.feature_names[feature_idx]}.png', dpi=300)
    plt.show()

    # Save raw data
    df.to_csv(f'./result/{SUBJECT}/Accuracy using Norm params - feature {Feature_info.feature_names[feature_idx]}.csv', index=False)

    return best_param, best_acc

# %% [markdown]
# # WL (Index 2)

# %%
feature_idx = 2  # WL / 2 (mean) / 0.8 (std)
mean_list = [1, 1.5, 2, 2.5, 3, 3.5]
std_list = [0.4, 0.6, 0.8, 1, 1.2]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.57%
# Maximum validation accuracy : 87.43%
# Accuracy of test dataset using model V0: 87.1379%
# 	 Accuracy on test dataset 5: 87.4276%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3694%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.7672%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.3304%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.08%
# Maximum validation accuracy : 87.2%
# Accuracy of test dataset using model V0: 87.0220%
# 	 Accuracy on test dataset 5: 87.1958%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.9988%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.4314%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.0745%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.94%
# Maximum validation accuracy : 86.15%
# Accuracy of test dataset using model V0: 86.0950%
# 	 Accuracy on test dataset 5: 86.1530%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.9485%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.7093%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.6794%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.05%
# Maximum validation accuracy : 84.41%
# Accuracy of test dataset using model V0: 84.2410%
# 	 Accuracy on test dataset 5: 84.4148%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.5704%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.9102%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1443%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.92%
# Maximum validation accuracy : 85.86%
# Accuracy of test dataset using model V0: 85.8053%
# 	 Accuracy on test dataset 5: 85.8633%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.1650%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.0029%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.2141%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.94%
# Maximum validation accuracy : 87.66%
# Accuracy of test dataset using model V0: 87.6014%
# 	 Accuracy on test dataset 5: 87.6593%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.9600%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.3538%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6682%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.72%
# Maximum validation accuracy : 87.89%
# Accuracy of test dataset using model V0: 87.4855%
# 	 Accuracy on test dataset 5: 87.8911%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.9021%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6126%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4821%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.62%
# Maximum validation accuracy : 85.52%
# Accuracy of test dataset using model V0: 85.4577%
# 	 Accuracy on test dataset 5: 85.5156%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7053%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.1413%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.8432%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.96%
# Maximum validation accuracy : 86.5%
# Accuracy of test dataset using model V0: 86.4426%
# 	 Accuracy on test dataset 5: 86.5006%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.0411%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1801%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.4942%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.52%
# Maximum validation accuracy : 86.91%
# Accuracy of test dataset using model V0: 86.7323%
# 	 Accuracy on test dataset 5: 86.9061%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7284%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.5356%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.5747%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.38%
# Maximum validation accuracy : 89.34%
# Accuracy of test dataset using model V0: 89.2816%
# 	 Accuracy on test dataset 5: 89.3395%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.0179%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.5200%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.8776%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.7%
# Maximum validation accuracy : 86.33%
# Accuracy of test dataset using model V0: 86.3268%
# 	 Accuracy on test dataset 5: 86.3268%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.8830%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.8442%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.7376%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.43%
# Maximum validation accuracy : 88.18%
# Accuracy of test dataset using model V0: 88.1228%
# 	 Accuracy on test dataset 5: 88.1808%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8790%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.5316%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2727%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.56%
# Maximum validation accuracy : 86.62%
# Accuracy of test dataset using model V0: 86.5585%
# 	 Accuracy on test dataset 5: 86.6165%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.2884%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.5588%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.5631%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.31%
# Maximum validation accuracy : 86.62%
# Accuracy of test dataset using model V0: 86.6165%
# 	 Accuracy on test dataset 5: 86.6165%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5200%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.2999%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0982%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.89%
# Maximum validation accuracy : 86.91%
# Accuracy of test dataset using model V0: 86.5585%
# 	 Accuracy on test dataset 5: 86.9061%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5663%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.8095%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2727%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.98%
# Maximum validation accuracy : 85.92%
# Accuracy of test dataset using model V0: 85.8633%
# 	 Accuracy on test dataset 5: 85.9212%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8327%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.0643%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2145%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.37%
# Maximum validation accuracy : 87.08%
# Accuracy of test dataset using model V0: 87.0800%
# 	 Accuracy on test dataset 5: 87.0800%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.0567%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.9797%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.0861%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.44%
# Maximum validation accuracy : 87.6%
# Accuracy of test dataset using model V0: 87.2538%
# 	 Accuracy on test dataset 5: 87.6014%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5547%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.8054%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.4360%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.1%
# Maximum validation accuracy : 87.02%
# Accuracy of test dataset using model V0: 86.9641%
# 	 Accuracy on test dataset 5: 87.0220%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4505%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6358%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.3192%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.2%
# Maximum validation accuracy : 85.92%
# Accuracy of test dataset using model V0: 85.8633%
# 	 Accuracy on test dataset 5: 85.9212%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4157%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1494%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9819%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.39%
# Maximum validation accuracy : 86.33%
# Accuracy of test dataset using model V0: 86.2688%
# 	 Accuracy on test dataset 5: 86.3268%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.9294%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1338%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4239%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.92%
# Maximum validation accuracy : 88.93%
# Accuracy of test dataset using model V0: 88.9340%
# 	 Accuracy on test dataset 5: 88.9340%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7748%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.3463%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0168%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.37%
# Maximum validation accuracy : 88.76%
# Accuracy of test dataset using model V0: 88.7022%
# 	 Accuracy on test dataset 5: 88.7601%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3810%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.0602%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.7967%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.2%
# Maximum validation accuracy : 85.05%
# Accuracy of test dataset using model V0: 84.8783%
# 	 Accuracy on test dataset 5: 85.0521%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.1453%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.8715%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.7376%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.75%
# Maximum validation accuracy : 85.63%
# Accuracy of test dataset using model V0: 85.5156%
# 	 Accuracy on test dataset 5: 85.6315%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.0799%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.7209%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0866%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.81%
# Maximum validation accuracy : 86.38%
# Accuracy of test dataset using model V0: 86.3847%
# 	 Accuracy on test dataset 5: 86.3847%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1726%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.9062%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.1796%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.3%
# Maximum validation accuracy : 87.2%
# Accuracy of test dataset using model V0: 87.1379%
# 	 Accuracy on test dataset 5: 87.1958%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.9948%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.2768%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0982%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.12%
# Maximum validation accuracy : 86.56%
# Accuracy of test dataset using model V0: 86.5585%
# 	 Accuracy on test dataset 5: 86.5585%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.8830%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.5200%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0284%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.83%
# Maximum validation accuracy : 85.57%
# Accuracy of test dataset using model V0: 85.4577%
# 	 Accuracy on test dataset 5: 85.5736%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.2305%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.4470%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1443%
# Best Accuracy: 87.5632 with mean=1.5, std=0.8

# %% [markdown]
# # MAV

# %%
feature_idx = 4  # MAV / 11.0 (mean) / 4.43 (std)

mean_list = [8.0, 10.0, 11.0, 12.5, 14.0]
std_list = [3.0, 3.8, 4.4, 5.2, 6.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.63%
# Maximum validation accuracy : 85.57%
# Accuracy of test dataset using model V0: 85.1101%
# 	 Accuracy on test dataset 5: 85.5736%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8906%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7053%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9819%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.89%
# Maximum validation accuracy : 88.18%
# Accuracy of test dataset using model V0: 88.0070%
# 	 Accuracy on test dataset 5: 88.1808%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5431%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4505%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8772%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.95%
# Maximum validation accuracy : 85.05%
# Accuracy of test dataset using model V0: 84.8783%
# 	 Accuracy on test dataset 5: 85.0521%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4852%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.7788%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.5980%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.01%
# Maximum validation accuracy : 87.95%
# Accuracy of test dataset using model V0: 87.9490%
# 	 Accuracy on test dataset 5: 87.9490%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.8251%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.8674%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.3546%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.08%
# Maximum validation accuracy : 86.1%
# Accuracy of test dataset using model V0: 85.8053%
# 	 Accuracy on test dataset 5: 86.0950%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5084%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.0336%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0749%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.12%
# Maximum validation accuracy : 86.96%
# Accuracy of test dataset using model V0: 86.7323%
# 	 Accuracy on test dataset 5: 86.9641%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.1222%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.0799%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0749%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.57%
# Maximum validation accuracy : 85.28%
# Accuracy of test dataset using model V0: 85.2260%
# 	 Accuracy on test dataset 5: 85.2839%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4389%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.3694%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.7376%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.65%
# Maximum validation accuracy : 83.66%
# Accuracy of test dataset using model V0: 83.3720%
# 	 Accuracy on test dataset 5: 83.6616%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.5935%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.3272%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7022%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.38%
# Maximum validation accuracy : 86.91%
# Accuracy of test dataset using model V0: 86.7903%
# 	 Accuracy on test dataset 5: 86.9061%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.2768%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.9062%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.5282%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.86%
# Maximum validation accuracy : 87.49%
# Accuracy of test dataset using model V0: 87.4276%
# 	 Accuracy on test dataset 5: 87.4855%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5895%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.5316%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.5980%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.08%
# Maximum validation accuracy : 86.91%
# Accuracy of test dataset using model V0: 86.4426%
# 	 Accuracy on test dataset 5: 86.9061%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.7441%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.9913%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1792%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.46%
# Maximum validation accuracy : 88.24%
# Accuracy of test dataset using model V0: 87.9490%
# 	 Accuracy on test dataset 5: 88.2387%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7632%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.2148%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6682%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.89%
# Maximum validation accuracy : 87.25%
# Accuracy of test dataset using model V0: 87.0220%
# 	 Accuracy on test dataset 5: 87.2538%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.3156%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4273%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.3658%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.63%
# Maximum validation accuracy : 88.35%
# Accuracy of test dataset using model V0: 88.3546%
# 	 Accuracy on test dataset 5: 88.3546%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1841%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.7475%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.3313%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.97%
# Maximum validation accuracy : 85.05%
# Accuracy of test dataset using model V0: 84.8204%
# 	 Accuracy on test dataset 5: 85.0521%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.6358%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.7441%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4239%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.24%
# Maximum validation accuracy : 85.28%
# Accuracy of test dataset using model V0: 85.1680%
# 	 Accuracy on test dataset 5: 85.2839%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.0683%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.8292%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.4002%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.54%
# Maximum validation accuracy : 89.05%
# Accuracy of test dataset using model V0: 88.0070%
# 	 Accuracy on test dataset 5: 89.0498%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.2536%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6126%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0982%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.44%
# Maximum validation accuracy : 84.53%
# Accuracy of test dataset using model V0: 84.5307%
# 	 Accuracy on test dataset 5: 84.5307%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5200%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.0104%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2494%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.79%
# Maximum validation accuracy : 85.86%
# Accuracy of test dataset using model V0: 85.6895%
# 	 Accuracy on test dataset 5: 85.8633%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3926%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.8946%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.3653%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.43%
# Maximum validation accuracy : 86.21%
# Accuracy of test dataset using model V0: 86.2109%
# 	 Accuracy on test dataset 5: 86.2109%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.0220%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.3306%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.7152%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.91%
# Maximum validation accuracy : 85.86%
# Accuracy of test dataset using model V0: 85.5156%
# 	 Accuracy on test dataset 5: 85.8633%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8906%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4505%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9819%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.05%
# Maximum validation accuracy : 84.94%
# Accuracy of test dataset using model V0: 84.4148%
# 	 Accuracy on test dataset 5: 84.9363%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.9525%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7516%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.5984%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.6%
# Maximum validation accuracy : 86.44%
# Accuracy of test dataset using model V0: 86.3268%
# 	 Accuracy on test dataset 5: 86.4426%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.2073%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.3231%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2960%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.86%
# Maximum validation accuracy : 86.67%
# Accuracy of test dataset using model V0: 86.5585%
# 	 Accuracy on test dataset 5: 86.6744%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.9716%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.9832%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4356%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.39%
# Maximum validation accuracy : 84.41%
# Accuracy of test dataset using model V0: 84.1831%
# 	 Accuracy on test dataset 5: 84.4148%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1610%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.6630%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.5049%
# Best Accuracy: 87.0877 with mean=11.0, std=5.2

# %% [markdown]
# # MS(Mean squared)

# %%
feature_idx = 5

mean_list = [160, 200, 229, 260, 290]
std_list  = [200, 260, 304, 360, 420]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.04%
# Maximum validation accuracy : 84.53%
# Accuracy of test dataset using model V0: 84.5307%
# 	 Accuracy on test dataset 5: 84.5307%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.2461%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.8408%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.4114%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.26%
# Maximum validation accuracy : 81.92%
# Accuracy of test dataset using model V0: 81.6918%
# 	 Accuracy on test dataset 5: 81.9235%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.8408%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.9913%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7604%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.31%
# Maximum validation accuracy : 85.34%
# Accuracy of test dataset using model V0: 84.4148%
# 	 Accuracy on test dataset 5: 85.3418%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.5049%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.6207%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7022%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.58%
# Maximum validation accuracy : 81.98%
# Accuracy of test dataset using model V0: 81.8076%
# 	 Accuracy on test dataset 5: 81.9815%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.0840%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.7944%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.0042%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.18%
# Maximum validation accuracy : 83.66%
# Accuracy of test dataset using model V0: 82.0973%
# 	 Accuracy on test dataset 5: 83.6616%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.6827%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.9068%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.3644%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.82%
# Maximum validation accuracy : 85.86%
# Accuracy of test dataset using model V0: 85.5156%
# 	 Accuracy on test dataset 5: 85.8633%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.4314%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.4777%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.0977%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.91%
# Maximum validation accuracy : 83.84%
# Accuracy of test dataset using model V0: 83.3720%
# 	 Accuracy on test dataset 5: 83.8355%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.2733%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.6439%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.9930%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.68%
# Maximum validation accuracy : 80.53%
# Accuracy of test dataset using model V0: 79.9537%
# 	 Accuracy on test dataset 5: 80.5330%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 82.3625%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.1193%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.5151%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.21%
# Maximum validation accuracy : 82.73%
# Accuracy of test dataset using model V0: 81.5759%
# 	 Accuracy on test dataset 5: 82.7346%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.6248%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.8720%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.0619%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.94%
# Maximum validation accuracy : 83.49%
# Accuracy of test dataset using model V0: 83.3720%
# 	 Accuracy on test dataset 5: 83.4878%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.1882%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.6630%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5161%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.76%
# Maximum validation accuracy : 84.41%
# Accuracy of test dataset using model V0: 84.1251%
# 	 Accuracy on test dataset 5: 84.4148%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.6746%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.4545%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7604%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.05%
# Maximum validation accuracy : 82.04%
# Accuracy of test dataset using model V0: 80.3013%
# 	 Accuracy on test dataset 5: 82.0394%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 81.7603%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 81.6792%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.1196%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.01%
# Maximum validation accuracy : 84.41%
# Accuracy of test dataset using model V0: 84.3569%
# 	 Accuracy on test dataset 5: 84.4148%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.6902%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.2345%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.7027%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.88%
# Maximum validation accuracy : 83.95%
# Accuracy of test dataset using model V0: 82.7926%
# 	 Accuracy on test dataset 5: 83.9513%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.9334%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.0649%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.1322%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.74%
# Maximum validation accuracy : 81.11%
# Accuracy of test dataset using model V0: 80.8806%
# 	 Accuracy on test dataset 5: 81.1124%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.8639%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.1691%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.1438%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.68%
# Maximum validation accuracy : 83.02%
# Accuracy of test dataset using model V0: 81.3441%
# 	 Accuracy on test dataset 5: 83.0243%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.7250%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.7441%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7953%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.17%
# Maximum validation accuracy : 83.78%
# Accuracy of test dataset using model V0: 83.3140%
# 	 Accuracy on test dataset 5: 83.7775%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.4933%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.5860%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5626%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.07%
# Maximum validation accuracy : 84.65%
# Accuracy of test dataset using model V0: 84.1831%
# 	 Accuracy on test dataset 5: 84.6466%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.5472%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.6630%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1094%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.79%
# Maximum validation accuracy : 81.63%
# Accuracy of test dataset using model V0: 80.6489%
# 	 Accuracy on test dataset 5: 81.6338%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.2038%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.3353%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.6087%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.18%
# Maximum validation accuracy : 83.2%
# Accuracy of test dataset using model V0: 82.1553%
# 	 Accuracy on test dataset 5: 83.1981%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.7250%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.4702%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.9809%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.3%
# Maximum validation accuracy : 84.41%
# Accuracy of test dataset using model V0: 84.3569%
# 	 Accuracy on test dataset 5: 84.4148%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.8523%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.1071%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.2601%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.24%
# Maximum validation accuracy : 83.14%
# Accuracy of test dataset using model V0: 82.6767%
# 	 Accuracy on test dataset 5: 83.1402%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.5240%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.9450%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7953%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.02%
# Maximum validation accuracy : 84.18%
# Accuracy of test dataset using model V0: 83.6037%
# 	 Accuracy on test dataset 5: 84.1831%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.0261%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.6555%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.8413%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.4%
# Maximum validation accuracy : 84.3%
# Accuracy of test dataset using model V0: 82.2711%
# 	 Accuracy on test dataset 5: 84.2990%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.1691%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.1343%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.0507%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.45%
# Maximum validation accuracy : 82.27%
# Accuracy of test dataset using model V0: 81.1703%
# 	 Accuracy on test dataset 5: 82.2711%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.0921%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.8373%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.3527%
# Best Accuracy: 85.4398 with mean=260, std=304

# %% [markdown]
# # Root Mean Squared (RMS)

# %%
feature_idx = 6
mean_list_RMS = [10.0, 12.0, 13.8, 15.5, 17.0]
std_list_RMS  = [4.5, 5.5, 6.85, 8.0, 9.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.94%
# Maximum validation accuracy : 80.94%
# Accuracy of test dataset using model V0: 80.9386%
# 	 Accuracy on test dataset 5: 80.9386%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.1303%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.7481%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5510%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.61%
# Maximum validation accuracy : 74.62%
# Accuracy of test dataset using model V0: 74.6234%
# 	 Accuracy on test dataset 5: 74.6234%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.9%
# Maximum validation accuracy : 75.43%
# Accuracy of test dataset using model V0: 75.4345%
# 	 Accuracy on test dataset 5: 75.4345%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.18%
# Maximum validation accuracy : 73.7%
# Accuracy of test dataset using model V0: 73.6964%
# 	 Accuracy on test dataset 5: 73.6964%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.14%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.17%
# Maximum validation accuracy : 74.86%
# Accuracy of test dataset using model V0: 74.5655%
# 	 Accuracy on test dataset 5: 74.8552%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.97%
# Maximum validation accuracy : 75.38%
# Accuracy of test dataset using model V0: 75.3187%
# 	 Accuracy on test dataset 5: 75.3766%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.65%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.88%
# Maximum validation accuracy : 74.62%
# Accuracy of test dataset using model V0: 74.3337%
# 	 Accuracy on test dataset 5: 74.6234%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.55%
# Maximum validation accuracy : 76.59%
# Accuracy of test dataset using model V0: 76.5933%
# 	 Accuracy on test dataset 5: 76.5933%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.69%
# Maximum validation accuracy : 75.38%
# Accuracy of test dataset using model V0: 75.3187%
# 	 Accuracy on test dataset 5: 75.3766%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.34%
# Maximum validation accuracy : 75.55%
# Accuracy of test dataset using model V0: 75.3766%
# 	 Accuracy on test dataset 5: 75.5504%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.97%
# Maximum validation accuracy : 75.26%
# Accuracy of test dataset using model V0: 75.2607%
# 	 Accuracy on test dataset 5: 75.2607%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.87%
# Maximum validation accuracy : 75.2%
# Accuracy of test dataset using model V0: 75.2028%
# 	 Accuracy on test dataset 5: 75.2028%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.04%
# Maximum validation accuracy : 76.71%
# Accuracy of test dataset using model V0: 76.7092%
# 	 Accuracy on test dataset 5: 76.7092%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.79%
# Maximum validation accuracy : 74.16%
# Accuracy of test dataset using model V0: 74.1599%
# 	 Accuracy on test dataset 5: 74.1599%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.07%
# Maximum validation accuracy : 76.65%
# Accuracy of test dataset using model V0: 76.6512%
# 	 Accuracy on test dataset 5: 76.6512%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.88%
# Maximum validation accuracy : 75.96%
# Accuracy of test dataset using model V0: 75.9560%
# 	 Accuracy on test dataset 5: 75.9560%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.56%
# Maximum validation accuracy : 76.54%
# Accuracy of test dataset using model V0: 76.0139%
# 	 Accuracy on test dataset 5: 76.5353%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.39%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.79%
# Maximum validation accuracy : 75.55%
# Accuracy of test dataset using model V0: 74.5075%
# 	 Accuracy on test dataset 5: 75.5504%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.81%
# Maximum validation accuracy : 83.89%
# Accuracy of test dataset using model V0: 83.8355%
# 	 Accuracy on test dataset 5: 83.8934%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.3503%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.0452%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2378%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.91%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.56%
# Maximum validation accuracy : 75.32%
# Accuracy of test dataset using model V0: 75.3187%
# 	 Accuracy on test dataset 5: 75.3187%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.85%
# Maximum validation accuracy : 74.16%
# Accuracy of test dataset using model V0: 74.1599%
# 	 Accuracy on test dataset 5: 74.1599%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 85.8778 with mean=290, std=260

# %% [markdown]
# # Log Detector (LD)

# %%
feature_idx = 8
mean_list_LogDet = [6.5, 8.0, 9.0, 10.0, 11.0]
std_list_LogDet  = [2.0, 2.5, 2.87, 3.3, 3.8]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.35%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.21%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.5%
# Maximum validation accuracy : 75.32%
# Accuracy of test dataset using model V0: 75.2607%
# 	 Accuracy on test dataset 5: 75.3187%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.42%
# Maximum validation accuracy : 76.65%
# Accuracy of test dataset using model V0: 76.6512%
# 	 Accuracy on test dataset 5: 76.6512%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.63%
# Maximum validation accuracy : 75.96%
# Accuracy of test dataset using model V0: 75.9560%
# 	 Accuracy on test dataset 5: 75.9560%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.94%
# Maximum validation accuracy : 74.86%
# Accuracy of test dataset using model V0: 74.8552%
# 	 Accuracy on test dataset 5: 74.8552%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.39%
# Maximum validation accuracy : 76.83%
# Accuracy of test dataset using model V0: 76.8250%
# 	 Accuracy on test dataset 5: 76.8250%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.33%
# Maximum validation accuracy : 74.33%
# Accuracy of test dataset using model V0: 74.3337%
# 	 Accuracy on test dataset 5: 74.3337%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.97%
# Maximum validation accuracy : 77.06%
# Accuracy of test dataset using model V0: 77.0568%
# 	 Accuracy on test dataset 5: 77.0568%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.98%
# Maximum validation accuracy : 75.32%
# Accuracy of test dataset using model V0: 75.3187%
# 	 Accuracy on test dataset 5: 75.3187%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.45%
# Maximum validation accuracy : 74.97%
# Accuracy of test dataset using model V0: 74.9710%
# 	 Accuracy on test dataset 5: 74.9710%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.2%
# Maximum validation accuracy : 73.64%
# Accuracy of test dataset using model V0: 73.6385%
# 	 Accuracy on test dataset 5: 73.6385%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.75%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.71%
# Maximum validation accuracy : 76.48%
# Accuracy of test dataset using model V0: 76.4774%
# 	 Accuracy on test dataset 5: 76.4774%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.72%
# Maximum validation accuracy : 77.11%
# Accuracy of test dataset using model V0: 77.1147%
# 	 Accuracy on test dataset 5: 77.1147%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.34%
# Maximum validation accuracy : 76.07%
# Accuracy of test dataset using model V0: 76.0718%
# 	 Accuracy on test dataset 5: 76.0718%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.58%
# Maximum validation accuracy : 74.97%
# Accuracy of test dataset using model V0: 74.9710%
# 	 Accuracy on test dataset 5: 74.9710%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.5%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.69%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.82%
# Maximum validation accuracy : 74.04%
# Accuracy of test dataset using model V0: 74.0440%
# 	 Accuracy on test dataset 5: 74.0440%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.07%
# Maximum validation accuracy : 74.16%
# Accuracy of test dataset using model V0: 74.1599%
# 	 Accuracy on test dataset 5: 74.1599%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.59%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.78%
# Maximum validation accuracy : 75.67%
# Accuracy of test dataset using model V0: 75.6663%
# 	 Accuracy on test dataset 5: 75.6663%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.36%
# Maximum validation accuracy : 77.17%
# Accuracy of test dataset using model V0: 77.1727%
# 	 Accuracy on test dataset 5: 77.1727%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.55%
# Maximum validation accuracy : 73.7%
# Accuracy of test dataset using model V0: 73.6964%
# 	 Accuracy on test dataset 5: 73.6964%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 78.7219 with mean=160, std=200

# %% [markdown]
# # DASDV (Difference Absolute Standard Deviation Value)

# %%
feature_idx = 9
mean_list_DASDV = [2.2, 2.6, 3.0, 3.4, 3.8]
std_list_DASDV  = [0.6, 0.75, 0.87, 1.0, 1.1]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.97%
# Maximum validation accuracy : 76.36%
# Accuracy of test dataset using model V0: 76.3615%
# 	 Accuracy on test dataset 5: 76.3615%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.53%
# Maximum validation accuracy : 76.3%
# Accuracy of test dataset using model V0: 76.3036%
# 	 Accuracy on test dataset 5: 76.3036%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.77%
# Maximum validation accuracy : 75.67%
# Accuracy of test dataset using model V0: 75.6663%
# 	 Accuracy on test dataset 5: 75.6663%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.01%
# Maximum validation accuracy : 76.01%
# Accuracy of test dataset using model V0: 76.0139%
# 	 Accuracy on test dataset 5: 76.0139%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.07%
# Maximum validation accuracy : 74.86%
# Accuracy of test dataset using model V0: 74.8552%
# 	 Accuracy on test dataset 5: 74.8552%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.14%
# Maximum validation accuracy : 76.71%
# Accuracy of test dataset using model V0: 76.7092%
# 	 Accuracy on test dataset 5: 76.7092%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.1%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.7242%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.45%
# Maximum validation accuracy : 74.68%
# Accuracy of test dataset using model V0: 74.6813%
# 	 Accuracy on test dataset 5: 74.6813%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.01%
# Maximum validation accuracy : 74.62%
# Accuracy of test dataset using model V0: 74.6234%
# 	 Accuracy on test dataset 5: 74.6234%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.42%
# Maximum validation accuracy : 75.26%
# Accuracy of test dataset using model V0: 75.2607%
# 	 Accuracy on test dataset 5: 75.2607%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.49%
# Maximum validation accuracy : 74.97%
# Accuracy of test dataset using model V0: 74.9710%
# 	 Accuracy on test dataset 5: 74.9710%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.68%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.7242%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.01%
# Maximum validation accuracy : 74.51%
# Accuracy of test dataset using model V0: 74.5075%
# 	 Accuracy on test dataset 5: 74.5075%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.23%
# Maximum validation accuracy : 75.43%
# Accuracy of test dataset using model V0: 75.4345%
# 	 Accuracy on test dataset 5: 75.4345%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.23%
# Maximum validation accuracy : 76.36%
# Accuracy of test dataset using model V0: 76.3615%
# 	 Accuracy on test dataset 5: 76.3615%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.85%
# Maximum validation accuracy : 76.54%
# Accuracy of test dataset using model V0: 76.5353%
# 	 Accuracy on test dataset 5: 76.5353%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.16%
# Maximum validation accuracy : 76.01%
# Accuracy of test dataset using model V0: 76.0139%
# 	 Accuracy on test dataset 5: 76.0139%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.81%
# Maximum validation accuracy : 76.42%
# Accuracy of test dataset using model V0: 76.4195%
# 	 Accuracy on test dataset 5: 76.4195%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.53%
# Maximum validation accuracy : 74.28%
# Accuracy of test dataset using model V0: 74.2758%
# 	 Accuracy on test dataset 5: 74.2758%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.56%
# Maximum validation accuracy : 74.74%
# Accuracy of test dataset using model V0: 74.7393%
# 	 Accuracy on test dataset 5: 74.7393%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.71%
# Maximum validation accuracy : 76.54%
# Accuracy of test dataset using model V0: 76.5353%
# 	 Accuracy on test dataset 5: 76.5353%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.21%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.4%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.52%
# Maximum validation accuracy : 74.39%
# Accuracy of test dataset using model V0: 74.3917%
# 	 Accuracy on test dataset 5: 74.3917%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.1%
# Maximum validation accuracy : 77.4%
# Accuracy of test dataset using model V0: 77.4044%
# 	 Accuracy on test dataset 5: 77.4044%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 79.8495%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 80.5675%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 80.4909%
# Best Accuracy: 80.3026 with mean=290, std=420

# %% [markdown]
# # MFL (Maximum Fractal Length)

# %%
feature_idx = 10
mean_list_MFL = [1.0, 1.3, 1.5, 1.7, 2.0]
std_list_MFL  = [0.12, 0.17, 0.21, 0.25, 0.30]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.81%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.7%
# Maximum validation accuracy : 76.13%
# Accuracy of test dataset using model V0: 76.1298%
# 	 Accuracy on test dataset 5: 76.1298%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.07%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.67%
# Maximum validation accuracy : 74.86%
# Accuracy of test dataset using model V0: 74.8552%
# 	 Accuracy on test dataset 5: 74.8552%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.56%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.16%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.93%
# Maximum validation accuracy : 74.45%
# Accuracy of test dataset using model V0: 74.4496%
# 	 Accuracy on test dataset 5: 74.4496%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.51%
# Maximum validation accuracy : 77.0%
# Accuracy of test dataset using model V0: 76.9988%
# 	 Accuracy on test dataset 5: 76.9988%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.01%
# Maximum validation accuracy : 75.14%
# Accuracy of test dataset using model V0: 75.1448%
# 	 Accuracy on test dataset 5: 75.1448%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.1%
# Maximum validation accuracy : 73.75%
# Accuracy of test dataset using model V0: 73.7543%
# 	 Accuracy on test dataset 5: 73.7543%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.52%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.94%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.42%
# Maximum validation accuracy : 74.68%
# Accuracy of test dataset using model V0: 74.6813%
# 	 Accuracy on test dataset 5: 74.6813%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.25%
# Maximum validation accuracy : 76.59%
# Accuracy of test dataset using model V0: 76.5933%
# 	 Accuracy on test dataset 5: 76.5933%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.8%
# Maximum validation accuracy : 76.42%
# Accuracy of test dataset using model V0: 76.4195%
# 	 Accuracy on test dataset 5: 76.4195%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.64%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.87%
# Maximum validation accuracy : 75.67%
# Accuracy of test dataset using model V0: 75.6663%
# 	 Accuracy on test dataset 5: 75.6663%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.77%
# Maximum validation accuracy : 75.2%
# Accuracy of test dataset using model V0: 75.2028%
# 	 Accuracy on test dataset 5: 75.2028%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.48%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.98%
# Maximum validation accuracy : 74.45%
# Accuracy of test dataset using model V0: 74.4496%
# 	 Accuracy on test dataset 5: 74.4496%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.67%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.01%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.67%
# Maximum validation accuracy : 75.49%
# Accuracy of test dataset using model V0: 75.4925%
# 	 Accuracy on test dataset 5: 75.4925%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.93%
# Maximum validation accuracy : 74.39%
# Accuracy of test dataset using model V0: 74.3917%
# 	 Accuracy on test dataset 5: 74.3917%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.12%
# Maximum validation accuracy : 75.49%
# Accuracy of test dataset using model V0: 75.4925%
# 	 Accuracy on test dataset 5: 75.4925%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 78.7219 with mean=160, std=200

# %% [markdown]
# # WMS

# %%
feature_idx = 13
mean_list_WMS = [2.0, 2.4, 2.8, 3.2, 3.6]
std_list_WMS  = [0.8, 1.0, 1.12, 1.3, 1.5]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.84%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.69%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.3%
# Maximum validation accuracy : 75.38%
# Accuracy of test dataset using model V0: 75.3766%
# 	 Accuracy on test dataset 5: 75.3766%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.93%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.34%
# Maximum validation accuracy : 73.52%
# Accuracy of test dataset using model V0: 73.5226%
# 	 Accuracy on test dataset 5: 73.5226%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.21%
# Maximum validation accuracy : 74.68%
# Accuracy of test dataset using model V0: 74.6813%
# 	 Accuracy on test dataset 5: 74.6813%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.27%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.1%
# Maximum validation accuracy : 76.54%
# Accuracy of test dataset using model V0: 76.5353%
# 	 Accuracy on test dataset 5: 76.5353%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.24%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.79%
# Maximum validation accuracy : 77.17%
# Accuracy of test dataset using model V0: 77.1727%
# 	 Accuracy on test dataset 5: 77.1727%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.11%
# Maximum validation accuracy : 76.3%
# Accuracy of test dataset using model V0: 76.3036%
# 	 Accuracy on test dataset 5: 76.3036%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.97%
# Maximum validation accuracy : 76.83%
# Accuracy of test dataset using model V0: 76.8250%
# 	 Accuracy on test dataset 5: 76.8250%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.23%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.91%
# Maximum validation accuracy : 75.26%
# Accuracy of test dataset using model V0: 75.2607%
# 	 Accuracy on test dataset 5: 75.2607%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.39%
# Maximum validation accuracy : 75.67%
# Accuracy of test dataset using model V0: 75.6663%
# 	 Accuracy on test dataset 5: 75.6663%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.17%
# Maximum validation accuracy : 73.93%
# Accuracy of test dataset using model V0: 73.9282%
# 	 Accuracy on test dataset 5: 73.9282%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.01%
# Maximum validation accuracy : 74.33%
# Accuracy of test dataset using model V0: 74.3337%
# 	 Accuracy on test dataset 5: 74.3337%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.06%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.7242%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.85%
# Maximum validation accuracy : 74.86%
# Accuracy of test dataset using model V0: 74.8552%
# 	 Accuracy on test dataset 5: 74.8552%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.71%
# Maximum validation accuracy : 74.97%
# Accuracy of test dataset using model V0: 74.9710%
# 	 Accuracy on test dataset 5: 74.9710%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.85%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.91%
# Maximum validation accuracy : 73.58%
# Accuracy of test dataset using model V0: 73.5805%
# 	 Accuracy on test dataset 5: 73.5805%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.78%
# Maximum validation accuracy : 75.43%
# Accuracy of test dataset using model V0: 75.4345%
# 	 Accuracy on test dataset 5: 75.4345%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.77%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.77%
# Maximum validation accuracy : 76.83%
# Accuracy of test dataset using model V0: 76.8250%
# 	 Accuracy on test dataset 5: 76.8250%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 78.7219 with mean=160, std=200

# %%
import sys
sys.path.append("../../Share")
sys.path.append("../")

import config, Processing_same_with_MATLAB, Feature_info
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

SUBJECT = "Harold"
data_files = config.dataset_sub_H2
default_path = config.default_path_sub_H2

# %%
fs, lower_cutoff, upper_cutoff = Feature_info.fs, Feature_info.lower_cutoff, Feature_info.upper_cutoff
filter_b, filter_a = Processing_same_with_MATLAB.cheby2(4, 30, [lower_cutoff / (fs/2), upper_cutoff / (fs/2)], btype='bandpass')

import Train_and_test_one_feature_with_norm_param

Trainer_feature_wise = Train_and_test_one_feature_with_norm_param.main(filter_a,
                                                          filter_b,
                                                          data_files = data_files,
                                                          default_path = default_path,
                                                          SUBJECT = SUBJECT,
                                                          K = 4) #K : K 이전 데이터 학습, K이후 데이터 테스트

Normalization_TF = True


def get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT):
    All_acc, All_param = [], []

    for M in mean_list:
        for S in std_list:
            test_acc, X_train_stacked, y_train_stacked, X_test_stacked, y_test_stacked = Trainer_feature_wise.Train_and_test(
                Normalization_TF, M, S, num_feature_set=14, target_feat_idx=feature_idx
            )
            All_acc.append(np.mean(test_acc))
            All_param.append([M, S])

    # Find best param
    best_idx = np.argmax(All_acc)
    best_param = All_param[best_idx]
    best_acc = All_acc[best_idx]

    # Create DataFrame
    df = pd.DataFrame(All_param, columns=["Mean", "Std"])
    df["Accuracy"] = All_acc

    # Pivot for heatmap
    heatmap_data = df.pivot(index="Mean", columns="Std", values="Accuracy")

    # Plot
    plt.figure(figsize=(8, 6))
    sns.heatmap(heatmap_data, annot=True, fmt=".4f", cmap="viridis", cbar_kws={'label': 'Accuracy'})
    plt.title(f'Grid Search Accuracy - {Feature_info.feature_names[feature_idx]}')
    plt.xlabel("Std")
    plt.ylabel("Mean")
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.grid(False)
    plt.savefig(f'./result/{SUBJECT}/GridSearchPlot_{Feature_info.feature_names[feature_idx]}.png', dpi=300)
    plt.show()

    # Save raw data
    df.to_csv(f'./result/{SUBJECT}/Accuracy using Norm params - feature {Feature_info.feature_names[feature_idx]}.csv', index=False)

    return best_param, best_acc

# %% [markdown]
# # WL (Index 2)

# %%
feature_idx = 2  # WL / 2 (mean) / 0.8 (std)
mean_list = [1, 1.5, 2, 2.5, 3, 3.5]
std_list = [0.4, 0.6, 0.8, 1, 1.2]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.92%
# Maximum validation accuracy : 94.52%
# Accuracy of test dataset using model V0: 93.8776%
# 	 Accuracy on test dataset 5: 94.5189%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.8921%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.7315%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.4621%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.94%
# Maximum validation accuracy : 93.64%
# Accuracy of test dataset using model V0: 93.5277%
# 	 Accuracy on test dataset 5: 93.6443%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.8901%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.6343%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.7345%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.17%
# Maximum validation accuracy : 93.59%
# Accuracy of test dataset using model V0: 93.4111%
# 	 Accuracy on test dataset 5: 93.5860%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.4491%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.6505%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.5010%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.88%
# Maximum validation accuracy : 91.66%
# Accuracy of test dataset using model V0: 91.6618%
# 	 Accuracy on test dataset 5: 91.6618%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.1145%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.3356%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2363%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.61%
# Maximum validation accuracy : 91.9%
# Accuracy of test dataset using model V0: 91.8950%
# 	 Accuracy on test dataset 5: 91.8950%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.6832%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.5347%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.0964%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.18%
# Maximum validation accuracy : 92.13%
# Accuracy of test dataset using model V0: 92.0700%
# 	 Accuracy on test dataset 5: 92.1283%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.7992%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.4074%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.4077%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.61%
# Maximum validation accuracy : 92.94%
# Accuracy of test dataset using model V0: 92.9446%
# 	 Accuracy on test dataset 5: 92.9446%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.4163%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.0810%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.3257%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.61%
# Maximum validation accuracy : 95.28%
# Accuracy of test dataset using model V0: 95.2770%
# 	 Accuracy on test dataset 5: 95.2770%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.4143%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.0139%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.7733%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.77%
# Maximum validation accuracy : 91.9%
# Accuracy of test dataset using model V0: 91.8950%
# 	 Accuracy on test dataset 5: 91.8950%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.5131%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1227%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.7189%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 93.22%
# Maximum validation accuracy : 94.87%
# Accuracy of test dataset using model V0: 94.8688%
# 	 Accuracy on test dataset 5: 94.8688%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 91.1338%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.9167%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.1898%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.24%
# Maximum validation accuracy : 93.35%
# Accuracy of test dataset using model V0: 93.3528%
# 	 Accuracy on test dataset 5: 93.3528%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.9481%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 89.1319%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 90.6141%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.48%
# Maximum validation accuracy : 91.66%
# Accuracy of test dataset using model V0: 91.6618%
# 	 Accuracy on test dataset 5: 91.6618%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.9656%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.8889%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.6409%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 93.18%
# Maximum validation accuracy : 94.87%
# Accuracy of test dataset using model V0: 94.8688%
# 	 Accuracy on test dataset 5: 94.8688%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 91.6328%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.2176%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.4700%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.78%
# Maximum validation accuracy : 93.53%
# Accuracy of test dataset using model V0: 93.5277%
# 	 Accuracy on test dataset 5: 93.5277%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.9501%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.9005%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.4427%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.49%
# Maximum validation accuracy : 94.93%
# Accuracy of test dataset using model V0: 94.8105%
# 	 Accuracy on test dataset 5: 94.9271%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.9133%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.3380%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.0614%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.99%
# Maximum validation accuracy : 95.8%
# Accuracy of test dataset using model V0: 95.8017%
# 	 Accuracy on test dataset 5: 95.8017%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 91.2963%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.8981%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.5828%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.77%
# Maximum validation accuracy : 94.75%
# Accuracy of test dataset using model V0: 94.7522%
# 	 Accuracy on test dataset 5: 94.7522%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 91.1918%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.9051%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.3259%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.7%
# Maximum validation accuracy : 94.11%
# Accuracy of test dataset using model V0: 94.1108%
# 	 Accuracy on test dataset 5: 94.1108%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.3118%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.9398%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.5244%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.47%
# Maximum validation accuracy : 91.31%
# Accuracy of test dataset using model V0: 91.0787%
# 	 Accuracy on test dataset 5: 91.3120%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 88.5923%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.4514%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.5321%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.55%
# Maximum validation accuracy : 94.23%
# Accuracy of test dataset using model V0: 94.1108%
# 	 Accuracy on test dataset 5: 94.2274%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.8785%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.7037%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.5517%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.81%
# Maximum validation accuracy : 93.64%
# Accuracy of test dataset using model V0: 93.6443%
# 	 Accuracy on test dataset 5: 93.6443%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.7624%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.9213%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.1041%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.68%
# Maximum validation accuracy : 93.82%
# Accuracy of test dataset using model V0: 93.8192%
# 	 Accuracy on test dataset 5: 93.8192%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 91.0758%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.2778%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.1002%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.84%
# Maximum validation accuracy : 93.94%
# Accuracy of test dataset using model V0: 93.9359%
# 	 Accuracy on test dataset 5: 93.9359%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.4839%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.3264%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.9017%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.37%
# Maximum validation accuracy : 91.72%
# Accuracy of test dataset using model V0: 91.7201%
# 	 Accuracy on test dataset 5: 91.7201%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8168%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.5625%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.0574%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.22%
# Maximum validation accuracy : 94.23%
# Accuracy of test dataset using model V0: 94.2274%
# 	 Accuracy on test dataset 5: 94.2274%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.9617%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.5995%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.3066%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.91%
# Maximum validation accuracy : 94.52%
# Accuracy of test dataset using model V0: 94.5189%
# 	 Accuracy on test dataset 5: 94.5189%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 91.1106%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.3356%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.3140%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.92%
# Maximum validation accuracy : 93.99%
# Accuracy of test dataset using model V0: 93.8776%
# 	 Accuracy on test dataset 5: 93.9942%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 91.2266%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7708%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.5165%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.73%
# Maximum validation accuracy : 93.99%
# Accuracy of test dataset using model V0: 93.9942%
# 	 Accuracy on test dataset 5: 93.9942%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.3331%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1875%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.4777%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.86%
# Maximum validation accuracy : 93.88%
# Accuracy of test dataset using model V0: 93.8776%
# 	 Accuracy on test dataset 5: 93.8776%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.6116%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.7315%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.6528%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.32%
# Maximum validation accuracy : 92.83%
# Accuracy of test dataset using model V0: 92.7697%
# 	 Accuracy on test dataset 5: 92.8280%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 88.0933%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.8333%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.3220%
# Best Accuracy: 90.2314 with mean=2, std=0.4

# %% [markdown]
# # MAV

# %%
feature_idx = 4  # MAV / 11.0 (mean) / 4.43 (std)

mean_list = [8.0, 10.0, 11.0, 12.5, 14.0]
std_list = [3.0, 3.8, 4.4, 5.2, 6.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.93%
# Maximum validation accuracy : 92.89%
# Accuracy of test dataset using model V0: 92.8863%
# 	 Accuracy on test dataset 5: 92.8863%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 88.4066%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1875%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.9057%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.03%
# Maximum validation accuracy : 93.41%
# Accuracy of test dataset using model V0: 93.4111%
# 	 Accuracy on test dataset 5: 93.4111%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 88.8940%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.6736%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.0731%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.38%
# Maximum validation accuracy : 93.41%
# Accuracy of test dataset using model V0: 93.4111%
# 	 Accuracy on test dataset 5: 93.4111%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.3582%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.1852%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.5165%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.03%
# Maximum validation accuracy : 93.12%
# Accuracy of test dataset using model V0: 93.0612%
# 	 Accuracy on test dataset 5: 93.1195%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.6484%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1875%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.6762%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.38%
# Maximum validation accuracy : 93.47%
# Accuracy of test dataset using model V0: 93.2945%
# 	 Accuracy on test dataset 5: 93.4694%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.1610%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.6505%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.2599%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.27%
# Maximum validation accuracy : 93.99%
# Accuracy of test dataset using model V0: 93.9942%
# 	 Accuracy on test dataset 5: 93.9942%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.5536%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.9097%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.2753%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.86%
# Maximum validation accuracy : 92.83%
# Accuracy of test dataset using model V0: 92.7697%
# 	 Accuracy on test dataset 5: 92.8280%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.2170%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.9375%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.0574%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.3%
# Maximum validation accuracy : 92.36%
# Accuracy of test dataset using model V0: 92.2449%
# 	 Accuracy on test dataset 5: 92.3615%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 88.6968%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7824%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4581%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.88%
# Maximum validation accuracy : 91.2%
# Accuracy of test dataset using model V0: 91.1953%
# 	 Accuracy on test dataset 5: 91.1953%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 88.8360%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1065%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.7579%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.27%
# Maximum validation accuracy : 92.94%
# Accuracy of test dataset using model V0: 92.9446%
# 	 Accuracy on test dataset 5: 92.9446%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.2402%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7130%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.6645%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.84%
# Maximum validation accuracy : 94.34%
# Accuracy of test dataset using model V0: 94.2274%
# 	 Accuracy on test dataset 5: 94.3440%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.9037%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.7894%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.0341%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.22%
# Maximum validation accuracy : 93.76%
# Accuracy of test dataset using model V0: 93.7609%
# 	 Accuracy on test dataset 5: 93.7609%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.8573%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7245%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.0808%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.55%
# Maximum validation accuracy : 91.72%
# Accuracy of test dataset using model V0: 91.7201%
# 	 Accuracy on test dataset 5: 91.7201%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.1029%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.4190%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.3026%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.16%
# Maximum validation accuracy : 94.46%
# Accuracy of test dataset using model V0: 94.4023%
# 	 Accuracy on test dataset 5: 94.4606%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.1358%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.9167%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.2715%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.01%
# Maximum validation accuracy : 90.79%
# Accuracy of test dataset using model V0: 90.6706%
# 	 Accuracy on test dataset 5: 90.7872%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.9192%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.8102%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.3259%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.97%
# Maximum validation accuracy : 93.53%
# Accuracy of test dataset using model V0: 93.5277%
# 	 Accuracy on test dataset 5: 93.5277%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.8224%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.3171%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8394%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.71%
# Maximum validation accuracy : 94.58%
# Accuracy of test dataset using model V0: 94.5773%
# 	 Accuracy on test dataset 5: 94.5773%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.5207%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.4028%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.7618%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.08%
# Maximum validation accuracy : 95.22%
# Accuracy of test dataset using model V0: 95.2187%
# 	 Accuracy on test dataset 5: 95.2187%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.2518%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.8356%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.7112%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.78%
# Maximum validation accuracy : 92.42%
# Accuracy of test dataset using model V0: 92.3615%
# 	 Accuracy on test dataset 5: 92.4198%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.7992%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.9398%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.2715%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.33%
# Maximum validation accuracy : 93.35%
# Accuracy of test dataset using model V0: 93.3528%
# 	 Accuracy on test dataset 5: 93.3528%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.9849%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.2569%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.9914%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.35%
# Maximum validation accuracy : 92.59%
# Accuracy of test dataset using model V0: 92.5948%
# 	 Accuracy on test dataset 5: 92.5948%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 88.8824%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.5880%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.1665%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.4%
# Maximum validation accuracy : 93.64%
# Accuracy of test dataset using model V0: 93.6443%
# 	 Accuracy on test dataset 5: 93.6443%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 90.1590%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.0949%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.0030%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.34%
# Maximum validation accuracy : 92.71%
# Accuracy of test dataset using model V0: 92.5948%
# 	 Accuracy on test dataset 5: 92.7114%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.5827%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.9028%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.3103%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.08%
# Maximum validation accuracy : 93.29%
# Accuracy of test dataset using model V0: 93.2945%
# 	 Accuracy on test dataset 5: 93.2945%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.2770%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.9630%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 89.7035%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.0%
# Maximum validation accuracy : 93.59%
# Accuracy of test dataset using model V0: 93.5860%
# 	 Accuracy on test dataset 5: 93.5860%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 89.5787%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.2454%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 88.8513%
# Best Accuracy: 89.2284 with mean=12.5, std=3.8

# %% [markdown]
# # MS(Mean squared)

# %%
feature_idx = 5

mean_list = [160, 200, 229, 260, 290]
std_list  = [200, 260, 304, 360, 420]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.36%
# Maximum validation accuracy : 86.53%
# Accuracy of test dataset using model V0: 86.3557%
# 	 Accuracy on test dataset 5: 86.5306%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 82.7434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.6690%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.5162%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.73%
# Maximum validation accuracy : 87.52%
# Accuracy of test dataset using model V0: 87.1720%
# 	 Accuracy on test dataset 5: 87.5219%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.1380%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.8588%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.9325%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.82%
# Maximum validation accuracy : 87.06%
# Accuracy of test dataset using model V0: 86.9971%
# 	 Accuracy on test dataset 5: 87.0554%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.2540%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.2523%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.5746%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.4%
# Maximum validation accuracy : 90.61%
# Accuracy of test dataset using model V0: 90.6122%
# 	 Accuracy on test dataset 5: 90.6122%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.2037%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.6134%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.0222%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.74%
# Maximum validation accuracy : 85.48%
# Accuracy of test dataset using model V0: 85.3644%
# 	 Accuracy on test dataset 5: 85.4810%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 80.8402%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.7546%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.6523%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.02%
# Maximum validation accuracy : 90.44%
# Accuracy of test dataset using model V0: 90.4373%
# 	 Accuracy on test dataset 5: 90.4373%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1785%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.8380%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.2557%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.54%
# Maximum validation accuracy : 90.26%
# Accuracy of test dataset using model V0: 90.2041%
# 	 Accuracy on test dataset 5: 90.2624%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8400%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.1551%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7654%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.74%
# Maximum validation accuracy : 91.6%
# Accuracy of test dataset using model V0: 91.4869%
# 	 Accuracy on test dataset 5: 91.6035%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7935%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.7731%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.8938%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.46%
# Maximum validation accuracy : 84.49%
# Accuracy of test dataset using model V0: 84.3732%
# 	 Accuracy on test dataset 5: 84.4898%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 81.4437%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 80.0810%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 81.3215%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.29%
# Maximum validation accuracy : 85.83%
# Accuracy of test dataset using model V0: 85.7726%
# 	 Accuracy on test dataset 5: 85.8309%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 82.7550%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.9977%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.7808%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.18%
# Maximum validation accuracy : 88.86%
# Accuracy of test dataset using model V0: 88.8047%
# 	 Accuracy on test dataset 5: 88.8630%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.1476%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.5764%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.2400%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.5%
# Maximum validation accuracy : 90.2%
# Accuracy of test dataset using model V0: 90.0875%
# 	 Accuracy on test dataset 5: 90.2041%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1785%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.3518%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.4268%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.73%
# Maximum validation accuracy : 90.03%
# Accuracy of test dataset using model V0: 90.0292%
# 	 Accuracy on test dataset 5: 90.0292%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.5770%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.8426%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.2400%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.83%
# Maximum validation accuracy : 91.31%
# Accuracy of test dataset using model V0: 91.1370%
# 	 Accuracy on test dataset 5: 91.3120%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.0160%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.1505%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5786%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.89%
# Maximum validation accuracy : 87.64%
# Accuracy of test dataset using model V0: 87.4636%
# 	 Accuracy on test dataset 5: 87.6385%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.6138%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.1366%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.0960%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.19%
# Maximum validation accuracy : 87.23%
# Accuracy of test dataset using model V0: 87.1720%
# 	 Accuracy on test dataset 5: 87.2303%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.2056%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.9120%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.6019%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.63%
# Maximum validation accuracy : 91.43%
# Accuracy of test dataset using model V0: 91.4286%
# 	 Accuracy on test dataset 5: 91.4286%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1205%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.6759%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1272%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.83%
# Maximum validation accuracy : 83.97%
# Accuracy of test dataset using model V0: 83.9650%
# 	 Accuracy on test dataset 5: 83.9650%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 82.4069%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 81.8519%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.5473%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.68%
# Maximum validation accuracy : 88.05%
# Accuracy of test dataset using model V0: 88.0466%
# 	 Accuracy on test dataset 5: 88.0466%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.9155%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.5370%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5319%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.43%
# Maximum validation accuracy : 89.15%
# Accuracy of test dataset using model V0: 89.1545%
# 	 Accuracy on test dataset 5: 89.1545%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.0412%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.4329%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.9872%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.17%
# Maximum validation accuracy : 89.1%
# Accuracy of test dataset using model V0: 89.0379%
# 	 Accuracy on test dataset 5: 89.0962%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.5538%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.7917%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7303%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.69%
# Maximum validation accuracy : 86.88%
# Accuracy of test dataset using model V0: 86.8805%
# 	 Accuracy on test dataset 5: 86.8805%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.3101%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.9815%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5435%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.42%
# Maximum validation accuracy : 88.92%
# Accuracy of test dataset using model V0: 88.9213%
# 	 Accuracy on test dataset 5: 88.9213%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.6118%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.5764%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.4618%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.89%
# Maximum validation accuracy : 87.64%
# Accuracy of test dataset using model V0: 87.6385%
# 	 Accuracy on test dataset 5: 87.6385%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.1844%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.9236%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.4151%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.76%
# Maximum validation accuracy : 87.81%
# Accuracy of test dataset using model V0: 87.7551%
# 	 Accuracy on test dataset 5: 87.8134%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.4958%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.2477%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.4852%
# Best Accuracy: 85.4240 with mean=200, std=200

# %% [markdown]
# # Root Mean Squared (RMS)

# %%
feature_idx = 6
mean_list_RMS = [10.0, 12.0, 13.8, 15.5, 17.0]
std_list_RMS  = [4.5, 5.5, 6.85, 8.0, 9.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.29%
# Maximum validation accuracy : 73.88%
# Accuracy of test dataset using model V0: 73.8775%
# 	 Accuracy on test dataset 5: 73.8775%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.32%
# Maximum validation accuracy : 74.23%
# Accuracy of test dataset using model V0: 74.2274%
# 	 Accuracy on test dataset 5: 74.2274%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.92%
# Maximum validation accuracy : 89.68%
# Accuracy of test dataset using model V0: 89.6793%
# 	 Accuracy on test dataset 5: 89.6793%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.9908%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.5602%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.9755%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.57%
# Maximum validation accuracy : 72.77%
# Accuracy of test dataset using model V0: 72.7697%
# 	 Accuracy on test dataset 5: 72.7697%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.41%
# Maximum validation accuracy : 72.54%
# Accuracy of test dataset using model V0: 72.5364%
# 	 Accuracy on test dataset 5: 72.5364%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.85%
# Maximum validation accuracy : 73.76%
# Accuracy of test dataset using model V0: 73.7609%
# 	 Accuracy on test dataset 5: 73.7609%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.63%
# Maximum validation accuracy : 90.79%
# Accuracy of test dataset using model V0: 90.4956%
# 	 Accuracy on test dataset 5: 90.7872%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3177%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.8542%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.4424%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.71%
# Maximum validation accuracy : 72.13%
# Accuracy of test dataset using model V0: 72.1283%
# 	 Accuracy on test dataset 5: 72.1283%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.8%
# Maximum validation accuracy : 72.89%
# Accuracy of test dataset using model V0: 72.8863%
# 	 Accuracy on test dataset 5: 72.8863%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.56%
# Maximum validation accuracy : 71.95%
# Accuracy of test dataset using model V0: 71.9534%
# 	 Accuracy on test dataset 5: 71.9534%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.08%
# Maximum validation accuracy : 73.53%
# Accuracy of test dataset using model V0: 73.5277%
# 	 Accuracy on test dataset 5: 73.5277%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.56%
# Maximum validation accuracy : 75.22%
# Accuracy of test dataset using model V0: 75.2187%
# 	 Accuracy on test dataset 5: 75.2187%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.28%
# Maximum validation accuracy : 86.06%
# Accuracy of test dataset using model V0: 86.0058%
# 	 Accuracy on test dataset 5: 86.0641%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.2985%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.0810%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8627%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.59%
# Maximum validation accuracy : 73.41%
# Accuracy of test dataset using model V0: 73.4111%
# 	 Accuracy on test dataset 5: 73.4111%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.53%
# Maximum validation accuracy : 74.29%
# Accuracy of test dataset using model V0: 74.2857%
# 	 Accuracy on test dataset 5: 74.2857%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.45%
# Maximum validation accuracy : 72.59%
# Accuracy of test dataset using model V0: 72.5947%
# 	 Accuracy on test dataset 5: 72.5947%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.28%
# Maximum validation accuracy : 74.23%
# Accuracy of test dataset using model V0: 74.2274%
# 	 Accuracy on test dataset 5: 74.2274%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.74%
# Maximum validation accuracy : 73.64%
# Accuracy of test dataset using model V0: 73.6443%
# 	 Accuracy on test dataset 5: 73.6443%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.83%
# Maximum validation accuracy : 73.64%
# Accuracy of test dataset using model V0: 73.6443%
# 	 Accuracy on test dataset 5: 73.6443%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.93%
# Maximum validation accuracy : 72.3%
# Accuracy of test dataset using model V0: 72.3032%
# 	 Accuracy on test dataset 5: 72.3032%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.48%
# Maximum validation accuracy : 73.47%
# Accuracy of test dataset using model V0: 73.0612%
# 	 Accuracy on test dataset 5: 73.4694%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.12%
# Maximum validation accuracy : 70.96%
# Accuracy of test dataset using model V0: 70.9621%
# 	 Accuracy on test dataset 5: 70.9621%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.11%
# Maximum validation accuracy : 73.94%
# Accuracy of test dataset using model V0: 73.9359%
# 	 Accuracy on test dataset 5: 73.9359%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.91%
# Maximum validation accuracy : 73.06%
# Accuracy of test dataset using model V0: 73.0612%
# 	 Accuracy on test dataset 5: 73.0612%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.5%
# Maximum validation accuracy : 73.24%
# Accuracy of test dataset using model V0: 73.2361%
# 	 Accuracy on test dataset 5: 73.2361%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Best Accuracy: 85.5088 with mean=160, std=304

# %% [markdown]
# # Log Detector (LD)

# %%
feature_idx = 8
mean_list_LogDet = [6.5, 8.0, 9.0, 10.0, 11.0]
std_list_LogDet  = [2.0, 2.5, 2.87, 3.3, 3.8]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.1%
# Maximum validation accuracy : 72.42%
# Accuracy of test dataset using model V0: 72.4198%
# 	 Accuracy on test dataset 5: 72.4198%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.25%
# Maximum validation accuracy : 73.82%
# Accuracy of test dataset using model V0: 73.8192%
# 	 Accuracy on test dataset 5: 73.8192%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.56%
# Maximum validation accuracy : 74.52%
# Accuracy of test dataset using model V0: 74.5189%
# 	 Accuracy on test dataset 5: 74.5189%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.39%
# Maximum validation accuracy : 72.42%
# Accuracy of test dataset using model V0: 72.4198%
# 	 Accuracy on test dataset 5: 72.4198%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.26%
# Maximum validation accuracy : 72.94%
# Accuracy of test dataset using model V0: 72.9446%
# 	 Accuracy on test dataset 5: 72.9446%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.93%
# Maximum validation accuracy : 72.24%
# Accuracy of test dataset using model V0: 72.2449%
# 	 Accuracy on test dataset 5: 72.2449%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.38%
# Maximum validation accuracy : 72.13%
# Accuracy of test dataset using model V0: 72.1283%
# 	 Accuracy on test dataset 5: 72.1283%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.75%
# Maximum validation accuracy : 85.01%
# Accuracy of test dataset using model V0: 84.9563%
# 	 Accuracy on test dataset 5: 85.0146%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 80.4688%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 80.7176%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.1504%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.77%
# Maximum validation accuracy : 73.12%
# Accuracy of test dataset using model V0: 73.1195%
# 	 Accuracy on test dataset 5: 73.1195%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.14%
# Maximum validation accuracy : 72.83%
# Accuracy of test dataset using model V0: 72.8280%
# 	 Accuracy on test dataset 5: 72.8280%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.5%
# Maximum validation accuracy : 89.27%
# Accuracy of test dataset using model V0: 89.0379%
# 	 Accuracy on test dataset 5: 89.2711%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.2753%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.2593%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.3724%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.84%
# Maximum validation accuracy : 73.76%
# Accuracy of test dataset using model V0: 73.7609%
# 	 Accuracy on test dataset 5: 73.7609%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.9%
# Maximum validation accuracy : 72.89%
# Accuracy of test dataset using model V0: 72.8863%
# 	 Accuracy on test dataset 5: 72.8863%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.33%
# Maximum validation accuracy : 73.94%
# Accuracy of test dataset using model V0: 73.9359%
# 	 Accuracy on test dataset 5: 73.9359%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.74%
# Maximum validation accuracy : 70.73%
# Accuracy of test dataset using model V0: 70.7289%
# 	 Accuracy on test dataset 5: 70.7289%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.92%
# Maximum validation accuracy : 73.41%
# Accuracy of test dataset using model V0: 73.4111%
# 	 Accuracy on test dataset 5: 73.4111%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.98%
# Maximum validation accuracy : 73.0%
# Accuracy of test dataset using model V0: 73.0029%
# 	 Accuracy on test dataset 5: 73.0029%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.1%
# Maximum validation accuracy : 89.27%
# Accuracy of test dataset using model V0: 89.2128%
# 	 Accuracy on test dataset 5: 89.2711%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.4145%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.0718%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8627%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.43%
# Maximum validation accuracy : 72.48%
# Accuracy of test dataset using model V0: 72.4781%
# 	 Accuracy on test dataset 5: 72.4781%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.98%
# Maximum validation accuracy : 72.89%
# Accuracy of test dataset using model V0: 72.8863%
# 	 Accuracy on test dataset 5: 72.8863%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.39%
# Maximum validation accuracy : 72.77%
# Accuracy of test dataset using model V0: 72.7697%
# 	 Accuracy on test dataset 5: 72.7697%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.65%
# Maximum validation accuracy : 74.64%
# Accuracy of test dataset using model V0: 74.6356%
# 	 Accuracy on test dataset 5: 74.6356%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.29%
# Maximum validation accuracy : 73.47%
# Accuracy of test dataset using model V0: 73.4694%
# 	 Accuracy on test dataset 5: 73.4694%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.2%
# Maximum validation accuracy : 74.4%
# Accuracy of test dataset using model V0: 74.4023%
# 	 Accuracy on test dataset 5: 74.4023%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.87%
# Maximum validation accuracy : 72.94%
# Accuracy of test dataset using model V0: 72.9446%
# 	 Accuracy on test dataset 5: 72.9446%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Best Accuracy: 85.7830 with mean=260, std=304

# %% [markdown]
# # DASDV (Difference Absolute Standard Deviation Value)

# %%
feature_idx = 9
mean_list_DASDV = [2.2, 2.6, 3.0, 3.4, 3.8]
std_list_DASDV  = [0.6, 0.75, 0.87, 1.0, 1.1]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.31%
# Maximum validation accuracy : 72.83%
# Accuracy of test dataset using model V0: 72.8280%
# 	 Accuracy on test dataset 5: 72.8280%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.48%
# Maximum validation accuracy : 72.24%
# Accuracy of test dataset using model V0: 72.2449%
# 	 Accuracy on test dataset 5: 72.2449%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.21%
# Maximum validation accuracy : 71.43%
# Accuracy of test dataset using model V0: 71.4286%
# 	 Accuracy on test dataset 5: 71.4286%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.46%
# Maximum validation accuracy : 74.23%
# Accuracy of test dataset using model V0: 74.2274%
# 	 Accuracy on test dataset 5: 74.2274%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.62%
# Maximum validation accuracy : 71.49%
# Accuracy of test dataset using model V0: 71.4869%
# 	 Accuracy on test dataset 5: 71.4869%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.98%
# Maximum validation accuracy : 72.3%
# Accuracy of test dataset using model V0: 72.3032%
# 	 Accuracy on test dataset 5: 72.3032%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.1%
# Maximum validation accuracy : 73.7%
# Accuracy of test dataset using model V0: 73.7026%
# 	 Accuracy on test dataset 5: 73.7026%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.58%
# Maximum validation accuracy : 72.07%
# Accuracy of test dataset using model V0: 72.0700%
# 	 Accuracy on test dataset 5: 72.0700%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.57%
# Maximum validation accuracy : 71.95%
# Accuracy of test dataset using model V0: 71.9534%
# 	 Accuracy on test dataset 5: 71.9534%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.58%
# Maximum validation accuracy : 73.47%
# Accuracy of test dataset using model V0: 73.4694%
# 	 Accuracy on test dataset 5: 73.4694%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.48%
# Maximum validation accuracy : 71.55%
# Accuracy of test dataset using model V0: 71.5452%
# 	 Accuracy on test dataset 5: 71.5452%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.96%
# Maximum validation accuracy : 71.08%
# Accuracy of test dataset using model V0: 71.0787%
# 	 Accuracy on test dataset 5: 71.0787%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.97%
# Maximum validation accuracy : 71.43%
# Accuracy of test dataset using model V0: 71.4286%
# 	 Accuracy on test dataset 5: 71.4286%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.82%
# Maximum validation accuracy : 74.17%
# Accuracy of test dataset using model V0: 74.1691%
# 	 Accuracy on test dataset 5: 74.1691%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.41%
# Maximum validation accuracy : 73.64%
# Accuracy of test dataset using model V0: 73.6443%
# 	 Accuracy on test dataset 5: 73.6443%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.6%
# Maximum validation accuracy : 72.71%
# Accuracy of test dataset using model V0: 72.7114%
# 	 Accuracy on test dataset 5: 72.7114%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.78%
# Maximum validation accuracy : 74.23%
# Accuracy of test dataset using model V0: 74.2274%
# 	 Accuracy on test dataset 5: 74.2274%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.38%
# Maximum validation accuracy : 73.0%
# Accuracy of test dataset using model V0: 73.0029%
# 	 Accuracy on test dataset 5: 73.0029%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.56%
# Maximum validation accuracy : 72.48%
# Accuracy of test dataset using model V0: 72.4781%
# 	 Accuracy on test dataset 5: 72.4781%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.94%
# Maximum validation accuracy : 71.84%
# Accuracy of test dataset using model V0: 71.8367%
# 	 Accuracy on test dataset 5: 71.8367%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.47%
# Maximum validation accuracy : 73.94%
# Accuracy of test dataset using model V0: 73.9359%
# 	 Accuracy on test dataset 5: 73.9359%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.45%
# Maximum validation accuracy : 72.13%
# Accuracy of test dataset using model V0: 72.1283%
# 	 Accuracy on test dataset 5: 72.1283%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.08%
# Maximum validation accuracy : 71.72%
# Accuracy of test dataset using model V0: 71.7201%
# 	 Accuracy on test dataset 5: 71.7201%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.16%
# Maximum validation accuracy : 72.48%
# Accuracy of test dataset using model V0: 72.4781%
# 	 Accuracy on test dataset 5: 72.4781%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.06%
# Maximum validation accuracy : 72.94%
# Accuracy of test dataset using model V0: 72.9446%
# 	 Accuracy on test dataset 5: 72.9446%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Best Accuracy: 73.8675 with mean=160, std=200

# %% [markdown]
# # MFL (Maximum Fractal Length)

# %%
feature_idx = 10
mean_list_MFL = [1.0, 1.3, 1.5, 1.7, 2.0]
std_list_MFL  = [0.12, 0.17, 0.21, 0.25, 0.30]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.87%
# Maximum validation accuracy : 72.36%
# Accuracy of test dataset using model V0: 72.3615%
# 	 Accuracy on test dataset 5: 72.3615%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.49%
# Maximum validation accuracy : 73.82%
# Accuracy of test dataset using model V0: 73.8192%
# 	 Accuracy on test dataset 5: 73.8192%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.53%
# Maximum validation accuracy : 73.82%
# Accuracy of test dataset using model V0: 73.8192%
# 	 Accuracy on test dataset 5: 73.8192%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.25%
# Maximum validation accuracy : 73.76%
# Accuracy of test dataset using model V0: 73.7609%
# 	 Accuracy on test dataset 5: 73.7609%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.16%
# Maximum validation accuracy : 73.7%
# Accuracy of test dataset using model V0: 73.7026%
# 	 Accuracy on test dataset 5: 73.7026%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.69%
# Maximum validation accuracy : 74.81%
# Accuracy of test dataset using model V0: 74.8105%
# 	 Accuracy on test dataset 5: 74.8105%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.86%
# Maximum validation accuracy : 74.64%
# Accuracy of test dataset using model V0: 74.6356%
# 	 Accuracy on test dataset 5: 74.6356%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 74.5%
# Maximum validation accuracy : 72.89%
# Accuracy of test dataset using model V0: 72.8863%
# 	 Accuracy on test dataset 5: 72.8863%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.41%
# Maximum validation accuracy : 75.8%
# Accuracy of test dataset using model V0: 75.8017%
# 	 Accuracy on test dataset 5: 75.8017%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.13%
# Maximum validation accuracy : 71.72%
# Accuracy of test dataset using model V0: 71.7201%
# 	 Accuracy on test dataset 5: 71.7201%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.15%
# Maximum validation accuracy : 74.11%
# Accuracy of test dataset using model V0: 74.1108%
# 	 Accuracy on test dataset 5: 74.1108%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 72.96%
# Maximum validation accuracy : 74.69%
# Accuracy of test dataset using model V0: 74.6939%
# 	 Accuracy on test dataset 5: 74.6939%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 74.62%
# Maximum validation accuracy : 73.41%
# Accuracy of test dataset using model V0: 73.4111%
# 	 Accuracy on test dataset 5: 73.4111%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.8%
# Maximum validation accuracy : 75.1%
# Accuracy of test dataset using model V0: 75.1020%
# 	 Accuracy on test dataset 5: 75.1020%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.09%
# Maximum validation accuracy : 73.82%
# Accuracy of test dataset using model V0: 73.8192%
# 	 Accuracy on test dataset 5: 73.8192%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.03%
# Maximum validation accuracy : 74.4%
# Accuracy of test dataset using model V0: 74.4023%
# 	 Accuracy on test dataset 5: 74.4023%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.5%
# Maximum validation accuracy : 72.83%
# Accuracy of test dataset using model V0: 72.8280%
# 	 Accuracy on test dataset 5: 72.8280%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.83%
# Maximum validation accuracy : 73.94%
# Accuracy of test dataset using model V0: 73.9359%
# 	 Accuracy on test dataset 5: 73.9359%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.38%
# Maximum validation accuracy : 73.12%
# Accuracy of test dataset using model V0: 73.1195%
# 	 Accuracy on test dataset 5: 73.1195%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.7%
# Maximum validation accuracy : 73.53%
# Accuracy of test dataset using model V0: 73.5277%
# 	 Accuracy on test dataset 5: 73.5277%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 74.5%
# Maximum validation accuracy : 72.77%
# Accuracy of test dataset using model V0: 72.7697%
# 	 Accuracy on test dataset 5: 72.7697%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.62%
# Maximum validation accuracy : 73.7%
# Accuracy of test dataset using model V0: 73.7026%
# 	 Accuracy on test dataset 5: 73.7026%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.25%
# Maximum validation accuracy : 74.05%
# Accuracy of test dataset using model V0: 74.0525%
# 	 Accuracy on test dataset 5: 74.0525%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.48%
# Maximum validation accuracy : 72.48%
# Accuracy of test dataset using model V0: 72.4781%
# 	 Accuracy on test dataset 5: 72.4781%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.44%
# Maximum validation accuracy : 73.76%
# Accuracy of test dataset using model V0: 73.7609%
# 	 Accuracy on test dataset 5: 73.7609%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Best Accuracy: 73.8675 with mean=160, std=200

# %% [markdown]
# # WMS

# %%
feature_idx = 13
mean_list_WMS = [2.0, 2.4, 2.8, 3.2, 3.6]
std_list_WMS  = [0.8, 1.0, 1.12, 1.3, 1.5]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.79%
# Maximum validation accuracy : 72.71%
# Accuracy of test dataset using model V0: 72.7114%
# 	 Accuracy on test dataset 5: 72.7114%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.91%
# Maximum validation accuracy : 72.65%
# Accuracy of test dataset using model V0: 72.6531%
# 	 Accuracy on test dataset 5: 72.6531%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.07%
# Maximum validation accuracy : 80.64%
# Accuracy of test dataset using model V0: 80.5248%
# 	 Accuracy on test dataset 5: 80.6414%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.9022%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.7153%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.3369%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.58%
# Maximum validation accuracy : 81.87%
# Accuracy of test dataset using model V0: 81.2828%
# 	 Accuracy on test dataset 5: 81.8659%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.9138%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 79.4097%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 80.3642%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.98%
# Maximum validation accuracy : 73.64%
# Accuracy of test dataset using model V0: 73.6443%
# 	 Accuracy on test dataset 5: 73.6443%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.08%
# Maximum validation accuracy : 75.1%
# Accuracy of test dataset using model V0: 75.1020%
# 	 Accuracy on test dataset 5: 75.1020%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.59%
# Maximum validation accuracy : 73.88%
# Accuracy of test dataset using model V0: 73.8775%
# 	 Accuracy on test dataset 5: 73.8775%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.93%
# Maximum validation accuracy : 73.29%
# Accuracy of test dataset using model V0: 73.2945%
# 	 Accuracy on test dataset 5: 73.2945%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.3%
# Maximum validation accuracy : 73.06%
# Accuracy of test dataset using model V0: 73.0612%
# 	 Accuracy on test dataset 5: 73.0612%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.64%
# Maximum validation accuracy : 73.24%
# Accuracy of test dataset using model V0: 73.2361%
# 	 Accuracy on test dataset 5: 73.2361%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.82%
# Maximum validation accuracy : 73.41%
# Accuracy of test dataset using model V0: 73.4111%
# 	 Accuracy on test dataset 5: 73.4111%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.44%
# Maximum validation accuracy : 71.9%
# Accuracy of test dataset using model V0: 71.8950%
# 	 Accuracy on test dataset 5: 71.8950%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.64%
# Maximum validation accuracy : 71.55%
# Accuracy of test dataset using model V0: 71.5452%
# 	 Accuracy on test dataset 5: 71.5452%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.97%
# Maximum validation accuracy : 74.52%
# Accuracy of test dataset using model V0: 74.5189%
# 	 Accuracy on test dataset 5: 74.5189%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.04%
# Maximum validation accuracy : 73.0%
# Accuracy of test dataset using model V0: 73.0029%
# 	 Accuracy on test dataset 5: 73.0029%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.77%
# Maximum validation accuracy : 73.0%
# Accuracy of test dataset using model V0: 73.0029%
# 	 Accuracy on test dataset 5: 73.0029%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.32%
# Maximum validation accuracy : 73.0%
# Accuracy of test dataset using model V0: 73.0029%
# 	 Accuracy on test dataset 5: 73.0029%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.78%
# Maximum validation accuracy : 72.59%
# Accuracy of test dataset using model V0: 72.5947%
# 	 Accuracy on test dataset 5: 72.5947%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.4%
# Maximum validation accuracy : 71.9%
# Accuracy of test dataset using model V0: 71.8950%
# 	 Accuracy on test dataset 5: 71.8950%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.45%
# Maximum validation accuracy : 72.83%
# Accuracy of test dataset using model V0: 72.8280%
# 	 Accuracy on test dataset 5: 72.8280%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.52%
# Maximum validation accuracy : 72.59%
# Accuracy of test dataset using model V0: 72.5947%
# 	 Accuracy on test dataset 5: 72.5947%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.45%
# Maximum validation accuracy : 73.88%
# Accuracy of test dataset using model V0: 73.8775%
# 	 Accuracy on test dataset 5: 73.8775%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.28%
# Maximum validation accuracy : 72.71%
# Accuracy of test dataset using model V0: 72.7114%
# 	 Accuracy on test dataset 5: 72.7114%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.21%
# Maximum validation accuracy : 73.18%
# Accuracy of test dataset using model V0: 73.1778%
# 	 Accuracy on test dataset 5: 73.1778%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Dataset 1/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34477, 4, 1) (34477,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.28%
# Maximum validation accuracy : 73.7%
# Accuracy of test dataset using model V0: 73.7026%
# 	 Accuracy on test dataset 5: 73.7026%
# Dataset 6/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 73.3434%
# Dataset 7/8 - Session Exp_2025-07-16-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 74.4907%
# Dataset 8/8 - Session Exp_2025-07-16-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 73.7684%
# Best Accuracy: 79.5626 with mean=160, std=360

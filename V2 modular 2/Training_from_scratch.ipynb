# %%
import Training_from_scratch
import config
import numpy as np

prog_trainer = Training_from_scratch.ProgressiveTrainer(config, subject="Hunmin")
Init_acc_all, Prev_acc_all, Trained_acc_all = prog_trainer.run(plot_learning_curve=False)
# Out:
# ===========================================
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.56%
# Maximum validation accuracy : 92.88%
#
# ===========================================
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.76%
# Maximum validation accuracy : 88.24%
#
# ===========================================
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.56%
# Maximum validation accuracy : 91.64%
#
# ===========================================
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.0%
# Maximum validation accuracy : 92.08%
#
# ===========================================
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.02%
# Maximum validation accuracy : 92.45%
#
# ===========================================
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.21%
# Maximum validation accuracy : 86.14%
#
# ===========================================
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.61%
# Maximum validation accuracy : 93.64%
#
# ===========================================
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.46%
# Maximum validation accuracy : 86.36%
#
# ===========================================
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.1%
# Maximum validation accuracy : 91.07%
#
# ===========================================
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.06%
# Maximum validation accuracy : 91.97%
#
# ===========================================
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.93%
# Maximum validation accuracy : 93.69%
#
# ===========================================
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.78%
# Maximum validation accuracy : 91.59%
#
# ===========================================
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.48%
# Maximum validation accuracy : 92.65%
#
# ===========================================
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.83%
# Maximum validation accuracy : 92.28%
#
# ===========================================
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.8%
# Maximum validation accuracy : 93.59%
#
# ===========================================
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.12%
# Maximum validation accuracy : 93.18%
#
# ===========================================
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.84%
# Maximum validation accuracy : 92.14%
#
# ===========================================
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.83%
# Maximum validation accuracy : 91.98%
#
# ===========================================
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.91%
# Maximum validation accuracy : 93.59%
#
# ===========================================
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.1%
# Maximum validation accuracy : 93.35%
#
# ===========================================
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.09%
# Maximum validation accuracy : 91.61%
#
# ===========================================
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.38%
# Maximum validation accuracy : 93.71%
#
# ===========================================
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.55%
# Maximum validation accuracy : 90.88%
#
# ===========================================
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.62%
# Maximum validation accuracy : 93.84%
#
# ===========================================
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ===========================================
# There is more than one dataset - check
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.01%
# Maximum validation accuracy : 96.41%
#
# ===========================================
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.32%
# Maximum validation accuracy : 90.58%
#
# ===========================================
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.44%
# Maximum validation accuracy : 87.75%
#
# ===========================================
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.62%
# Maximum validation accuracy : 94.25%
#
# ===========================================
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.3%
# Maximum validation accuracy : 94.03%
#
# ===========================================
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.24%
# Maximum validation accuracy : 93.63%

# %%
#baseline1_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results.csv'
baseline1_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_1data.csv'
baseline2_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_10data.csv'
baseline3_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_14data.csv'
baseline4_csv_path = 'C:/Users/hml76/PycharmProjects/Tremor_project_local/NCI_mindforce/github/Results/Baseline_results_train_with_18data.csv'
baselines = [baseline1_csv_path, baseline2_csv_path,  baseline3_csv_path,  baseline4_csv_path]
baseline_K = ['1', '10', '14', '18']

prog_trainer.plot_results(baselines, baseline_K)

for idx, x in enumerate([Init_acc_all, Prev_acc_all, Trained_acc_all]):
    if idx==0:
        print(f"Average of acc without training anything (should be random): {np.mean(x)*100:.2f}%")
    elif idx==1:
        print(f"Average of acc using previous test data after training: {np.mean(x)*100:.2f}%")
    elif idx==2:
        print(f"Average of acc using current test data after training: {np.mean(x)*100:.2f}%")
# Out:
# Average of acc without training anything (should be random): 10.01%
# Average of acc using previous test data after training: 92.04%
# Average of acc using current test data after training: 80.42%

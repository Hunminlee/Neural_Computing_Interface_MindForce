# %%
import Test_without_Training
import config

if __name__ == "__main__":
    for K in [1, 10, 14, 18]:
        trainer = Test_without_Training.TremorModelTrainer(config, subject="Hunmin")
        trainer.run_all_sessions_training_K_data(K)
        df = trainer.save_results(f'../Results/Baseline_results_train_with_{K}data.csv')
# Out:
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 91.73%
# Maximum validation accuracy : 93.02%
# Accuracy of test dataset using model V0: 91.8605%
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.8412%
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.5436%
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.7812%
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 71.0810%
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.4366%
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.7881%
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 74.1980%
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 73.6372%
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.7505%
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 69.5001%
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 73.0252%
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.6983%
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.6396%
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.0675%
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.4830%
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.6241%
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.5001%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.2068%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.3623%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.5121%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.2600%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.3581%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 88.6690%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.6226%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 78.9070%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.1995%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.9368%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.9789%
# Results saved to ../Results/Baseline_results_train_with_1data.csv
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,)
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,)
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,)
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,)
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,)
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,)
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,)
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,)
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,)
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.82%
# Maximum validation accuracy : 90.13%
# Accuracy of test dataset using model V0: 89.8942%
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.8400%
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6665%
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5486%
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.7947%
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4228%
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.5974%
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.6800%
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.0429%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.0588%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5940%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.9218%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.6179%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.7451%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 90.9606%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.9716%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.1643%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.7749%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.5093%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.8336%
# Results saved to ../Results/Baseline_results_train_with_10data.csv
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,)
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,)
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,)
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,)
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,)
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,)
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,)
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,)
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,)
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,)
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# (101296, 4, 14, 1) (101296,)
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# (109756, 4, 14, 1) (109756,)
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# (118143, 4, 14, 1) (118143,)
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.7%
# Maximum validation accuracy : 91.02%
# Accuracy of test dataset using model V0: 91.0235%
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2359%
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.9000%
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6566%
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.7863%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.2689%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9893%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.6294%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6416%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5017%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 91.3079%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.8669%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.3263%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.4142%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.8184%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.3843%
# Results saved to ../Results/Baseline_results_train_with_14data.csv
# Dataset 1/30 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,)
# Dataset 2/30 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,)
# Dataset 3/30 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,)
# Dataset 4/30 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,)
# Dataset 5/30 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,)
# Dataset 6/30 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,)
# Dataset 7/30 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,)
# Dataset 8/30 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,)
# Dataset 9/30 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,)
# Dataset 10/30 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,)
# Dataset 11/30 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,)
# Dataset 12/30 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# (101296, 4, 14, 1) (101296,)
# Dataset 13/30 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# (109756, 4, 14, 1) (109756,)
# Dataset 14/30 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# (118143, 4, 14, 1) (118143,)
# Dataset 15/30 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# (126634, 4, 14, 1) (126634,)
# Dataset 16/30 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# (135110, 4, 14, 1) (135110,)
# Dataset 17/30 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# (143628, 4, 14, 1) (143628,)
# Dataset 18/30 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# (151851, 4, 14, 1) (151851,)
# Dataset 19/30 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 90.57%
# Maximum validation accuracy : 91.59%
# Accuracy of test dataset using model V0: 91.4547%
# Dataset 20/30 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.7630%
# Dataset 21/30 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.8729%
# Dataset 22/30 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.9310%
# Dataset 23/30 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6300%
# Dataset 24/30 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4983%
# Dataset 25/30 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# There is more than one dataset - check
# Accuracy on unseen dataset: 91.9676%
# Dataset 26/30 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2392%
# Dataset 27/30 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.9079%
# Dataset 28/30 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.1710%
# Dataset 29/30 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.8764%
# Dataset 30/30 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.3333%
# Results saved to ../Results/Baseline_results_train_with_18data.csv

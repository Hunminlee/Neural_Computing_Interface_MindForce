# %% [markdown]
# # Search good hyper-parameters in Normalization
# - It seems finding a good value helps a lot in performance

# %%
import sys
sys.path.append("../Share")
import config, utils, baseline, Trainer, Processing_same_with_MATLAB
import os
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

baseline_K_val = [18] #Train ~18 session data, test with 19~
K = baseline_K_val[0]

feature_names = ['Zero Crossing (ZC)', 'Slope Sign Changes (SSC)', 'Waveform Length (WL)', 'WAMP', 'Mean Absolute Value (MAV)', 'Mean Square (MS)', 'Root Mean Square (RMS)',
                 'v-order 3 (V3)', 'log detector (LD)', 'difference absolute standard deviation value (DASDV)', 'maximum fractal length (MFL)', 'myopulse percentage rate (MPR)',
                 'mean absolute value slope (MAVS)', 'weighted mean absolute (WMS)',
                 'Cepstrum Coefficient 1', 'Cepstrum Coefficient 2', 'Cepstrum Coefficient 3', 'Cepstrum Coefficient Average', 'DWTC1', 'DWTC2',
                 'DWTPC1', 'DWTPC2', 'DWTPC3']


feature_idx = range(0,len(feature_names))

fs = round(10e6 / 2048)  # 4883 Hz
lower_cutoff = 100
upper_cutoff = 600
filter_b, filter_a = Processing_same_with_MATLAB.cheby2(4, 30, [lower_cutoff / (fs/2), upper_cutoff / (fs/2)], btype='bandpass')

feat_mean_1ch = np.array([0.1, 0.1, 2.5, 0.0, 11.0, 229.0, 13.8, -11.0, 9.0, 3.0, 1.5, 0.0, 0.0, 2.8])
feat_std_1ch = np.array([0.02, 0.05, 0.65, 0.02, 4.43, 303.9, 6.85, 12.18, 2.87, 0.87, 0.21, 0.04, 6.68, 1.12])
feat_mean = np.tile(feat_mean_1ch, (4, 1))
feat_std = np.tile(feat_std_1ch, (4, 1))

data_files = config.dataset_sub_H
default_path = config.default_path_sub_H

# %% [markdown]
# # Without Normalization

# %%
Normalization_TF = False ############################ important!!!!


extractor = Processing_same_with_MATLAB.EMGFeatureExtractor(feat_mean, feat_std, filter_b, filter_a, Norm_bool=Normalization_TF)
X_train_all, y_train_all, X_test_all, y_test_all = [], [], [], []

for idx, session_info in enumerate(data_files):
    print(f"Dataset {idx + 1}/{len(data_files)} - Session {session_info}\n{'='*40}")
    path = os.path.join(default_path, f'{session_info}raw/')
    features, class_labels = [], []
    for c_idx, c in enumerate(config.classes_5):
        raw_data = os.listdir(path+c)
        mat = scipy.io.loadmat(path+c+raw_data[0])
        extractor.buffer = mat['Data_ADC']
        class_labels.append(mat['Data_Cls'].reshape(-1))
        features_per_cls = extractor.extract_features(num_feature_set=23)
        features_per_cls = np.transpose(features_per_cls, (2, 0, 1))  # shape: (1729, 4, 14)
        features.append(features_per_cls)
        #print(features_per_cls.shape, mat['Data_Cls'].reshape(-1).shape)

    X = np.concatenate(features, axis=0)
    y = np.concatenate(class_labels, axis=0)
    if X.shape[0] != y.shape[-1]:
        print(f"Incorrect shape between features and Class: {X.shape} and {y.shape}, {session_info}")
        break

    if idx < K:
        X_train, y_train, _, _,  = utils.split_data(X, y, ratio=1)
        X_train_all.append(X_train)
        y_train_all.append(y_train)

    else:
        X_test, y_test, _, _ = utils.split_data(X, y, ratio=1)
        X_test_all.append(X_test)
        y_test_all.append(y_test)

X_train_stacked = np.concatenate(X_train_all, axis=0)
y_train_stacked = np.concatenate(y_train_all, axis=0)
X_test_stacked = np.concatenate(X_test_all, axis=0)
y_test_stacked = np.concatenate(y_test_all, axis=0)
# Out:
# Dataset 1/58 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/58 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/58 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/58 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/58 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/58 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/58 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/58 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/58 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/58 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/58 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/58 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/58 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/58 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/58 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/58 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/58 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/58 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/58 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/58 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/58 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/58 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/58 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 24/58 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 25/58 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 26/58 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 27/58 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 28/58 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 29/58 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 30/58 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 31/58 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 32/58 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 33/58 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 34/58 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 35/58 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 36/58 - Session Exp_2025-07-02-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 37/58 - Session Exp_2025-07-02-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 38/58 - Session Exp_2025-07-02-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 39/58 - Session Exp_2025-07-03-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 40/58 - Session Exp_2025-07-03-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 41/58 - Session Exp_2025-07-03-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 42/58 - Session Exp_2025-07-03-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 43/58 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 44/58 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 45/58 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 46/58 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 47/58 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 48/58 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 49/58 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 50/58 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 51/58 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 52/58 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 53/58 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 54/58 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 55/58 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 56/58 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 57/58 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 58/58 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================

# %%
trainer = Trainer.TremorModelTrainer(config, subject="Hunmin")
feature_acc = []

for idx, f in enumerate(feature_idx):
    X_train = X_train_stacked[:, :, f:f+1, :]
    X_test = X_test_stacked[:, :, f:f+1, :]

    X_train = np.squeeze(X_train, axis=-1)  # Remove last dim → (100000, 4, 1)
    X_test = np.squeeze(X_test, axis=-1)

    print(X_train.shape, X_test.shape)

    acc, _ = trainer.train_multiple_dataset(X_train, y_train_stacked, X_test, y_test_stacked)
    feature_acc.append(acc)
    print("\n")
# Out:
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 71.09%
# Maximum validation accuracy : 81.45%
# Accuracy of test dataset using model V0: 81.0281%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 73.01%
# Maximum validation accuracy : 82.41%
# Accuracy of test dataset using model V0: 82.3839%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.64%
# Maximum validation accuracy : 88.59%
# Accuracy of test dataset using model V0: 88.5313%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 64.52%
# Maximum validation accuracy : 74.67%
# Accuracy of test dataset using model V0: 74.6699%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.77%
# Maximum validation accuracy : 88.71%
# Accuracy of test dataset using model V0: 88.1533%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.17%
# Maximum validation accuracy : 88.52%
# Accuracy of test dataset using model V0: 88.2847%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.59%
# Maximum validation accuracy : 88.86%
# Accuracy of test dataset using model V0: 88.1076%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 78.06%
# Maximum validation accuracy : 84.81%
# Accuracy of test dataset using model V0: 84.7563%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.08%
# Maximum validation accuracy : 88.12%
# Accuracy of test dataset using model V0: 88.0276%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.47%
# Maximum validation accuracy : 88.53%
# Accuracy of test dataset using model V0: 88.4002%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.5%
# Maximum validation accuracy : 88.92%
# Accuracy of test dataset using model V0: 88.9152%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 61.03%
# Maximum validation accuracy : 75.11%
# Accuracy of test dataset using model V0: 74.8699%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 67.64%
# Maximum validation accuracy : 81.48%
# Accuracy of test dataset using model V0: 81.4431%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.98%
# Maximum validation accuracy : 88.73%
# Accuracy of test dataset using model V0: 88.7049%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 69.1%
# Maximum validation accuracy : 80.88%
# Accuracy of test dataset using model V0: 80.8333%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 65.8%
# Maximum validation accuracy : 78.78%
# Accuracy of test dataset using model V0: 78.7432%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 60.99%
# Maximum validation accuracy : 75.62%
# Accuracy of test dataset using model V0: 75.5376%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 65.34%
# Maximum validation accuracy : 78.39%
# Accuracy of test dataset using model V0: 78.0726%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 69.29%
# Maximum validation accuracy : 80.61%
# Accuracy of test dataset using model V0: 80.5570%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 62.77%
# Maximum validation accuracy : 76.31%
# Accuracy of test dataset using model V0: 75.5176%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 69.0%
# Maximum validation accuracy : 80.35%
# Accuracy of test dataset using model V0: 80.3337%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 66.47%
# Maximum validation accuracy : 78.74%
# Accuracy of test dataset using model V0: 78.6397%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 64.67%
# Maximum validation accuracy : 77.53%
# Accuracy of test dataset using model V0: 77.4616%

# %%
feature_names_idx = feature_names #+ ['All features']

plt.figure(figsize=(12, 6))
bars = plt.bar(range(len(feature_acc)), feature_acc, color='skyblue')
plt.xticks(range(len(feature_acc)), feature_names_idx, rotation=45, ha='right')
plt.ylabel('Accuracy')
plt.title('Feature-wise Accuracy')
plt.tight_layout()

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.005, f'{yval:.2f}', ha='center', va='bottom', fontsize=9)
plt.show()

# %% [markdown]
# - 이상하게 각자 feature test를 하면 Normalization 하지 않은 것도 88%정도 나왔음
# - 그래서 아래 Normalization 한것도 돌리고 있고 만약 성능이 같으면 ... 흠... 코드는 좋아보이는데
# -

# %%
여기 성능 그대로 normalization 안한거니깐 성능 안좋으면 여기서 바로 normalization test 할수 있음


features = (features - self.feat_mean[:, :, np.newaxis]) / self.feat_std[:, :, np.newaxis]

# %% [markdown]
# # With Normalization

# %%
Normalization_TF = True ############################ important!!!!


extractor = Processing_same_with_MATLAB.EMGFeatureExtractor(feat_mean, feat_std, filter_b, filter_a, Norm_bool=Normalization_TF)
X_train_all, y_train_all, X_test_all, y_test_all = [], [], [], []

for idx, session_info in enumerate(data_files):
    print(f"Dataset {idx + 1}/{len(data_files)} - Session {session_info}\n{'='*40}")
    path = os.path.join(default_path, f'{session_info}raw/')
    features, class_labels = [], []
    for c_idx, c in enumerate(config.classes_5):
        raw_data = os.listdir(path+c)
        mat = scipy.io.loadmat(path+c+raw_data[0])
        extractor.buffer = mat['Data_ADC']
        class_labels.append(mat['Data_Cls'].reshape(-1))
        features_per_cls = extractor.extract_features(num_feature_set=23)
        features_per_cls = np.transpose(features_per_cls, (2, 0, 1))  # shape: (1729, 4, 14)
        features.append(features_per_cls)
        #print(features_per_cls.shape, mat['Data_Cls'].reshape(-1).shape)

    X = np.concatenate(features, axis=0)
    y = np.concatenate(class_labels, axis=0)
    if X.shape[0] != y.shape[-1]:
        print(f"Incorrect shape between features and Class: {X.shape} and {y.shape}, {session_info}")
        break

    if idx < K:
        X_train, y_train, _, _,  = utils.split_data(X, y, ratio=1)
        X_train_all.append(X_train)
        y_train_all.append(y_train)

    else:
        X_test, y_test, _, _ = utils.split_data(X, y, ratio=1)
        X_test_all.append(X_test)
        y_test_all.append(y_test)

X_train_stacked_Norm = np.concatenate(X_train_all, axis=0)
y_train_stacked_Norm = np.concatenate(y_train_all, axis=0)
X_test_stacked_Norm = np.concatenate(X_test_all, axis=0)
y_test_stacked_Norm = np.concatenate(y_test_all, axis=0)
# Out:
# Dataset 1/58 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/58 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/58 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/58 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/58 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/58 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/58 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/58 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/58 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/58 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/58 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/58 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/58 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/58 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/58 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/58 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/58 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/58 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/58 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/58 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/58 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/58 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/58 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 24/58 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 25/58 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 26/58 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 27/58 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 28/58 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 29/58 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 30/58 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 31/58 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 32/58 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 33/58 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 34/58 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 35/58 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 36/58 - Session Exp_2025-07-02-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 37/58 - Session Exp_2025-07-02-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 38/58 - Session Exp_2025-07-02-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 39/58 - Session Exp_2025-07-03-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 40/58 - Session Exp_2025-07-03-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 41/58 - Session Exp_2025-07-03-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 42/58 - Session Exp_2025-07-03-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 43/58 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 44/58 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 45/58 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 46/58 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 47/58 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 48/58 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 49/58 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 50/58 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 51/58 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 52/58 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 53/58 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 54/58 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 55/58 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 56/58 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 57/58 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 58/58 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================

# %%
trainer = Trainer.TremorModelTrainer(config, subject="Hunmin")
feature_acc = []

for idx, f in enumerate(feature_idx):
    X_train = X_train_stacked_Norm[:, :, f:f+1, :]
    X_test = X_test_stacked_Norm[:, :, f:f+1, :]

    X_train = np.squeeze(X_train, axis=-1)  # Remove last dim → (100000, 4, 1)
    X_test = np.squeeze(X_test, axis=-1)

    print(X_train.shape, X_test.shape)

    acc, _ = trainer.train_multiple_dataset(X_train, y_train_stacked_Norm, X_test, y_test_stacked_Norm)
    feature_acc.append(acc)
    print("\n")
# Out:
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 71.32%
# Maximum validation accuracy : 81.45%
# Accuracy of test dataset using model V0: 81.4123%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 73.05%
# Maximum validation accuracy : 82.41%
# Accuracy of test dataset using model V0: 82.3964%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.78%
# Maximum validation accuracy : 88.64%
# Accuracy of test dataset using model V0: 88.3920%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 64.54%
# Maximum validation accuracy : 76.38%
# Accuracy of test dataset using model V0: 76.3394%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.7%
# Maximum validation accuracy : 88.63%
# Accuracy of test dataset using model V0: 88.5031%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.27%
# Maximum validation accuracy : 88.68%
# Accuracy of test dataset using model V0: 88.5069%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.68%
# Maximum validation accuracy : 88.9%
# Accuracy of test dataset using model V0: 88.7942%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 78.08%
# Maximum validation accuracy : 84.82%
# Accuracy of test dataset using model V0: 84.8005%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.02%
# Maximum validation accuracy : 87.95%
# Accuracy of test dataset using model V0: 87.8447%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.37%
# Maximum validation accuracy : 88.67%
# Accuracy of test dataset using model V0: 88.5639%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.53%
# Maximum validation accuracy : 88.61%
# Accuracy of test dataset using model V0: 88.4572%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 61.05%
# Maximum validation accuracy : 75.27%
# Accuracy of test dataset using model V0: 75.1282%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 67.7%
# Maximum validation accuracy : 81.45%
# Accuracy of test dataset using model V0: 81.4120%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 88.77%
# Maximum validation accuracy : 88.52%
# Accuracy of test dataset using model V0: 88.5066%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 66.86%
# Maximum validation accuracy : 78.74%
# Accuracy of test dataset using model V0: 78.7002%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 64.26%
# Maximum validation accuracy : 77.43%
# Accuracy of test dataset using model V0: 77.2383%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 61.26%
# Maximum validation accuracy : 75.73%
# Accuracy of test dataset using model V0: 75.6941%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 64.16%
# Maximum validation accuracy : 77.31%
# Accuracy of test dataset using model V0: 77.2589%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 66.72%
# Maximum validation accuracy : 79.07%
# Accuracy of test dataset using model V0: 79.0707%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 61.56%
# Maximum validation accuracy : 75.92%
# Accuracy of test dataset using model V0: 75.9192%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 66.57%
# Maximum validation accuracy : 78.76%
# Accuracy of test dataset using model V0: 78.7176%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 64.53%
# Maximum validation accuracy : 77.52%
# Accuracy of test dataset using model V0: 77.5218%
#
#
# (153388, 4, 1) (343867, 4, 1)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 62.91%
# Maximum validation accuracy : 76.59%
# Accuracy of test dataset using model V0: 76.5688%

# %%
feature_names_idx = feature_names #+ ['All features']

plt.figure(figsize=(12, 6))
bars = plt.bar(range(len(feature_acc)), feature_acc, color='skyblue')
plt.xticks(range(len(feature_acc)), feature_names_idx, rotation=45, ha='right')
plt.ylabel('Accuracy')
plt.title('Feature-wise Accuracy')
plt.tight_layout()

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.005, f'{yval:.2f}', ha='center', va='bottom', fontsize=9)
plt.show()

# without normalization
#[81.45, 82.41, 88.59, 74.67, 88.71, 88.52, 88.86, 84.81, 88.12, 88.53, 88.92, 75.11, 81.48, 88.73, 80.88, 78.78, 75.62, 78.39, 80.61, 76.31, 80.35, 78.74, 77.53]

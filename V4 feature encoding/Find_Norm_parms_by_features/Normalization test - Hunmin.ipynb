# %%
import sys
sys.path.append("../../Share")
sys.path.append("../")

import config, Processing_same_with_MATLAB, Feature_info
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

SUBJECT = "Hunmin"
data_files = config.dataset_sub_H
default_path = config.default_path_sub_H

# %%
fs, lower_cutoff, upper_cutoff = Feature_info.fs, Feature_info.lower_cutoff, Feature_info.upper_cutoff
filter_b, filter_a = Processing_same_with_MATLAB.cheby2(4, 30, [lower_cutoff / (fs/2), upper_cutoff / (fs/2)], btype='bandpass')

import Train_and_test_one_feature_with_norm_param

Trainer_feature_wise = Train_and_test_one_feature_with_norm_param.main(filter_a,
                                                          filter_b,
                                                          data_files = data_files,
                                                          default_path = default_path,
                                                          SUBJECT = SUBJECT,
                                                          K = 22) #K : K 이전 데이터 학습, K이후 데이터 테스트

Normalization_TF = True


def get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT):
    All_acc, All_param = [], []

    for M in mean_list:
        for S in std_list:
            test_acc, X_train_stacked, y_train_stacked, X_test_stacked, y_test_stacked = Trainer_feature_wise.Train_and_test(
                Normalization_TF, M, S, num_feature_set=14, target_feat_idx=feature_idx
            )
            All_acc.append(np.mean(test_acc))
            All_param.append([M, S])

    # Find best param
    best_idx = np.argmax(All_acc)
    best_param = All_param[best_idx]
    best_acc = All_acc[best_idx]

    # Create DataFrame
    df = pd.DataFrame(All_param, columns=["Mean", "Std"])
    df["Accuracy"] = All_acc

    # Pivot for heatmap
    heatmap_data = df.pivot(index="Mean", columns="Std", values="Accuracy")

    # Plot
    plt.figure(figsize=(8, 6))
    sns.heatmap(heatmap_data, annot=True, fmt=".4f", cmap="viridis", cbar_kws={'label': 'Accuracy'})
    plt.title(f'Grid Search Accuracy - {Feature_info.feature_names[feature_idx]}')
    plt.xlabel("Std")
    plt.ylabel("Mean")
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.grid(False)
    plt.savefig(f'./result/{SUBJECT}/GridSearchPlot_{Feature_info.feature_names[feature_idx]}.png', dpi=300)
    plt.show()

    # Save raw data
    df.to_csv(f'./result/{SUBJECT}/Accuracy using Norm params - feature {Feature_info.feature_names[feature_idx]}.csv', index=False)

    return best_param, best_acc

# %% [markdown]
# # WL (Index 2)

# %%
feature_idx = 2  # WL / 2 (mean) / 0.8 (std)
mean_list = [1, 1.5, 2, 2.5, 3, 3.5]
std_list = [0.4, 0.6, 0.8, 1, 1.2]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.86%
# Maximum validation accuracy : 89.23%
# Accuracy of test dataset using model V0: 88.4593%
# 	 Accuracy on test dataset 23: 89.2326%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 86.2457%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 88.3150%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 83.8413%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 85.7177%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 86.8063%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 89.0870%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 88.9514%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 86.4159%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 85.2221%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 87.7059%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 87.4608%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 82.4616%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 88.7213%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 86.5507%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 88.9164%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 89.7567%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 89.6699%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 86.5717%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 88.0399%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 89.6364%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 89.4847%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 88.2203%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 89.5543%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 88.7717%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 91.5902%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.2161%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 90.6634%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 90.2270%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.08%
# Maximum validation accuracy : 91.26%
# Accuracy of test dataset using model V0: 91.1957%
# 	 Accuracy on test dataset 23: 91.2552%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 88.0997%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 88.8759%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 85.1559%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 85.3045%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 88.5980%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 92.0709%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 89.7012%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 86.3114%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 85.2337%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 88.7033%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 88.0413%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 82.9033%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 88.9417%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 88.2783%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 89.4476%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 90.2781%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 90.8744%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 87.7419%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 89.1779%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 90.4933%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.5970%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 89.8667%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 91.6202%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 90.7532%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.2291%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.5642%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 91.3013%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.3154%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.3%
# Maximum validation accuracy : 91.85%
# Accuracy of test dataset using model V0: 91.7906%
# 	 Accuracy on test dataset 23: 91.8501%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 88.7601%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 89.4485%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 85.8423%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 85.7767%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 87.9814%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 90.2282%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 90.6503%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 85.8121%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 84.8973%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 88.1350%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 86.9616%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 82.8219%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 89.3479%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 87.3043%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 89.3768%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 90.4983%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 91.2102%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 88.1126%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 89.9094%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 91.2112%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.7595%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 89.9594%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 91.6899%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 91.0776%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.0084%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 92.3300%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 92.0668%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.8944%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.17%
# Maximum validation accuracy : 93.22%
# Accuracy of test dataset using model V0: 93.1588%
# 	 Accuracy on test dataset 23: 93.2183%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 89.6871%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 88.8292%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 86.0051%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 86.5439%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 89.0750%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 89.5863%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 90.2168%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 87.3795%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 85.0829%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 89.3644%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 88.4361%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 86.1111%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 88.6168%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 87.6870%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 89.4004%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 90.2318%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 91.1870%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 88.8310%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 90.4436%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 91.3849%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.8872%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 89.5652%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 90.3784%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 89.8957%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.4033%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.3321%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 90.9650%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.6628%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.03%
# Maximum validation accuracy : 92.86%
# Accuracy of test dataset using model V0: 92.8019%
# 	 Accuracy on test dataset 23: 92.8614%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 88.6906%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 88.2332%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 84.6673%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 86.0246%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 87.0972%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 90.4185%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 87.5688%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 85.4638%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 85.6513%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 85.1311%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 86.1488%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 80.3347%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 89.4987%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 86.4348%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 89.6483%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 89.4554%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 90.8859%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 87.3016%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 89.4101%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 90.7596%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.7131%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 89.5420%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 90.9006%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 90.2897%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 91.0210%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.9819%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 92.2176%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.3038%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.14%
# Maximum validation accuracy : 93.63%
# Accuracy of test dataset using model V0: 93.5158%
# 	 Accuracy on test dataset 23: 93.6347%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 89.5365%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 89.0512%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 86.0517%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 86.7328%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 88.6446%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 89.3485%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 90.1816%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 86.0444%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 84.7350%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 88.9237%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 88.7496%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 86.1576%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 88.2107%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 84.3014%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 88.2318%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 89.7682%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 91.8935%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 87.2205%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 89.4333%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 91.1302%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.3069%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 89.3449%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 90.6801%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 89.6871%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.6240%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 90.9956%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 90.6518%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.2112%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.85%
# Maximum validation accuracy : 92.33%
# Accuracy of test dataset using model V0: 92.3260%
# 	 Accuracy on test dataset 23: 92.3260%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 88.2966%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 88.3267%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 85.4584%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 86.2252%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 86.8179%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 88.8730%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 89.7598%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 86.2650%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 84.8393%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 89.1441%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 88.9121%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 85.4254%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 86.9923%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 84.6841%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 87.8541%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 88.7370%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 90.1563%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 86.3284%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 88.2838%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 90.0069%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.4113%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 89.3913%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 90.6221%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 89.4786%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.2988%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.4017%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 90.5822%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.0607%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.33%
# Maximum validation accuracy : 93.52%
# Accuracy of test dataset using model V0: 93.5158%
# 	 Accuracy on test dataset 23: 93.5158%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 88.9803%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 89.0278%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 86.0517%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 86.6737%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 88.9471%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# ...
# ========================================
# 	 Accuracy on unseen dataset 29: 90.5254%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 90.2988%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 87.8672%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 85.0365%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 88.9353%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 89.3533%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 83.3682%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 88.4196%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 85.6232%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 88.3735%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 89.6292%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 90.7470%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 87.5681%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 89.3637%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 90.8291%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.4926%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 88.8464%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 89.9605%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 89.2932%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.1245%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.6686%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 91.1853%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.2691%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.18%
# Maximum validation accuracy : 92.39%
# Accuracy of test dataset using model V0: 92.2665%
# 	 Accuracy on test dataset 23: 92.3855%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 88.8992%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 87.5555%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 84.6208%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 86.8744%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 88.6562%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 89.5506%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 88.5530%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 88.5406%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 85.5353%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 88.4598%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 89.0166%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 82.6592%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 87.8046%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 85.2754%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 87.5354%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 89.6871%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 91.4418%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 86.8729%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 89.4101%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 90.8175%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 91.6899%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 89.7507%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 91.1096%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 90.3013%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.5311%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.1812%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 90.8490%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 90.8754%
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.54%
# Maximum validation accuracy : 92.68%
# Accuracy of test dataset using model V0: 92.5640%
# 	 Accuracy on test dataset 23: 92.6829%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 89.6987%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 88.8175%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 85.6096%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 85.9773%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 88.0861%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 90.3352%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 89.9590%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 87.2983%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 84.9205%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 87.7291%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 88.2039%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 35: 86.3319%
# Dataset 36/51 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 36: 89.3363%
# Dataset 37/51 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 37: 87.4551%
# Dataset 38/51 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 38: 89.8961%
# Dataset 39/51 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 39: 90.7648%
# Dataset 40/51 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 40: 91.9861%
# Dataset 41/51 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 41: 88.5529%
# Dataset 42/51 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 42: 90.7803%
# Dataset 43/51 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 43: 92.3113%
# Dataset 44/51 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 44: 93.0826%
# Dataset 45/51 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 45: 91.3739%
# Dataset 46/51 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 46: 91.9336%
# Dataset 47/51 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 47: 91.7961%
# Dataset 48/51 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 48: 92.3452%
# Dataset 49/51 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 49: 91.9239%
# Dataset 50/51 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 50: 92.0320%
# Dataset 51/51 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 51: 91.5586%
# Best Accuracy: 89.6463 with mean=3.5, std=1.2

# %% [markdown]
# # MAV

# %%
feature_idx = 4  # MAV / 11.0 (mean) / 4.43 (std)

mean_list = [8.0, 10.0, 11.0, 12.5, 14.0]
std_list = [3.0, 3.8, 4.4, 5.2, 6.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/51 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# Dataset 2/51 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# Dataset 3/51 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/51 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/51 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 6/51 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 7/51 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Dataset 8/51 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Dataset 9/51 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Dataset 10/51 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Dataset 11/51 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 12/51 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 13/51 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 14/51 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 15/51 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 16/51 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 17/51 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 18/51 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 19/51 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 20/51 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 21/51 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Dataset 22/51 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Dataset 23/51 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 22:  (156924, 4, 1) (156924,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.63%
# Maximum validation accuracy : 93.28%
# Accuracy of test dataset using model V0: 93.0993%
# 	 Accuracy on test dataset 23: 93.2778%
# Dataset 24/51 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 24: 89.6060%
# Dataset 25/51 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 25: 88.2215%
# Dataset 26/51 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 26: 84.5044%
# Dataset 27/51 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 27: 86.8036%
# Dataset 28/51 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 28: 89.8546%
# Dataset 29/51 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 29: 92.3562%
# Dataset 30/51 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 30: 88.7639%
# Dataset 31/51 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 31: 86.4043%
# Dataset 32/51 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 32: 85.7673%
# Dataset 33/51 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 33: 88.5989%
# Dataset 34/51 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 34: 88.4129%
# Dataset 35/51 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# KeyboardInterrupt

# %% [markdown]
# # MS(Mean squared)

# %%
feature_idx = 5

mean_list = [160, 200, 229, 260, 290]
std_list  = [200, 260, 304, 360, 420]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")

# %% [markdown]
# # Root Mean Squared (RMS)

# %%
feature_idx = 6
mean_list_RMS = [10.0, 12.0, 13.8, 15.5, 17.0]
std_list_RMS  = [4.5, 5.5, 6.85, 8.0, 9.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")

# %% [markdown]
# # Log Detector (LD)

# %%
feature_idx = 8
mean_list_LogDet = [6.5, 8.0, 9.0, 10.0, 11.0]
std_list_LogDet  = [2.0, 2.5, 2.87, 3.3, 3.8]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")

# %% [markdown]
# # DASDV (Difference Absolute Standard Deviation Value)

# %%
feature_idx = 9
mean_list_DASDV = [2.2, 2.6, 3.0, 3.4, 3.8]
std_list_DASDV  = [0.6, 0.75, 0.87, 1.0, 1.1]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")

# %% [markdown]
# # MFL (Maximum Fractal Length)

# %%
feature_idx = 10
mean_list_MFL = [1.0, 1.3, 1.5, 1.7, 2.0]
std_list_MFL  = [0.12, 0.17, 0.21, 0.25, 0.30]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")

# %% [markdown]
# # WMS

# %%
feature_idx = 13
mean_list_WMS = [2.0, 2.4, 2.8, 3.2, 3.6]
std_list_WMS  = [0.8, 1.0, 1.12, 1.3, 1.5]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")

# %%
import sys
sys.path.append("../../Share")
sys.path.append("../")

import config, Processing_same_with_MATLAB, Feature_info
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

SUBJECT = "Harold"

# %%
fs, lower_cutoff, upper_cutoff = Feature_info.fs, Feature_info.lower_cutoff, Feature_info.upper_cutoff
filter_b, filter_a = Processing_same_with_MATLAB.cheby2(4, 30, [lower_cutoff / (fs/2), upper_cutoff / (fs/2)], btype='bandpass')

import Train_and_test_one_feature_with_norm_param

Trainer_feature_wise = Train_and_test_one_feature_with_norm_param.main(filter_a,
                                                          filter_b,
                                                          data_files = config.dataset_sub_C,
                                                          default_path = config.default_path_sub_C,
                                                          SUBJECT = SUBJECT,
                                                          K = 4) #K : K 이전 데이터 학습, K이후 데이터 테스트

Normalization_TF = True


def get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT):
    All_acc, All_param = [], []

    for M in mean_list:
        for S in std_list:
            test_acc, X_train_stacked, y_train_stacked, X_test_stacked, y_test_stacked = Trainer_feature_wise.Train_and_test(
                Normalization_TF, M, S, num_feature_set=14, target_feat_idx=feature_idx
            )
            All_acc.append(np.mean(test_acc))
            All_param.append([M, S])

    # Find best param
    best_idx = np.argmax(All_acc)
    best_param = All_param[best_idx]
    best_acc = All_acc[best_idx]

    # Create DataFrame
    df = pd.DataFrame(All_param, columns=["Mean", "Std"])
    df["Accuracy"] = All_acc

    # Pivot for heatmap
    heatmap_data = df.pivot(index="Mean", columns="Std", values="Accuracy")

    # Plot
    plt.figure(figsize=(8, 6))
    sns.heatmap(heatmap_data, annot=True, fmt=".4f", cmap="viridis", cbar_kws={'label': 'Accuracy'})
    plt.title(f'Grid Search Accuracy - {Feature_info.feature_names[feature_idx]}')
    plt.xlabel("Std")
    plt.ylabel("Mean")
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.grid(False)
    plt.savefig(f'./result/{SUBJECT}/GridSearchPlot_{Feature_info.feature_names[feature_idx]}.png', dpi=300)
    plt.show()

    # Save raw data
    df.to_csv(f'./result/{SUBJECT}/Accuracy using Norm params - feature {Feature_info.feature_names[feature_idx]}.csv', index=False)

    return best_param, best_acc

# %% [markdown]
# # WL (Index 2)

# %%
feature_idx = 2  # WL / 2 (mean) / 0.8 (std)
mean_list = [1, 1.5, 2, 2.5, 3, 3.5]
std_list = [0.4, 0.6, 0.8, 1, 1.2]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.6%
# Maximum validation accuracy : 87.2%
# Accuracy of test dataset using model V0: 87.0220%
# 	 Accuracy on test dataset 5: 87.1958%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3463%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.1181%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.2383%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.92%
# Maximum validation accuracy : 84.94%
# Accuracy of test dataset using model V0: 84.9363%
# 	 Accuracy on test dataset 5: 84.9363%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.4198%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.2420%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4239%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.11%
# Maximum validation accuracy : 84.7%
# Accuracy of test dataset using model V0: 84.5886%
# 	 Accuracy on test dataset 5: 84.7045%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3578%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.6051%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4704%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.88%
# Maximum validation accuracy : 87.02%
# Accuracy of test dataset using model V0: 86.9641%
# 	 Accuracy on test dataset 5: 87.0220%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.1801%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4852%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4123%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.98%
# Maximum validation accuracy : 86.38%
# Accuracy of test dataset using model V0: 86.2688%
# 	 Accuracy on test dataset 5: 86.3847%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8442%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4042%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.3541%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.37%
# Maximum validation accuracy : 86.62%
# Accuracy of test dataset using model V0: 86.6165%
# 	 Accuracy on test dataset 5: 86.6165%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.6705%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.2652%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2378%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.46%
# Maximum validation accuracy : 86.62%
# Accuracy of test dataset using model V0: 86.6165%
# 	 Accuracy on test dataset 5: 86.6165%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4737%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.9137%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6450%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.08%
# Maximum validation accuracy : 88.41%
# Accuracy of test dataset using model V0: 88.4125%
# 	 Accuracy on test dataset 5: 88.4125%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4505%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4273%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9237%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.94%
# Maximum validation accuracy : 87.43%
# Accuracy of test dataset using model V0: 87.1379%
# 	 Accuracy on test dataset 5: 87.4276%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.9253%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.3735%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8539%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.54%
# Maximum validation accuracy : 86.04%
# Accuracy of test dataset using model V0: 85.8053%
# 	 Accuracy on test dataset 5: 86.0371%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.6821%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.4464%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6450%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.3%
# Maximum validation accuracy : 85.92%
# Accuracy of test dataset using model V0: 85.6315%
# 	 Accuracy on test dataset 5: 85.9212%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4852%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7516%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8539%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.79%
# Maximum validation accuracy : 88.3%
# Accuracy of test dataset using model V0: 87.7173%
# 	 Accuracy on test dataset 5: 88.2966%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5431%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.5043%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.5984%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.94%
# Maximum validation accuracy : 88.01%
# Accuracy of test dataset using model V0: 87.7752%
# 	 Accuracy on test dataset 5: 88.0070%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7516%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1031%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9004%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.62%
# Maximum validation accuracy : 87.95%
# Accuracy of test dataset using model V0: 87.7752%
# 	 Accuracy on test dataset 5: 87.9490%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7053%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6474%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6799%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.31%
# Maximum validation accuracy : 86.91%
# Accuracy of test dataset using model V0: 86.7903%
# 	 Accuracy on test dataset 5: 86.9061%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3694%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.8402%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.6338%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.43%
# Maximum validation accuracy : 88.35%
# Accuracy of test dataset using model V0: 88.3546%
# 	 Accuracy on test dataset 5: 88.3546%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5547%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.5779%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8539%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.91%
# Maximum validation accuracy : 88.06%
# Accuracy of test dataset using model V0: 87.3117%
# 	 Accuracy on test dataset 5: 88.0649%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8327%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1106%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9819%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.38%
# Maximum validation accuracy : 87.72%
# Accuracy of test dataset using model V0: 87.6593%
# 	 Accuracy on test dataset 5: 87.7173%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8327%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.7591%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.7496%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.25%
# Maximum validation accuracy : 87.66%
# Accuracy of test dataset using model V0: 87.6014%
# 	 Accuracy on test dataset 5: 87.6593%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.6010%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.6317%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.0056%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.43%
# Maximum validation accuracy : 87.43%
# Accuracy of test dataset using model V0: 87.3117%
# 	 Accuracy on test dataset 5: 87.4276%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5431%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.9682%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.6329%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.23%
# Maximum validation accuracy : 87.31%
# Accuracy of test dataset using model V0: 87.1958%
# 	 Accuracy on test dataset 5: 87.3117%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3810%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6474%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.5054%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.72%
# Maximum validation accuracy : 87.37%
# Accuracy of test dataset using model V0: 87.3696%
# 	 Accuracy on test dataset 5: 87.3696%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7400%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.4928%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.1103%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.07%
# Maximum validation accuracy : 87.08%
# Accuracy of test dataset using model V0: 86.9641%
# 	 Accuracy on test dataset 5: 87.0800%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4042%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.9137%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4588%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.59%
# Maximum validation accuracy : 85.23%
# Accuracy of test dataset using model V0: 85.2260%
# 	 Accuracy on test dataset 5: 85.2260%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3810%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.1071%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.7725%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.37%
# Maximum validation accuracy : 85.34%
# Accuracy of test dataset using model V0: 85.3418%
# 	 Accuracy on test dataset 5: 85.3418%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3231%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.1187%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.7841%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.76%
# Maximum validation accuracy : 87.83%
# Accuracy of test dataset using model V0: 87.6593%
# 	 Accuracy on test dataset 5: 87.8331%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8095%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.3191%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6799%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.78%
# Maximum validation accuracy : 86.73%
# Accuracy of test dataset using model V0: 86.6744%
# 	 Accuracy on test dataset 5: 86.7323%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8327%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1262%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.0866%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.62%
# Maximum validation accuracy : 85.81%
# Accuracy of test dataset using model V0: 85.6315%
# 	 Accuracy on test dataset 5: 85.8053%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.8674%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.3463%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8539%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.08%
# Maximum validation accuracy : 87.89%
# Accuracy of test dataset using model V0: 87.8331%
# 	 Accuracy on test dataset 5: 87.8911%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5200%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 88.3961%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.5756%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.41%
# Maximum validation accuracy : 86.96%
# Accuracy of test dataset using model V0: 86.7323%
# 	 Accuracy on test dataset 5: 86.9641%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5547%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6474%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.3425%
# Best Accuracy: 87.4972 with mean=3.5, std=1

# %% [markdown]
# # MAV

# %%
feature_idx = 4  # MAV / 11.0 (mean) / 4.43 (std)

mean_list = [8.0, 10.0, 11.0, 12.5, 14.0]
std_list = [3.0, 3.8, 4.4, 5.2, 6.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.24%
# Maximum validation accuracy : 86.91%
# Accuracy of test dataset using model V0: 86.8482%
# 	 Accuracy on test dataset 5: 86.9061%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1957%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.8442%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.0056%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.81%
# Maximum validation accuracy : 87.95%
# Accuracy of test dataset using model V0: 87.8911%
# 	 Accuracy on test dataset 5: 87.9490%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5895%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.1453%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.5054%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.41%
# Maximum validation accuracy : 87.54%
# Accuracy of test dataset using model V0: 87.4855%
# 	 Accuracy on test dataset 5: 87.5435%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4621%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4273%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6915%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.31%
# Maximum validation accuracy : 86.38%
# Accuracy of test dataset using model V0: 86.2688%
# 	 Accuracy on test dataset 5: 86.3847%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.1262%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6358%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9702%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.11%
# Maximum validation accuracy : 87.14%
# Accuracy of test dataset using model V0: 86.8482%
# 	 Accuracy on test dataset 5: 87.1379%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.0104%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.2189%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9702%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.69%
# Maximum validation accuracy : 87.72%
# Accuracy of test dataset using model V0: 87.2538%
# 	 Accuracy on test dataset 5: 87.7173%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5779%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.6474%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.3192%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.73%
# Maximum validation accuracy : 86.62%
# Accuracy of test dataset using model V0: 86.2688%
# 	 Accuracy on test dataset 5: 86.6165%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.4198%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1726%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.1447%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.88%
# Maximum validation accuracy : 84.94%
# Accuracy of test dataset using model V0: 84.8204%
# 	 Accuracy on test dataset 5: 84.9363%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.3544%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.7597%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.2373%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.34%
# Maximum validation accuracy : 85.86%
# Accuracy of test dataset using model V0: 85.7474%
# 	 Accuracy on test dataset 5: 85.8633%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.0724%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.2768%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.3658%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.34%
# Maximum validation accuracy : 83.55%
# Accuracy of test dataset using model V0: 83.4878%
# 	 Accuracy on test dataset 5: 83.5458%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.4082%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.4354%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1443%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.78%
# Maximum validation accuracy : 87.6%
# Accuracy of test dataset using model V0: 87.6014%
# 	 Accuracy on test dataset 5: 87.6014%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.2843%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.4001%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.5868%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.66%
# Maximum validation accuracy : 86.62%
# Accuracy of test dataset using model V0: 86.6165%
# 	 Accuracy on test dataset 5: 86.6165%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.2884%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.5275%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.2615%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.34%
# Maximum validation accuracy : 89.05%
# Accuracy of test dataset using model V0: 89.0498%
# 	 Accuracy on test dataset 5: 89.0498%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 87.0411%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.6781%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.8781%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.75%
# Maximum validation accuracy : 87.54%
# Accuracy of test dataset using model V0: 87.3696%
# 	 Accuracy on test dataset 5: 87.5435%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.7748%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.3347%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.8074%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.94%
# Maximum validation accuracy : 86.62%
# Accuracy of test dataset using model V0: 86.2688%
# 	 Accuracy on test dataset 5: 86.6165%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.1071%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.6862%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.6682%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.07%
# Maximum validation accuracy : 87.2%
# Accuracy of test dataset using model V0: 87.1958%
# 	 Accuracy on test dataset 5: 87.1958%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.9566%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4852%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.4239%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.17%
# Maximum validation accuracy : 86.5%
# Accuracy of test dataset using model V0: 86.3847%
# 	 Accuracy on test dataset 5: 86.5006%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.4777%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.7823%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.3429%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.12%
# Maximum validation accuracy : 88.3%
# Accuracy of test dataset using model V0: 88.1228%
# 	 Accuracy on test dataset 5: 88.2966%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.6010%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7400%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.2843%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.82%
# Maximum validation accuracy : 84.01%
# Accuracy of test dataset using model V0: 83.8934%
# 	 Accuracy on test dataset 5: 84.0093%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.8755%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.8292%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5161%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.79%
# Maximum validation accuracy : 87.72%
# Accuracy of test dataset using model V0: 87.4855%
# 	 Accuracy on test dataset 5: 87.7173%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.3231%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.5391%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 87.0754%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.1%
# Maximum validation accuracy : 87.54%
# Accuracy of test dataset using model V0: 87.5435%
# 	 Accuracy on test dataset 5: 87.5435%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.5084%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 87.2380%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.8776%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.57%
# Maximum validation accuracy : 84.65%
# Accuracy of test dataset using model V0: 84.6466%
# 	 Accuracy on test dataset 5: 84.6466%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.6010%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.9641%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.5165%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.98%
# Maximum validation accuracy : 88.18%
# Accuracy of test dataset using model V0: 88.0070%
# 	 Accuracy on test dataset 5: 88.1808%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.4621%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.4621%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.9702%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.86%
# Maximum validation accuracy : 87.25%
# Accuracy of test dataset using model V0: 87.0220%
# 	 Accuracy on test dataset 5: 87.2538%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 86.2189%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.7516%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 86.3308%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.07%
# Maximum validation accuracy : 85.17%
# Accuracy of test dataset using model V0: 85.1680%
# 	 Accuracy on test dataset 5: 85.1680%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.3775%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.3387%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.2839%
# Best Accuracy: 87.5324 with mean=11.0, std=4.4

# %% [markdown]
# # MS(Mean squared)

# %%
feature_idx = 5

mean_list = [160, 200, 229, 260, 290]
std_list  = [200, 260, 304, 360, 420]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.65%
# Maximum validation accuracy : 82.44%
# Accuracy of test dataset using model V0: 82.3291%
# 	 Accuracy on test dataset 5: 82.4450%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.6439%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.2577%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.8534%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.55%
# Maximum validation accuracy : 82.56%
# Accuracy of test dataset using model V0: 80.7648%
# 	 Accuracy on test dataset 5: 82.5608%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.2733%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.0649%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.0973%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.71%
# Maximum validation accuracy : 83.6%
# Accuracy of test dataset using model V0: 82.7346%
# 	 Accuracy on test dataset 5: 83.6037%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.0417%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.2270%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.8646%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.36%
# Maximum validation accuracy : 81.46%
# Accuracy of test dataset using model V0: 80.1854%
# 	 Accuracy on test dataset 5: 81.4600%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.8911%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.1268%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.5272%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.74%
# Maximum validation accuracy : 84.3%
# Accuracy of test dataset using model V0: 83.4299%
# 	 Accuracy on test dataset 5: 84.2990%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.0145%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.0417%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.0624%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.21%
# Maximum validation accuracy : 83.78%
# Accuracy of test dataset using model V0: 82.1553%
# 	 Accuracy on test dataset 5: 83.7775%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.2849%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.8911%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.8064%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.46%
# Maximum validation accuracy : 81.17%
# Accuracy of test dataset using model V0: 80.5330%
# 	 Accuracy on test dataset 5: 81.1703%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 82.8141%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.7794%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.3876%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.52%
# Maximum validation accuracy : 81.58%
# Accuracy of test dataset using model V0: 81.3441%
# 	 Accuracy on test dataset 5: 81.5759%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.8292%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.9606%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.3648%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.58%
# Maximum validation accuracy : 82.79%
# Accuracy of test dataset using model V0: 82.5608%
# 	 Accuracy on test dataset 5: 82.7926%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.3387%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.5628%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5626%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.37%
# Maximum validation accuracy : 82.21%
# Accuracy of test dataset using model V0: 79.7798%
# 	 Accuracy on test dataset 5: 82.2132%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 82.5709%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.2814%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.8874%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.37%
# Maximum validation accuracy : 82.27%
# Accuracy of test dataset using model V0: 82.2711%
# 	 Accuracy on test dataset 5: 82.2711%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.1459%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.8101%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.9809%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.72%
# Maximum validation accuracy : 83.49%
# Accuracy of test dataset using model V0: 83.3720%
# 	 Accuracy on test dataset 5: 83.4878%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.0955%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.0608%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.4812%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.75%
# Maximum validation accuracy : 80.76%
# Accuracy of test dataset using model V0: 80.0695%
# 	 Accuracy on test dataset 5: 80.7648%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.1882%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.7134%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.4579%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.16%
# Maximum validation accuracy : 81.11%
# Accuracy of test dataset using model V0: 80.2433%
# 	 Accuracy on test dataset 5: 81.1124%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 82.6983%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.9531%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.1899%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.07%
# Maximum validation accuracy : 82.85%
# Accuracy of test dataset using model V0: 81.6338%
# 	 Accuracy on test dataset 5: 82.8505%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.9450%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.5976%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.7371%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.89%
# Maximum validation accuracy : 83.43%
# Accuracy of test dataset using model V0: 83.3140%
# 	 Accuracy on test dataset 5: 83.4299%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.8830%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.8367%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1675%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.37%
# Maximum validation accuracy : 82.62%
# Accuracy of test dataset using model V0: 82.4450%
# 	 Accuracy on test dataset 5: 82.6188%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.7018%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.5356%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.9349%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.6%
# Maximum validation accuracy : 83.31%
# Accuracy of test dataset using model V0: 82.9664%
# 	 Accuracy on test dataset 5: 83.3140%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.4239%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.4123%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.8302%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.44%
# Maximum validation accuracy : 83.84%
# Accuracy of test dataset using model V0: 83.4299%
# 	 Accuracy on test dataset 5: 83.8355%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.1187%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1957%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.4467%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.04%
# Maximum validation accuracy : 81.58%
# Accuracy of test dataset using model V0: 81.4021%
# 	 Accuracy on test dataset 5: 81.5759%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.4511%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 82.8141%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 82.9688%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.3%
# Maximum validation accuracy : 84.47%
# Accuracy of test dataset using model V0: 84.0672%
# 	 Accuracy on test dataset 5: 84.4728%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.5976%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1841%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.1210%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.62%
# Maximum validation accuracy : 83.49%
# Accuracy of test dataset using model V0: 83.1402%
# 	 Accuracy on test dataset 5: 83.4878%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.0376%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.2345%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5742%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.23%
# Maximum validation accuracy : 85.05%
# Accuracy of test dataset using model V0: 84.9363%
# 	 Accuracy on test dataset 5: 85.0521%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.7441%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.9873%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 85.2955%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.3%
# Maximum validation accuracy : 81.92%
# Accuracy of test dataset using model V0: 81.1703%
# 	 Accuracy on test dataset 5: 81.9235%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.6827%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 83.0110%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 83.1201%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.68%
# Maximum validation accuracy : 83.43%
# Accuracy of test dataset using model V0: 82.9664%
# 	 Accuracy on test dataset 5: 83.4299%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.1691%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.3428%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.0624%
# Best Accuracy: 85.6756 with mean=290, std=304

# %% [markdown]
# # Root Mean Squared (RMS)

# %%
feature_idx = 6
mean_list_RMS = [10.0, 12.0, 13.8, 15.5, 17.0]
std_list_RMS  = [4.5, 5.5, 6.85, 8.0, 9.0]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.21%
# Maximum validation accuracy : 85.23%
# Accuracy of test dataset using model V0: 85.2260%
# 	 Accuracy on test dataset 5: 85.2260%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 84.8176%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 85.4198%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.8418%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.29%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.5504%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.37%
# Maximum validation accuracy : 74.22%
# Accuracy of test dataset using model V0: 74.2178%
# 	 Accuracy on test dataset 5: 74.2178%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.19%
# Maximum validation accuracy : 76.19%
# Accuracy of test dataset using model V0: 76.1877%
# 	 Accuracy on test dataset 5: 76.1877%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.07%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.52%
# Maximum validation accuracy : 75.14%
# Accuracy of test dataset using model V0: 74.3337%
# 	 Accuracy on test dataset 5: 75.1448%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.04%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.26%
# Maximum validation accuracy : 75.2%
# Accuracy of test dataset using model V0: 75.2028%
# 	 Accuracy on test dataset 5: 75.2028%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.17%
# Maximum validation accuracy : 75.49%
# Accuracy of test dataset using model V0: 75.4925%
# 	 Accuracy on test dataset 5: 75.4925%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.16%
# Maximum validation accuracy : 73.81%
# Accuracy of test dataset using model V0: 73.8123%
# 	 Accuracy on test dataset 5: 73.8123%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.66%
# Maximum validation accuracy : 77.29%
# Accuracy of test dataset using model V0: 76.5933%
# 	 Accuracy on test dataset 5: 77.2885%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.07%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.01%
# Maximum validation accuracy : 75.96%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.9560%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.63%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.82%
# Maximum validation accuracy : 75.49%
# Accuracy of test dataset using model V0: 75.4345%
# 	 Accuracy on test dataset 5: 75.4925%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.17%
# Maximum validation accuracy : 77.52%
# Accuracy of test dataset using model V0: 77.5203%
# 	 Accuracy on test dataset 5: 77.5203%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.82%
# Maximum validation accuracy : 74.22%
# Accuracy of test dataset using model V0: 74.1599%
# 	 Accuracy on test dataset 5: 74.2178%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.03%
# Maximum validation accuracy : 76.3%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.3036%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.13%
# Maximum validation accuracy : 74.28%
# Accuracy of test dataset using model V0: 74.2758%
# 	 Accuracy on test dataset 5: 74.2758%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.16%
# Maximum validation accuracy : 81.58%
# Accuracy of test dataset using model V0: 81.4600%
# 	 Accuracy on test dataset 5: 81.5759%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 83.6248%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 84.0185%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.5859%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.69%
# Maximum validation accuracy : 74.68%
# Accuracy of test dataset using model V0: 74.6813%
# 	 Accuracy on test dataset 5: 74.6813%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.33%
# Maximum validation accuracy : 75.14%
# Accuracy of test dataset using model V0: 75.1448%
# 	 Accuracy on test dataset 5: 75.1448%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.88%
# Maximum validation accuracy : 75.14%
# Accuracy of test dataset using model V0: 75.1448%
# 	 Accuracy on test dataset 5: 75.1448%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.1%
# Maximum validation accuracy : 75.14%
# Accuracy of test dataset using model V0: 75.1448%
# 	 Accuracy on test dataset 5: 75.1448%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.71%
# Maximum validation accuracy : 74.62%
# Accuracy of test dataset using model V0: 74.6234%
# 	 Accuracy on test dataset 5: 74.6234%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 85.0264 with mean=160, std=200

# %% [markdown]
# # Log Detector (LD)

# %%
feature_idx = 8
mean_list_LogDet = [6.5, 8.0, 9.0, 10.0, 11.0]
std_list_LogDet  = [2.0, 2.5, 2.87, 3.3, 3.8]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.13%
# Maximum validation accuracy : 74.22%
# Accuracy of test dataset using model V0: 74.2178%
# 	 Accuracy on test dataset 5: 74.2178%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.87%
# Maximum validation accuracy : 77.29%
# Accuracy of test dataset using model V0: 77.2885%
# 	 Accuracy on test dataset 5: 77.2885%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.75%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.7242%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.71%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.56%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.75%
# Maximum validation accuracy : 74.16%
# Accuracy of test dataset using model V0: 74.1599%
# 	 Accuracy on test dataset 5: 74.1599%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.46%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.78%
# Maximum validation accuracy : 76.13%
# Accuracy of test dataset using model V0: 76.1298%
# 	 Accuracy on test dataset 5: 76.1298%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.14%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.17%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.13%
# Maximum validation accuracy : 76.13%
# Accuracy of test dataset using model V0: 76.1298%
# 	 Accuracy on test dataset 5: 76.1298%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.97%
# Maximum validation accuracy : 75.2%
# Accuracy of test dataset using model V0: 75.2028%
# 	 Accuracy on test dataset 5: 75.2028%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.81%
# Maximum validation accuracy : 76.94%
# Accuracy of test dataset using model V0: 76.9409%
# 	 Accuracy on test dataset 5: 76.9409%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.47%
# Maximum validation accuracy : 75.03%
# Accuracy of test dataset using model V0: 75.0290%
# 	 Accuracy on test dataset 5: 75.0290%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.42%
# Maximum validation accuracy : 74.51%
# Accuracy of test dataset using model V0: 74.5075%
# 	 Accuracy on test dataset 5: 74.5075%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.98%
# Maximum validation accuracy : 74.1%
# Accuracy of test dataset using model V0: 74.1020%
# 	 Accuracy on test dataset 5: 74.1020%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.33%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.48%
# Maximum validation accuracy : 74.33%
# Accuracy of test dataset using model V0: 74.3337%
# 	 Accuracy on test dataset 5: 74.3337%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.95%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.5%
# Maximum validation accuracy : 74.51%
# Accuracy of test dataset using model V0: 74.5075%
# 	 Accuracy on test dataset 5: 74.5075%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.91%
# Maximum validation accuracy : 74.33%
# Accuracy of test dataset using model V0: 74.3337%
# 	 Accuracy on test dataset 5: 74.3337%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.21%
# Maximum validation accuracy : 75.67%
# Accuracy of test dataset using model V0: 75.6663%
# 	 Accuracy on test dataset 5: 75.6663%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.71%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.7242%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.56%
# Maximum validation accuracy : 84.01%
# Accuracy of test dataset using model V0: 83.7775%
# 	 Accuracy on test dataset 5: 84.0093%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 85.3387%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 86.1378%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 84.8767%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.48%
# Maximum validation accuracy : 74.57%
# Accuracy of test dataset using model V0: 74.5655%
# 	 Accuracy on test dataset 5: 74.5655%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 85.4511 with mean=290, std=360

# %% [markdown]
# # DASDV (Difference Absolute Standard Deviation Value)

# %%
feature_idx = 9
mean_list_DASDV = [2.2, 2.6, 3.0, 3.4, 3.8]
std_list_DASDV  = [0.6, 0.75, 0.87, 1.0, 1.1]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.49%
# Maximum validation accuracy : 75.38%
# Accuracy of test dataset using model V0: 75.3766%
# 	 Accuracy on test dataset 5: 75.3766%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.43%
# Maximum validation accuracy : 77.06%
# Accuracy of test dataset using model V0: 77.0568%
# 	 Accuracy on test dataset 5: 77.0568%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.78%
# Maximum validation accuracy : 74.91%
# Accuracy of test dataset using model V0: 74.9131%
# 	 Accuracy on test dataset 5: 74.9131%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.9%
# Maximum validation accuracy : 74.97%
# Accuracy of test dataset using model V0: 74.9710%
# 	 Accuracy on test dataset 5: 74.9710%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.94%
# Maximum validation accuracy : 75.2%
# Accuracy of test dataset using model V0: 75.2028%
# 	 Accuracy on test dataset 5: 75.2028%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.24%
# Maximum validation accuracy : 74.39%
# Accuracy of test dataset using model V0: 74.3917%
# 	 Accuracy on test dataset 5: 74.3917%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.1%
# Maximum validation accuracy : 73.17%
# Accuracy of test dataset using model V0: 73.1750%
# 	 Accuracy on test dataset 5: 73.1750%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.27%
# Maximum validation accuracy : 76.94%
# Accuracy of test dataset using model V0: 76.9409%
# 	 Accuracy on test dataset 5: 76.9409%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.37%
# Maximum validation accuracy : 78.56%
# Accuracy of test dataset using model V0: 78.5632%
# 	 Accuracy on test dataset 5: 78.5632%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.63%
# Maximum validation accuracy : 73.99%
# Accuracy of test dataset using model V0: 73.9861%
# 	 Accuracy on test dataset 5: 73.9861%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.71%
# Maximum validation accuracy : 76.71%
# Accuracy of test dataset using model V0: 76.7092%
# 	 Accuracy on test dataset 5: 76.7092%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.94%
# Maximum validation accuracy : 73.99%
# Accuracy of test dataset using model V0: 73.9861%
# 	 Accuracy on test dataset 5: 73.9861%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.78%
# Maximum validation accuracy : 76.07%
# Accuracy of test dataset using model V0: 76.0718%
# 	 Accuracy on test dataset 5: 76.0718%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.39%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.27%
# Maximum validation accuracy : 74.97%
# Accuracy of test dataset using model V0: 74.9710%
# 	 Accuracy on test dataset 5: 74.9710%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.11%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.62%
# Maximum validation accuracy : 76.3%
# Accuracy of test dataset using model V0: 76.3036%
# 	 Accuracy on test dataset 5: 76.3036%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.79%
# Maximum validation accuracy : 76.01%
# Accuracy of test dataset using model V0: 76.0139%
# 	 Accuracy on test dataset 5: 76.0139%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.2%
# Maximum validation accuracy : 77.29%
# Accuracy of test dataset using model V0: 77.2885%
# 	 Accuracy on test dataset 5: 77.2885%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.4%
# Maximum validation accuracy : 76.36%
# Accuracy of test dataset using model V0: 76.3615%
# 	 Accuracy on test dataset 5: 76.3615%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.33%
# Maximum validation accuracy : 74.91%
# Accuracy of test dataset using model V0: 74.9131%
# 	 Accuracy on test dataset 5: 74.9131%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.56%
# Maximum validation accuracy : 75.32%
# Accuracy of test dataset using model V0: 75.3187%
# 	 Accuracy on test dataset 5: 75.3187%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.95%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.78%
# Maximum validation accuracy : 74.33%
# Accuracy of test dataset using model V0: 74.3337%
# 	 Accuracy on test dataset 5: 74.3337%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.48%
# Maximum validation accuracy : 73.7%
# Accuracy of test dataset using model V0: 73.6964%
# 	 Accuracy on test dataset 5: 73.6964%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 78.7219 with mean=160, std=200

# %% [markdown]
# # MFL (Maximum Fractal Length)

# %%
feature_idx = 10
mean_list_MFL = [1.0, 1.3, 1.5, 1.7, 2.0]
std_list_MFL  = [0.12, 0.17, 0.21, 0.25, 0.30]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.36%
# Maximum validation accuracy : 73.99%
# Accuracy of test dataset using model V0: 73.9861%
# 	 Accuracy on test dataset 5: 73.9861%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.85%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.42%
# Maximum validation accuracy : 77.29%
# Accuracy of test dataset using model V0: 77.2885%
# 	 Accuracy on test dataset 5: 77.2885%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.74%
# Maximum validation accuracy : 76.94%
# Accuracy of test dataset using model V0: 76.9409%
# 	 Accuracy on test dataset 5: 76.9409%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.56%
# Maximum validation accuracy : 76.19%
# Accuracy of test dataset using model V0: 76.1877%
# 	 Accuracy on test dataset 5: 76.1877%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.85%
# Maximum validation accuracy : 76.42%
# Accuracy of test dataset using model V0: 76.4195%
# 	 Accuracy on test dataset 5: 76.4195%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.55%
# Maximum validation accuracy : 75.61%
# Accuracy of test dataset using model V0: 75.6083%
# 	 Accuracy on test dataset 5: 75.6083%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.65%
# Maximum validation accuracy : 76.54%
# Accuracy of test dataset using model V0: 76.5353%
# 	 Accuracy on test dataset 5: 76.5353%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 77.26%
# Maximum validation accuracy : 78.39%
# Accuracy of test dataset using model V0: 78.3893%
# 	 Accuracy on test dataset 5: 78.3893%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.71%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.93%
# Maximum validation accuracy : 76.07%
# Accuracy of test dataset using model V0: 76.0718%
# 	 Accuracy on test dataset 5: 76.0718%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.39%
# Maximum validation accuracy : 75.03%
# Accuracy of test dataset using model V0: 75.0290%
# 	 Accuracy on test dataset 5: 75.0290%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.35%
# Maximum validation accuracy : 77.0%
# Accuracy of test dataset using model V0: 76.9988%
# 	 Accuracy on test dataset 5: 76.9988%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.25%
# Maximum validation accuracy : 75.26%
# Accuracy of test dataset using model V0: 75.2607%
# 	 Accuracy on test dataset 5: 75.2607%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.56%
# Maximum validation accuracy : 75.96%
# Accuracy of test dataset using model V0: 75.9560%
# 	 Accuracy on test dataset 5: 75.9560%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.01%
# Maximum validation accuracy : 76.71%
# Accuracy of test dataset using model V0: 76.7092%
# 	 Accuracy on test dataset 5: 76.7092%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.26%
# Maximum validation accuracy : 75.2%
# Accuracy of test dataset using model V0: 75.2028%
# 	 Accuracy on test dataset 5: 75.2028%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.59%
# Maximum validation accuracy : 75.78%
# Accuracy of test dataset using model V0: 75.7822%
# 	 Accuracy on test dataset 5: 75.7822%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.72%
# Maximum validation accuracy : 76.07%
# Accuracy of test dataset using model V0: 76.0718%
# 	 Accuracy on test dataset 5: 76.0718%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.71%
# Maximum validation accuracy : 75.32%
# Accuracy of test dataset using model V0: 75.3187%
# 	 Accuracy on test dataset 5: 75.3187%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.7%
# Maximum validation accuracy : 75.9%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 75.8980%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.1%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.7242%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.51%
# Maximum validation accuracy : 75.38%
# Accuracy of test dataset using model V0: 75.3766%
# 	 Accuracy on test dataset 5: 75.3766%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.71%
# Maximum validation accuracy : 75.2%
# Accuracy of test dataset using model V0: 75.2028%
# 	 Accuracy on test dataset 5: 75.2028%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 76.27%
# Maximum validation accuracy : 77.23%
# Accuracy of test dataset using model V0: 77.2306%
# 	 Accuracy on test dataset 5: 77.2306%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 78.7219 with mean=160, std=200

# %% [markdown]
# # WMS

# %%
feature_idx = 13
mean_list_WMS = [2.0, 2.4, 2.8, 3.2, 3.6]
std_list_WMS  = [0.8, 1.0, 1.12, 1.3, 1.5]

best_param, best_acc = get_best_param(mean_list, std_list, Normalization_TF, feature_idx, SUBJECT)
print(f"Best Accuracy: {best_acc:.4f} with mean={best_param[0]}, std={best_param[1]}")
# Out:
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.06%
# Maximum validation accuracy : 76.77%
# Accuracy of test dataset using model V0: 76.7671%
# 	 Accuracy on test dataset 5: 76.7671%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.97%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.21%
# Maximum validation accuracy : 74.91%
# Accuracy of test dataset using model V0: 74.9131%
# 	 Accuracy on test dataset 5: 74.9131%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.68%
# Maximum validation accuracy : 76.88%
# Accuracy of test dataset using model V0: 76.8830%
# 	 Accuracy on test dataset 5: 76.8830%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.77%
# Maximum validation accuracy : 74.74%
# Accuracy of test dataset using model V0: 74.7393%
# 	 Accuracy on test dataset 5: 74.7393%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.33%
# Maximum validation accuracy : 74.39%
# Accuracy of test dataset using model V0: 74.3917%
# 	 Accuracy on test dataset 5: 74.3917%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.17%
# Maximum validation accuracy : 76.3%
# Accuracy of test dataset using model V0: 76.3036%
# 	 Accuracy on test dataset 5: 76.3036%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.66%
# Maximum validation accuracy : 76.48%
# Accuracy of test dataset using model V0: 76.4774%
# 	 Accuracy on test dataset 5: 76.4774%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.65%
# Maximum validation accuracy : 75.84%
# Accuracy of test dataset using model V0: 75.8401%
# 	 Accuracy on test dataset 5: 75.8401%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.36%
# Maximum validation accuracy : 75.72%
# Accuracy of test dataset using model V0: 75.7242%
# 	 Accuracy on test dataset 5: 75.7242%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.53%
# Maximum validation accuracy : 75.03%
# Accuracy of test dataset using model V0: 75.0290%
# 	 Accuracy on test dataset 5: 75.0290%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.46%
# Maximum validation accuracy : 76.71%
# Accuracy of test dataset using model V0: 76.7092%
# 	 Accuracy on test dataset 5: 76.7092%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.43%
# Maximum validation accuracy : 77.06%
# Accuracy of test dataset using model V0: 77.0568%
# 	 Accuracy on test dataset 5: 77.0568%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.53%
# Maximum validation accuracy : 76.13%
# Accuracy of test dataset using model V0: 76.1298%
# 	 Accuracy on test dataset 5: 76.1298%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 78.79%
# Maximum validation accuracy : 75.32%
# Accuracy of test dataset using model V0: 75.3187%
# 	 Accuracy on test dataset 5: 75.3187%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.49%
# Maximum validation accuracy : 77.0%
# Accuracy of test dataset using model V0: 75.8980%
# 	 Accuracy on test dataset 5: 76.9988%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.35%
# Maximum validation accuracy : 76.25%
# Accuracy of test dataset using model V0: 76.2457%
# 	 Accuracy on test dataset 5: 76.2457%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.53%
# Maximum validation accuracy : 74.62%
# Accuracy of test dataset using model V0: 74.6234%
# 	 Accuracy on test dataset 5: 74.6234%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.3%
# Maximum validation accuracy : 75.14%
# Accuracy of test dataset using model V0: 75.1448%
# 	 Accuracy on test dataset 5: 75.1448%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.81%
# Maximum validation accuracy : 75.96%
# Accuracy of test dataset using model V0: 75.9560%
# 	 Accuracy on test dataset 5: 75.9560%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.5%
# Maximum validation accuracy : 75.03%
# Accuracy of test dataset using model V0: 75.0290%
# 	 Accuracy on test dataset 5: 75.0290%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 81.3%
# Maximum validation accuracy : 75.14%
# Accuracy of test dataset using model V0: 75.1448%
# 	 Accuracy on test dataset 5: 75.1448%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.98%
# Maximum validation accuracy : 74.97%
# Accuracy of test dataset using model V0: 74.9710%
# 	 Accuracy on test dataset 5: 74.9710%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 80.68%
# Maximum validation accuracy : 74.28%
# Accuracy of test dataset using model V0: 74.2758%
# 	 Accuracy on test dataset 5: 74.2758%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Dataset 1/8 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 2/8 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 3/8 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 4/8 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Dataset 5/8 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# 	 Training 4:  (34343, 4, 1) (34343,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.58%
# Maximum validation accuracy : 75.09%
# Accuracy of test dataset using model V0: 75.0869%
# 	 Accuracy on test dataset 5: 75.0869%
# Dataset 6/8 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 6: 78.0776%
# Dataset 7/8 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 7: 78.8651%
# Dataset 8/8 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# 	 Accuracy on unseen dataset 8: 79.2229%
# Best Accuracy: 78.7219 with mean=160, std=200

# %%
import os

import pandas as pd
import scipy
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("../../Share")
import config, utils, baseline, Processing_same_with_MATLAB

# %% [markdown]
# 1. Sync up to the Data_ADC and Data_Cls
# 2. Extract features
# 3. Normalization problem
#     - Without Norm.
# 4.

# %%
fs = round(10e6 / 2048)  # 4883 Hz
lower_cutoff = 100
upper_cutoff = 600
filter_b, filter_a = Processing_same_with_MATLAB.cheby2(4, 30, [lower_cutoff / (fs/2), upper_cutoff / (fs/2)], btype='bandpass')

feat_mean_1ch = np.array([0.1, 0.1, 2.5, 0.0, 11.0, 229.0, 13.8, -11.0, 9.0, 3.0, 1.5, 0.0, 0.0, 2.8])
feat_std_1ch = np.array([0.02, 0.05, 0.65, 0.02, 4.43, 303.9, 6.85, 12.18, 2.87, 0.87, 0.21, 0.04, 6.68, 1.12])
feat_mean = np.tile(feat_mean_1ch, (4, 1))
feat_std = np.tile(feat_std_1ch, (4, 1))

extractor = Processing_same_with_MATLAB.EMGFeatureExtractor(feat_mean, feat_std, filter_b, filter_a, Norm_bool=False)
trainer = baseline.TremorModelTrainer(config, subject="Hunmin")

# %% [markdown]
# # Found that there are normalization applied, so I've tested it without using an normalization

# %%
data_files = config.dataset_sub_H
default_path = config.default_path_sub_H

baseline_K = [1, 6, 10, 14, 18, 22, 26, 30, 34, 38]
for K in baseline_K:
    X_train_all, y_train_all, X_test_all, y_test_all = [], [], [], []
    ACC_all = []

    for idx, session_info in enumerate(data_files):
    #for idx, session_info in enumerate(['Exp_2025-06-27-v1/E9AD0E7DCC2B/']):
        #print(f"Dataset {idx + 1}/{len(data_files)} - Session {session_info}\n{'='*40}")
        path = os.path.join(default_path, f'{session_info}raw/')
        features, class_labels = [], []
        for c_idx, c in enumerate(config.classes_5):
            raw_data = os.listdir(path+c)
            mat = scipy.io.loadmat(path+c+raw_data[0])
            extractor.buffer = mat['Data_ADC']
            class_labels.append(mat['Data_Cls'].reshape(-1))
            features_per_cls = extractor.extract_features()
            features_per_cls = np.transpose(features_per_cls, (2, 0, 1))  # shape: (1729, 4, 14)
            features.append(features_per_cls)
            #print(features_per_cls.shape, mat['Data_Cls'].reshape(-1).shape)

        #print(session_info)
        X = np.concatenate(features, axis=0)
        y = np.concatenate(class_labels, axis=0)

        if X.shape[0] != y.shape[-1]:
            print(f"Incorrect shape between features and Class: {X.shape} and {y.shape}, {session_info}")
            break

        if idx < K:
            X_train, y_train, X_test, y_test = utils.split_data(X, y, ratio=0.9)
            X_train_all.append(X_train)
            y_train_all.append(y_train)
            X_test_all.append(X_test)
            y_test_all.append(y_test)

            # Concatenate all so far
            X_train_stacked = np.concatenate(X_train_all, axis=0)
            y_train_stacked = np.concatenate(y_train_all, axis=0)
            X_test_stacked = np.concatenate(X_test_all, axis=0)
            y_test_stacked = np.concatenate(y_test_all, axis=0)
            acc=0
        elif idx == K:
            print(f"\t Training {K}: ", X_train_stacked.shape, y_train_stacked.shape)
            acc, pre_trained_CNN = trainer.train_multiple_dataset(X_train, y_train, X_test, y_test)
        else:
            #Test with current data
            X = np.expand_dims(X, axis=-1)
            acc = pre_trained_CNN.evaluate(X, y, verbose=0)[1]*100
            print(f"\t Accuracy on unseen dataset {idx+1}: {acc:.4f}%")
        ACC_all.append(acc)
    pd.DataFrame(ACC_all).to_csv(f'../Results/WithoutNorm/Baseline_results_train_with_{K}data_noNorm_H.csv', index=False)
# Out:
# 	 Training 1:  (7762, 4, 14, 1) (7762,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 85.79%
# Maximum validation accuracy : 93.28%
# Accuracy of test dataset using model V0: 93.1634%
# 	 Accuracy on unseen dataset 3: 77.9809%
# 	 Accuracy on unseen dataset 4: 82.3174%
# 	 Accuracy on unseen dataset 5: 83.2314%
# 	 Accuracy on unseen dataset 6: 72.4713%
# 	 Accuracy on unseen dataset 7: 67.4156%
# 	 Accuracy on unseen dataset 8: 74.6497%
# 	 Accuracy on unseen dataset 9: 69.2933%
# 	 Accuracy on unseen dataset 10: 68.1280%
# 	 Accuracy on unseen dataset 11: 67.3636%
# 	 Accuracy on unseen dataset 12: 66.7369%
# 	 Accuracy on unseen dataset 13: 69.9239%
# 	 Accuracy on unseen dataset 14: 67.8234%
# 	 Accuracy on unseen dataset 15: 79.7248%
# 	 Accuracy on unseen dataset 16: 81.0413%
# 	 Accuracy on unseen dataset 17: 82.3106%
# 	 Accuracy on unseen dataset 18: 83.7106%
# 	 Accuracy on unseen dataset 19: 78.5606%
# 	 Accuracy on unseen dataset 20: 83.7049%
# 	 Accuracy on unseen dataset 21: 81.6533%
# 	 Accuracy on unseen dataset 22: 82.1134%
# 	 Accuracy on unseen dataset 23: 82.7562%
# 	 Accuracy on unseen dataset 24: 87.2074%
# 	 Accuracy on unseen dataset 25: 84.7044%
# 	 Accuracy on unseen dataset 26: 88.3550%
# 	 Accuracy on unseen dataset 27: 77.1246%
# 	 Accuracy on unseen dataset 28: 79.8371%
# 	 Accuracy on unseen dataset 29: 83.6424%
# 	 Accuracy on unseen dataset 30: 86.3738%
# 	 Accuracy on unseen dataset 31: 74.0509%
# 	 Accuracy on unseen dataset 32: 81.4407%
# 	 Accuracy on unseen dataset 33: 79.5059%
# 	 Accuracy on unseen dataset 34: 82.1897%
# 	 Accuracy on unseen dataset 35: 87.7964%
# 	 Accuracy on unseen dataset 36: 88.0393%
# 	 Accuracy on unseen dataset 37: 89.2275%
# 	 Accuracy on unseen dataset 38: 71.4699%
# 	 Accuracy on unseen dataset 39: 71.0768%
# 	 Accuracy on unseen dataset 40: 80.6369%
# 	 Accuracy on unseen dataset 41: 81.1928%
# 	 Accuracy on unseen dataset 42: 65.1273%
# 	 Accuracy on unseen dataset 43: 85.2866%
# 	 Accuracy on unseen dataset 44: 85.2754%
# 	 Accuracy on unseen dataset 45: 87.2049%
# 	 Accuracy on unseen dataset 46: 87.3001%
# 	 Accuracy on unseen dataset 47: 88.4424%
# 	 Accuracy on unseen dataset 48: 85.1929%
# 	 Accuracy on unseen dataset 49: 89.0966%
# 	 Accuracy on unseen dataset 50: 90.0069%
# 	 Training 6:  (45688, 4, 14, 1) (45688,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 82.75%
# Maximum validation accuracy : 84.82%
# Accuracy of test dataset using model V0: 84.5886%
# 	 Accuracy on unseen dataset 8: 72.0787%
# 	 Accuracy on unseen dataset 9: 64.0167%
# 	 Accuracy on unseen dataset 10: 65.2169%
# 	 Accuracy on unseen dataset 11: 64.5018%
# 	 Accuracy on unseen dataset 12: 67.6502%
# 	 Accuracy on unseen dataset 13: 67.1855%
# 	 Accuracy on unseen dataset 14: 65.1912%
# 	 Accuracy on unseen dataset 15: 75.2944%
# 	 Accuracy on unseen dataset 16: 76.2316%
# 	 Accuracy on unseen dataset 17: 78.5216%
# 	 Accuracy on unseen dataset 18: 81.0739%
# 	 Accuracy on unseen dataset 19: 71.0136%
# 	 Accuracy on unseen dataset 20: 79.0125%
# 	 Accuracy on unseen dataset 21: 76.4679%
# 	 Accuracy on unseen dataset 22: 78.4596%
# 	 Accuracy on unseen dataset 23: 76.9368%
# 	 Accuracy on unseen dataset 24: 83.0475%
# 	 Accuracy on unseen dataset 25: 82.1921%
# 	 Accuracy on unseen dataset 26: 82.6431%
# 	 Accuracy on unseen dataset 27: 71.4117%
# 	 Accuracy on unseen dataset 28: 74.4735%
# 	 Accuracy on unseen dataset 29: 82.9886%
# 	 Accuracy on unseen dataset 30: 84.7217%
# 	 Accuracy on unseen dataset 31: 74.8984%
# 	 Accuracy on unseen dataset 32: 81.7075%
# 	 Accuracy on unseen dataset 33: 81.0485%
# 	 Accuracy on unseen dataset 34: 82.9792%
# 	 Accuracy on unseen dataset 35: 78.5681%
# 	 Accuracy on unseen dataset 36: 81.9549%
# 	 Accuracy on unseen dataset 37: 85.4235%
# 	 Accuracy on unseen dataset 38: 75.1157%
# 	 Accuracy on unseen dataset 39: 69.5087%
# 	 Accuracy on unseen dataset 40: 82.5362%
# 	 Accuracy on unseen dataset 41: 83.5900%
# 	 Accuracy on unseen dataset 42: 71.0880%
# 	 Accuracy on unseen dataset 43: 85.1706%
# 	 Accuracy on unseen dataset 44: 83.1420%
# 	 Accuracy on unseen dataset 45: 87.8777%
# 	 Accuracy on unseen dataset 46: 87.8447%
# 	 Accuracy on unseen dataset 47: 88.4308%
# 	 Accuracy on unseen dataset 48: 84.8453%
# 	 Accuracy on unseen dataset 49: 87.3665%
# 	 Accuracy on unseen dataset 50: 89.2659%
# 	 Training 10:  (76695, 4, 14, 1) (76695,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 85.62%
# Maximum validation accuracy : 92.23%
# Accuracy of test dataset using model V0: 92.2274%
# 	 Accuracy on unseen dataset 12: 83.2221%
# 	 Accuracy on unseen dataset 13: 87.4898%
# 	 Accuracy on unseen dataset 14: 89.6483%
# 	 Accuracy on unseen dataset 15: 81.2638%
# 	 Accuracy on unseen dataset 16: 82.9909%
# 	 Accuracy on unseen dataset 17: 78.4403%
# 	 Accuracy on unseen dataset 18: 88.0087%
# 	 Accuracy on unseen dataset 19: 68.8440%
# 	 Accuracy on unseen dataset 20: 72.6625%
# 	 Accuracy on unseen dataset 21: 88.4083%
# 	 Accuracy on unseen dataset 22: 89.9432%
# 	 Accuracy on unseen dataset 23: 85.8860%
# 	 Accuracy on unseen dataset 24: 85.1101%
# 	 Accuracy on unseen dataset 25: 83.2087%
# 	 Accuracy on unseen dataset 26: 79.6650%
# 	 Accuracy on unseen dataset 27: 81.2323%
# 	 Accuracy on unseen dataset 28: 87.7371%
# 	 Accuracy on unseen dataset 29: 89.6101%
# 	 Accuracy on unseen dataset 30: 83.6204%
# 	 Accuracy on unseen dataset 31: 83.4436%
# 	 Accuracy on unseen dataset 32: 83.9346%
# 	 Accuracy on unseen dataset 33: 89.2832%
# 	 Accuracy on unseen dataset 34: 86.7990%
# 	 Accuracy on unseen dataset 35: 78.5449%
# 	 Accuracy on unseen dataset 36: 74.9798%
# 	 Accuracy on unseen dataset 37: 77.6059%
# 	 Accuracy on unseen dataset 38: 67.7894%
# 	 Accuracy on unseen dataset 39: 65.3154%
# 	 Accuracy on unseen dataset 40: 82.5941%
# 	 Accuracy on unseen dataset 41: 84.1459%
# 	 Accuracy on unseen dataset 42: 69.8495%
# 	 Accuracy on unseen dataset 43: 91.8311%
# 	 Accuracy on unseen dataset 44: 89.1594%
# 	 Accuracy on unseen dataset 45: 91.3244%
# 	 Accuracy on unseen dataset 46: 93.1054%
# 	 Accuracy on unseen dataset 47: 91.3492%
# 	 Accuracy on unseen dataset 48: 89.3523%
# 	 Accuracy on unseen dataset 49: 90.6642%
# 	 Accuracy on unseen dataset 50: 91.9060%
# 	 Training 14:  (107402, 4, 14, 1) (107402,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 87.84%
# Maximum validation accuracy : 92.68%
# Accuracy of test dataset using model V0: 92.2078%
# 	 Accuracy on unseen dataset 16: 82.1854%
# 	 Accuracy on unseen dataset 17: 78.1381%
# 	 Accuracy on unseen dataset 18: 86.8649%
# 	 Accuracy on unseen dataset 19: 74.1397%
# 	 Accuracy on unseen dataset 20: 77.1799%
# 	 Accuracy on unseen dataset 21: 89.3152%
# 	 Accuracy on unseen dataset 22: 91.2075%
# 	 Accuracy on unseen dataset 23: 84.1842%
# 	 Accuracy on unseen dataset 24: 85.8169%
# 	 Accuracy on unseen dataset 25: 82.4842%
# 	 Accuracy on unseen dataset 26: 81.4798%
# 	 Accuracy on unseen dataset 27: 80.8074%
# 	 Accuracy on unseen dataset 28: 85.3636%
# 	 Accuracy on unseen dataset 29: 87.9458%
# 	 Accuracy on unseen dataset 30: 84.1359%
# 	 Accuracy on unseen dataset 31: 82.3290%
# 	 Accuracy on unseen dataset 32: 84.4566%
# 	 Accuracy on unseen dataset 33: 86.8128%
# 	 Accuracy on unseen dataset 34: 85.7773%
# 	 Accuracy on unseen dataset 35: 80.4974%
# 	 Accuracy on unseen dataset 36: 76.0671%
# 	 Accuracy on unseen dataset 37: 78.7343%
# 	 Accuracy on unseen dataset 38: 66.3773%
# 	 Accuracy on unseen dataset 39: 65.7684%
# 	 Accuracy on unseen dataset 40: 83.7985%
# 	 Accuracy on unseen dataset 41: 85.3503%
# 	 Accuracy on unseen dataset 42: 68.3218%
# 	 Accuracy on unseen dataset 43: 92.0515%
# 	 Accuracy on unseen dataset 44: 90.7826%
# 	 Accuracy on unseen dataset 45: 92.1388%
# 	 Accuracy on unseen dataset 46: 93.0939%
# 	 Accuracy on unseen dataset 47: 90.5385%
# 	 Accuracy on unseen dataset 48: 89.1438%
# 	 Accuracy on unseen dataset 49: 90.4668%
# 	 Accuracy on unseen dataset 50: 91.4312%
# 	 Training 18:  (138049, 4, 14, 1) (138049,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 91.99%
# Maximum validation accuracy : 97.11%
# Accuracy of test dataset using model V0: 96.8712%
# 	 Accuracy on unseen dataset 20: 80.2731%
# 	 Accuracy on unseen dataset 21: 88.7455%
# 	 Accuracy on unseen dataset 22: 90.0940%
# 	 Accuracy on unseen dataset 23: 77.6865%
# 	 Accuracy on unseen dataset 24: 81.0081%
# 	 Accuracy on unseen dataset 25: 78.0439%
# 	 Accuracy on unseen dataset 26: 75.3955%
# 	 Accuracy on unseen dataset 27: 72.0963%
# 	 Accuracy on unseen dataset 28: 83.1995%
# 	 Accuracy on unseen dataset 29: 85.9368%
# 	 Accuracy on unseen dataset 30: 78.9221%
# 	 Accuracy on unseen dataset 31: 76.5239%
# 	 Accuracy on unseen dataset 32: 81.4523%
# 	 Accuracy on unseen dataset 33: 82.7302%
# 	 Accuracy on unseen dataset 34: 81.6440%
# 	 Accuracy on unseen dataset 35: 84.9489%
# 	 Accuracy on unseen dataset 36: 82.0937%
# 	 Accuracy on unseen dataset 37: 87.9479%
# 	 Accuracy on unseen dataset 38: 74.2245%
# 	 Accuracy on unseen dataset 39: 67.1390%
# 	 Accuracy on unseen dataset 40: 86.7632%
# 	 Accuracy on unseen dataset 41: 88.2339%
# 	 Accuracy on unseen dataset 42: 70.7407%
# 	 Accuracy on unseen dataset 43: 87.6421%
# 	 Accuracy on unseen dataset 44: 88.3246%
# 	 Accuracy on unseen dataset 45: 89.3886%
# 	 Accuracy on unseen dataset 46: 88.7486%
# 	 Accuracy on unseen dataset 47: 88.0486%
# 	 Accuracy on unseen dataset 48: 87.8345%
# 	 Accuracy on unseen dataset 49: 90.8848%
# 	 Accuracy on unseen dataset 50: 90.0069%
# 	 Training 22:  (168975, 4, 14, 1) (168975,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.08%
# Maximum validation accuracy : 93.74%
# Accuracy of test dataset using model V0: 93.5035%
# 	 Accuracy on unseen dataset 24: 86.0834%
# 	 Accuracy on unseen dataset 25: 81.4793%
# 	 Accuracy on unseen dataset 26: 80.6073%
# 	 Accuracy on unseen dataset 27: 77.3961%
# 	 Accuracy on unseen dataset 28: 83.3159%
# 	 Accuracy on unseen dataset 29: 89.7052%
# 	 Accuracy on unseen dataset 30: 82.8354%
# 	 Accuracy on unseen dataset 31: 78.4163%
# 	 Accuracy on unseen dataset 32: 82.3918%
# 	 Accuracy on unseen dataset 33: 85.3166%
# 	 Accuracy on unseen dataset 34: 82.7238%
# 	 Accuracy on unseen dataset 35: 80.9507%
# 	 Accuracy on unseen dataset 36: 77.9410%
# 	 Accuracy on unseen dataset 37: 81.6892%
# 	 Accuracy on unseen dataset 38: 67.9861%
# 	 Accuracy on unseen dataset 39: 68.4052%
# 	 Accuracy on unseen dataset 40: 85.8483%
# 	 Accuracy on unseen dataset 41: 87.1338%
# 	 Accuracy on unseen dataset 42: 69.5255%
# 	 Accuracy on unseen dataset 43: 91.5061%
# 	 Accuracy on unseen dataset 44: 88.3362%
# 	 Accuracy on unseen dataset 45: 90.4155%
# 	 Accuracy on unseen dataset 46: 92.1669%
# 	 Accuracy on unseen dataset 47: 90.5501%
# 	 Accuracy on unseen dataset 48: 88.0199%
# 	 Accuracy on unseen dataset 49: 91.3725%
# 	 Accuracy on unseen dataset 50: 92.2186%
# 	 Training 26:  (199743, 4, 14, 1) (199743,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.37%
# Maximum validation accuracy : 94.07%
# Accuracy of test dataset using model V0: 94.0698%
# 	 Accuracy on unseen dataset 28: 83.5020%
# 	 Accuracy on unseen dataset 29: 87.3039%
# 	 Accuracy on unseen dataset 30: 90.7088%
# 	 Accuracy on unseen dataset 31: 76.7677%
# 	 Accuracy on unseen dataset 32: 81.7655%
# 	 Accuracy on unseen dataset 33: 83.1014%
# 	 Accuracy on unseen dataset 34: 85.3710%
# 	 Accuracy on unseen dataset 35: 87.4477%
# 	 Accuracy on unseen dataset 36: 88.1087%
# 	 Accuracy on unseen dataset 37: 86.8660%
# 	 Accuracy on unseen dataset 38: 71.9444%
# 	 Accuracy on unseen dataset 39: 73.4348%
# 	 Accuracy on unseen dataset 40: 74.3138%
# 	 Accuracy on unseen dataset 41: 76.5373%
# 	 Accuracy on unseen dataset 42: 65.2431%
# 	 Accuracy on unseen dataset 43: 86.1105%
# 	 Accuracy on unseen dataset 44: 84.3710%
# 	 Accuracy on unseen dataset 45: 86.8744%
# 	 Accuracy on unseen dataset 46: 88.9687%
# 	 Accuracy on unseen dataset 47: 89.6005%
# 	 Accuracy on unseen dataset 48: 85.2972%
# 	 Accuracy on unseen dataset 49: 88.0516%
# 	 Accuracy on unseen dataset 50: 89.6943%
# 	 Training 30:  (230357, 4, 14, 1) (230357,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 84.63%
# Maximum validation accuracy : 89.1%
# Accuracy of test dataset using model V0: 89.0973%
# 	 Accuracy on unseen dataset 32: 82.1018%
# 	 Accuracy on unseen dataset 33: 82.2199%
# 	 Accuracy on unseen dataset 34: 84.1983%
# 	 Accuracy on unseen dataset 35: 79.6606%
# 	 Accuracy on unseen dataset 36: 80.3008%
# 	 Accuracy on unseen dataset 37: 81.3402%
# 	 Accuracy on unseen dataset 38: 71.7477%
# 	 Accuracy on unseen dataset 39: 68.8930%
# 	 Accuracy on unseen dataset 40: 76.5837%
# 	 Accuracy on unseen dataset 41: 77.8691%
# 	 Accuracy on unseen dataset 42: 66.3079%
# 	 Accuracy on unseen dataset 43: 86.7371%
# 	 Accuracy on unseen dataset 44: 83.0145%
# 	 Accuracy on unseen dataset 45: 87.4292%
# 	 Accuracy on unseen dataset 46: 88.3777%
# 	 Accuracy on unseen dataset 47: 89.0677%
# 	 Accuracy on unseen dataset 48: 84.4051%
# 	 Accuracy on unseen dataset 49: 87.0065%
# 	 Accuracy on unseen dataset 50: 89.0922%
# 	 Training 34:  (261380, 4, 14, 1) (261380,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 90.42%
# Maximum validation accuracy : 95.01%
# Accuracy of test dataset using model V0: 94.8897%
# 	 Accuracy on unseen dataset 36: 74.9798%
# 	 Accuracy on unseen dataset 37: 74.5579%
# 	 Accuracy on unseen dataset 38: 65.7639%
# 	 Accuracy on unseen dataset 39: 65.1411%
# 	 Accuracy on unseen dataset 40: 73.5032%
# 	 Accuracy on unseen dataset 41: 77.5796%
# 	 Accuracy on unseen dataset 42: 64.5023%
# 	 Accuracy on unseen dataset 43: 88.3500%
# 	 Accuracy on unseen dataset 44: 84.3362%
# 	 Accuracy on unseen dataset 45: 87.8305%
# 	 Accuracy on unseen dataset 46: 90.6373%
# 	 Accuracy on unseen dataset 47: 91.9861%
# 	 Accuracy on unseen dataset 48: 85.9460%
# 	 Accuracy on unseen dataset 49: 88.9805%
# 	 Accuracy on unseen dataset 50: 91.4428%
# 	 Training 38:  (292416, 4, 14, 1) (292416,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 77.66%
# Maximum validation accuracy : 79.86%
# Accuracy of test dataset using model V0: 79.6296%
# 	 Accuracy on unseen dataset 40: 77.9734%
# 	 Accuracy on unseen dataset 41: 79.5252%
# 	 Accuracy on unseen dataset 42: 69.2824%
# 	 Accuracy on unseen dataset 43: 83.4764%
# 	 Accuracy on unseen dataset 44: 80.0464%
# 	 Accuracy on unseen dataset 45: 83.2743%
# 	 Accuracy on unseen dataset 46: 84.8552%
# 	 Accuracy on unseen dataset 47: 85.2924%
# 	 Accuracy on unseen dataset 48: 80.6975%
# 	 Accuracy on unseen dataset 49: 86.2169%
# 	 Accuracy on unseen dataset 50: 86.4521%

# %%
b_path = '/NCI_mindforce'
baseline_K_char = ['1', '6', '10', '14', '18', '22', '26', '30', '34', '38']
baselines, baselines_N = [], []

for idx, K in enumerate(baseline_K_char):
    baselines.append(b_path + f'/github/Results/Baseline_results_train_with_{K}data_H.csv')
    baselines_N.append(b_path + f'/github/Results/WithoutNorm/Baseline_results_train_with_{K}data_noNorm_H.csv')

for idx, b in enumerate(baseline_K_char):
    ACC_with_norm = float(np.mean(pd.read_csv(baselines[idx])['Accuracy'][int(baseline_K[idx]):]))
    ACC_without_norm = float(np.mean(pd.read_csv(baselines_N[idx])[int(baseline_K[idx]):]))
    print(f"Baseline K-{baseline_K_char[idx]}: Norm : {ACC_with_norm:.2f}% / Without Norm: {ACC_without_norm:.2f}%")
# Out:
# Baseline K-1: Norm : 80.61% / Without Norm: 80.27%
# Baseline K-6: Norm : 83.63% / Without Norm: 78.35%
# Baseline K-10: Norm : 88.47% / Without Norm: 83.80%
# Baseline K-14: Norm : 88.19% / Without Norm: 83.83%
# Baseline K-18: Norm : 89.09% / Without Norm: 83.24%
# Baseline K-22: Norm : 88.91% / Without Norm: 83.86%
# Baseline K-26: Norm : 88.78% / Without Norm: 83.56%
# Baseline K-30: Norm : 88.26% / Without Norm: 81.77%
# Baseline K-34: Norm : 87.24% / Without Norm: 81.28%
# Baseline K-38: Norm : 89.57% / Without Norm: 81.41%

# %% [markdown]
# # Normalization is better
# - How to set the normalization value remains a question

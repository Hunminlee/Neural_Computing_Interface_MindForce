# %%
import sys
sys.path.append('../../Share')
import config
import baseline
import Target

import numpy as np
import pandas as pd

# %%
baseline_K_val = [1, 4, 7, 10, 13]

if __name__ == "__main__":
    for K in baseline_K_val:
        trainer = baseline.ModelTrainer(config, subject="Hunmin")
        trainer.run_all_sessions_training_K_data(K)
        df = trainer.save_results(f'../../Results/Results_Hunmin/Baseline_results_train_with_{K}data_H.csv')

# 저장해놨어서 데이터 업데이트 전에 한번 돌리면 굳이 안돌려도 됨'''
# Out:
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# second (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 93.04%
# Maximum validation accuracy : 97.67%
# Accuracy of test dataset using model V0: 97.6744%
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.4150%
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.2362%
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.8570%
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 65.5196%
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 70.8848%
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.5761%
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 71.1994%
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 67.6177%
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.1995%
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 69.3479%
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 71.7145%
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 71.5770%
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.7078%
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.9446%
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.7987%
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.6029%
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.2044%
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.7168%
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.3395%
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.0347%
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.4024%
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.7312%
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.0168%
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.8772%
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.9948%
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.7097%
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.3585%
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.9133%
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.3265%
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.9974%
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.7353%
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.4800%
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.6815%
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.5493%
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.3971%
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.8423%
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3279%
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2646%
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.5637%
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.4101%
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.1227%
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8194%
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0754%
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7498%
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8030%
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3019%
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8932%
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.5938%
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5901%
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.1301%
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8630%
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4807%
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.7366%
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.9464%
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.9540%
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4468%
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4911%
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8964%
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.8783%
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.8653%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.3794%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.9038%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0360%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0940%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_1data_H.csv
#
#
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,) (172, 4, 14, 1) (172,)
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,) (258, 4, 14, 1) (258,)
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,) (344, 4, 14, 1) (344,)
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# second (34103, 4, 14, 1) (34103,) (344, 4, 14, 1) (344,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 92.21%
# Maximum validation accuracy : 92.44%
# Accuracy of test dataset using model V0: 92.4419%
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.5177%
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.4505%
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.7186%
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 77.0804%
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.7945%
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 79.6519%
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.1110%
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.6624%
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.0944%
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.2566%
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.6108%
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.9126%
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.4067%
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.3897%
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.8137%
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.1300%
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.0274%
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.3198%
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0035%
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5186%
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.5872%
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.0264%
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.9453%
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0395%
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2753%
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.5931%
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.9437%
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.2097%
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.5769%
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5979%
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.6052%
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.9681%
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3650%
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.1506%
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2027%
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.9620%
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.5973%
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.1691%
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5274%
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.3188%
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.3087%
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8262%
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.8690%
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5410%
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.3220%
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6165%
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9598%
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.9094%
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.1233%
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.0399%
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.1118%
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.6403%
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5282%
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7930%
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7569%
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.4774%
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2186%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.6611%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4519%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.7344%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8736%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_4data_H.csv
#
#
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,) (172, 4, 14, 1) (172,)
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,) (258, 4, 14, 1) (258,)
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,) (344, 4, 14, 1) (344,)
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,) (421, 4, 14, 1) (421,)
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,) (507, 4, 14, 1) (507,)
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,) (593, 4, 14, 1) (593,)
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# second (58762, 4, 14, 1) (58762,) (593, 4, 14, 1) (593,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.91%
# Maximum validation accuracy : 91.91%
# Accuracy of test dataset using model V0: 91.9056%
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.1715%
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.0176%
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.1348%
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.9528%
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.3341%
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.9759%
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5821%
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.8561%
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.5300%
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.1170%
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.6315%
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.1367%
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.5247%
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.4120%
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4512%
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.0070%
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.9208%
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3322%
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.9788%
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.4695%
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0870%
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.2671%
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.7612%
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.2057%
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.2742%
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.7380%
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.4816%
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.2571%
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.9101%
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.9873%
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3511%
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6931%
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.2632%
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3753%
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0648%
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.3747%
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8870%
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.7247%
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.0197%
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.8109%
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.4576%
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.5655%
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.5081%
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.1935%
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0618%
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.2423%
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.2838%
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.1233%
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.5822%
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9001%
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7582%
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8034%
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.9444%
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.1955%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.0704%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.2016%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5439%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3583%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_7data_H.csv
#
#
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,) (172, 4, 14, 1) (172,)
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,) (258, 4, 14, 1) (258,)
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,) (344, 4, 14, 1) (344,)
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,) (421, 4, 14, 1) (421,)
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,) (507, 4, 14, 1) (507,)
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,) (593, 4, 14, 1) (593,)
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,) (679, 4, 14, 1) (679,)
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,) (765, 4, 14, 1) (765,)
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,) (851, 4, 14, 1) (851,)
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# second (84365, 4, 14, 1) (84365,) (851, 4, 14, 1) (851,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.34%
# Maximum validation accuracy : 91.66%
# Accuracy of test dataset using model V0: 91.6569%
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.1375%
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.4857%
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.7375%
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.1651%
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2899%
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5165%
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.5370%
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.5265%
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.0900%
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.2917%
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.0403%
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2727%
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2700%
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3882%
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.6110%
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5420%
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.5654%
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.3086%
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.0914%
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.3215%
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.8925%
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.4804%
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.8308%
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0046%
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.3458%
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0985%
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7106%
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.2515%
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.6080%
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0359%
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0604%
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7480%
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.7247%
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.9565%
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3765%
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4021%
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.2871%
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.5389%
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.9831%
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9755%
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.5157%
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.1561%
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2427%
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0037%
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.2509%
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.9075%
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3771%
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6320%
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.5709%
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.7984%
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2968%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.4255%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4253%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.1636%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.6855%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_10data_H.csv
#
#
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,) (172, 4, 14, 1) (172,)
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,) (258, 4, 14, 1) (258,)
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,) (344, 4, 14, 1) (344,)
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,) (421, 4, 14, 1) (421,)
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,) (507, 4, 14, 1) (507,)
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,) (593, 4, 14, 1) (593,)
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,) (679, 4, 14, 1) (679,)
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,) (765, 4, 14, 1) (765,)
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,) (851, 4, 14, 1) (851,)
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,) (937, 4, 14, 1) (937,)
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# (101296, 4, 14, 1) (101296,) (1022, 4, 14, 1) (1022,)
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# (109756, 4, 14, 1) (109756,) (1107, 4, 14, 1) (1107,)
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# second (109756, 4, 14, 1) (109756,) (1107, 4, 14, 1) (1107,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 90.15%
# Maximum validation accuracy : 91.06%
# Accuracy of test dataset using model V0: 91.0569%
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.1534%
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5118%
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2027%
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.4031%
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.0716%
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.6931%
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.3148%
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.8382%
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.8796%
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2352%
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.3482%
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.6342%
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.1577%
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4136%
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.8436%
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6227%
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.3811%
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.5213%
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6080%
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.6218%
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8303%
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.8078%
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.0493%
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6313%
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.3638%
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.2721%
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8274%
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8630%
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7480%
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.5604%
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.7188%
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.0826%
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.0939%
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.8225%
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.5157%
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.1106%
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.0218%
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9131%
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.9327%
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8734%
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6191%
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.8421%
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.3606%
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.4579%
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.1065%
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6405%
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.8181%
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4213%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.0007%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.2364%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4859%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6367%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_13data_H.csv

# %%
baseline_K_val = [1, 11, 21, 31, 41, 51, 61]

if __name__ == "__main__":
    for K in baseline_K_val:
        trainer = baseline.ModelTrainer(config, subject="Hunmin")
        trainer.run_all_sessions_training_K_data(K)
        df = trainer.save_results(f'../../Results/Results_Hunmin/Baseline_results_train_with_{K}data_H.csv')

# 저장해놨어서 데이터 업데이트 전에 한번 돌리면 굳이 안돌려도 됨'''
# Out:
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# second (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 93.4%
# Maximum validation accuracy : 94.19%
# Accuracy of test dataset using model V0: 94.1860%
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 70.6218%
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 79.6354%
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.8033%
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 62.9591%
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.0489%
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 72.1830%
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 68.5844%
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 63.9875%
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 69.6297%
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 66.6550%
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 69.5963%
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 68.6497%
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.1805%
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.4146%
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.5439%
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.0265%
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.5076%
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.2653%
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 78.4095%
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 78.8656%
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.4858%
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.4647%
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.5611%
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.3653%
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 75.8499%
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 79.3950%
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.9320%
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.9877%
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 76.7328%
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.9162%
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 80.8049%
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 82.3987%
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.0995%
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.7371%
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.4725%
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.1577%
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.9143%
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.6665%
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.1350%
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.5639%
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.4090%
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2526%
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5536%
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.9276%
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.5863%
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2438%
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.5820%
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.2368%
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.2469%
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.6108%
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.6800%
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.7435%
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.0283%
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.5407%
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.5009%
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5061%
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3533%
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.1408%
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 83.4762%
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 85.5553%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 84.6305%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.9687%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.7020%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.5976%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_1data_H.csv
#
#
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,) (172, 4, 14, 1) (172,)
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,) (258, 4, 14, 1) (258,)
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,) (344, 4, 14, 1) (344,)
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,) (421, 4, 14, 1) (421,)
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,) (507, 4, 14, 1) (507,)
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,) (593, 4, 14, 1) (593,)
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,) (679, 4, 14, 1) (679,)
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,) (765, 4, 14, 1) (765,)
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,) (851, 4, 14, 1) (851,)
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,) (937, 4, 14, 1) (937,)
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# second (92840, 4, 14, 1) (92840,) (937, 4, 14, 1) (937,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 89.83%
# Maximum validation accuracy : 90.5%
# Accuracy of test dataset using model V0: 90.5016%
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6325%
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3244%
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9436%
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3483%
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.5746%
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.8974%
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 81.5584%
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.7398%
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9661%
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.4090%
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.4867%
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.4322%
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.0960%
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.4365%
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.8980%
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3903%
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.1526%
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4704%
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.1488%
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.0805%
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.5010%
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 88.7031%
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.0516%
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.6106%
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.7130%
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.3716%
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.2248%
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8396%
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0823%
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.8978%
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.2923%
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.7809%
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.4174%
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.0710%
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.6883%
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9967%
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.4693%
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 93.0179%
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.1839%
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.7778%
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.8268%
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4446%
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 90.0023%
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 86.6566%
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 87.2909%
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.9692%
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.2690%
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.0126%
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 89.3743%
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.1284%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.4640%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.3291%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 91.9731%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.0659%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_11data_H.csv
#
#
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ========================================
# (8539, 4, 14, 1) (8539,) (86, 4, 14, 1) (86,)
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ========================================
# (17074, 4, 14, 1) (17074,) (172, 4, 14, 1) (172,)
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ========================================
# (25576, 4, 14, 1) (25576,) (258, 4, 14, 1) (258,)
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ========================================
# (34103, 4, 14, 1) (34103,) (344, 4, 14, 1) (344,)
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ========================================
# (41713, 4, 14, 1) (41713,) (421, 4, 14, 1) (421,)
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ========================================
# (50258, 4, 14, 1) (50258,) (507, 4, 14, 1) (507,)
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ========================================
# (58762, 4, 14, 1) (58762,) (593, 4, 14, 1) (593,)
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ========================================
# (67311, 4, 14, 1) (67311,) (679, 4, 14, 1) (679,)
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ========================================
# (75829, 4, 14, 1) (75829,) (765, 4, 14, 1) (765,)
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ========================================
# (84365, 4, 14, 1) (84365,) (851, 4, 14, 1) (851,)
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ========================================
# (92840, 4, 14, 1) (92840,) (937, 4, 14, 1) (937,)
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ========================================
# (101296, 4, 14, 1) (101296,) (1022, 4, 14, 1) (1022,)
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ========================================
# (109756, 4, 14, 1) (109756,) (1107, 4, 14, 1) (1107,)
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ========================================
# (118143, 4, 14, 1) (118143,) (1192, 4, 14, 1) (1192,)
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ========================================
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ========================================
# (466326, 4, 14, 1) (466326,) (4706, 4, 14, 1) (4706,)
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ========================================
# (474866, 4, 14, 1) (474866,) (4792, 4, 14, 1) (4792,)
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ========================================
# (483388, 4, 14, 1) (483388,) (4878, 4, 14, 1) (4878,)
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ========================================
# (491907, 4, 14, 1) (491907,) (4964, 4, 14, 1) (4964,)
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ========================================
# (500434, 4, 14, 1) (500434,) (5050, 4, 14, 1) (5050,)
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ========================================
# (508949, 4, 14, 1) (508949,) (5136, 4, 14, 1) (5136,)
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ========================================
# (517493, 4, 14, 1) (517493,) (5222, 4, 14, 1) (5222,)
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ========================================
# second (517493, 4, 14, 1) (517493,) (5222, 4, 14, 1) (5222,)
# Start Training (total epochs: 50)...
# Finish Training! (Model is saved)
# Maximum training accuracy : 90.77%
# Maximum validation accuracy : 92.63%
# Accuracy of test dataset using model V0: 92.6273%
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 92.5643%
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 95.3071%
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.0494%
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ========================================
# Accuracy on unseen dataset: 94.2118%
# Results saved to ../../Results/Results_Hunmin/Baseline_results_train_with_61data_H.csv

# %%
b_path = 'C:/Users/hml76/PycharmProjects/MindForce/'
#baseline_K = ['1', '11'
#baseline_K = ['1', '4', '7', '10', '13']
baseline_K = ['1', '4', '7', '10', '13', '21', '31', '41', '51', '61']
baselines = []

for idx, K in enumerate(baseline_K):
    baselines.append(b_path + f'/github/Results/Results_Hunmin/Baseline_results_train_with_{K}data_H.csv')

SUBJECT = "Hunmin"

# %%
prog_trainer = Target.ProgressiveTrainer(config, subject=SUBJECT)
Init_acc_all, Prev_acc_all, Trained_acc_all = prog_trainer.run(plot_learning_curve=False)
pd.DataFrame(Trained_acc_all).to_csv(f'../../Results/Results_Hunmin/Train_Test_per_sessions.csv', index=False)
# Out:
# ===========================================
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.59%
# Maximum validation accuracy : 90.38%
#
# ===========================================
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.05%
# Maximum validation accuracy : 88.4%
#
# ===========================================
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.61%
# Maximum validation accuracy : 86.07%
#
# ===========================================
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.36%
# Maximum validation accuracy : 91.99%
#
# ===========================================
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 75.81%
# Maximum validation accuracy : 77.18%
#
# ===========================================
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.87%
# Maximum validation accuracy : 87.3%
#
# ===========================================
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.76%
# Maximum validation accuracy : 93.83%
#
# ===========================================
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.75%
# Maximum validation accuracy : 84.71%
#
# ===========================================
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.36%
# Maximum validation accuracy : 89.73%
#
# ===========================================
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.23%
# Maximum validation accuracy : 86.45%
#
# ===========================================
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.09%
# Maximum validation accuracy : 89.23%
#
# ===========================================
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.78%
# Maximum validation accuracy : 90.35%
#
# ===========================================
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 84.88%
# Maximum validation accuracy : 85.3%
#
# ===========================================
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.95%
# Maximum validation accuracy : 92.26%
#
# ===========================================
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.16%
# Maximum validation accuracy : 93.63%
#
# ===========================================
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.54%
# Maximum validation accuracy : 93.88%
#
# ===========================================
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.98%
# Maximum validation accuracy : 93.63%
#
# ===========================================
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.88%
# Maximum validation accuracy : 92.22%
#
# ===========================================
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.39%
# Maximum validation accuracy : 90.44%
#
# ===========================================
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.46%
# Maximum validation accuracy : 93.95%
#
# ===========================================
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.91%
# Maximum validation accuracy : 93.42%
#
# ===========================================
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.89%
# Maximum validation accuracy : 86.5%
#
# ===========================================
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.71%
# Maximum validation accuracy : 89.66%
#
# ===========================================
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.46%
# Maximum validation accuracy : 90.57%
#
# ===========================================
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.87%
# Maximum validation accuracy : 89.11%
#
# ===========================================
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.23%
# Maximum validation accuracy : 90.79%
#
# ===========================================
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.24%
# Maximum validation accuracy : 92.56%
#
# ===========================================
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 93.67%
# Maximum validation accuracy : 95.83%
#
# ===========================================
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.89%
# Maximum validation accuracy : 93.49%
#
# ===========================================
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.67%
# Maximum validation accuracy : 91.66%
#
# ===========================================
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.41%
# Maximum validation accuracy : 88.79%
#
# ===========================================
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.89%
# Maximum validation accuracy : 90.42%
#
# ===========================================
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.76%
# Maximum validation accuracy : 87.98%
#
# ===========================================
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.14%
# Maximum validation accuracy : 85.67%
#
# ===========================================
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.05%
# Maximum validation accuracy : 93.63%
#
# ===========================================
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.78%
# Maximum validation accuracy : 95.01%
#
# ===========================================
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.9%
# Maximum validation accuracy : 86.07%
#
# ===========================================
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.58%
# Maximum validation accuracy : 90.3%
#
# ===========================================
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.78%
# Maximum validation accuracy : 90.52%
#
# ===========================================
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.31%
# Maximum validation accuracy : 87.33%
#
# ===========================================
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.4%
# Maximum validation accuracy : 88.04%
#
# ===========================================
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.06%
# Maximum validation accuracy : 90.27%
#
# ===========================================
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.53%
# Maximum validation accuracy : 90.85%
#
# ===========================================
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.18%
# Maximum validation accuracy : 92.32%
#
# ===========================================
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.82%
# Maximum validation accuracy : 90.49%
#
# ===========================================
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.51%
# Maximum validation accuracy : 90.16%
#
# ===========================================
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.81%
# Maximum validation accuracy : 89.5%
#
# ===========================================
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.96%
# Maximum validation accuracy : 91.17%
#
# ===========================================
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.86%
# Maximum validation accuracy : 88.63%
#
# ===========================================
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.89%
# Maximum validation accuracy : 90.3%
#
# ===========================================
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.53%
# Maximum validation accuracy : 89.9%
#
# ===========================================
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.32%
# Maximum validation accuracy : 90.11%
#
# ===========================================
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.92%
# Maximum validation accuracy : 91.62%
#
# ===========================================
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.34%
# Maximum validation accuracy : 87.86%
#
# ===========================================
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.6%
# Maximum validation accuracy : 88.92%
#
# ===========================================
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.59%
# Maximum validation accuracy : 89.22%
#
# ===========================================
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.08%
# Maximum validation accuracy : 89.57%
#
# ===========================================
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.77%
# Maximum validation accuracy : 89.8%
#
# ===========================================
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.01%
# Maximum validation accuracy : 90.57%
#
# ===========================================
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.05%
# Maximum validation accuracy : 90.91%
#
# ===========================================
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.29%
# Maximum validation accuracy : 90.06%
#
# ===========================================
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.12%
# Maximum validation accuracy : 90.35%
#
# ===========================================
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.22%
# Maximum validation accuracy : 92.66%
#
# ===========================================
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 92.49%
# Maximum validation accuracy : 92.72%
#
# ===========================================
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.79%
# Maximum validation accuracy : 91.3%
#
# ===========================================
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.65%
# Maximum validation accuracy : 90.42%

# %%
SUBJECT = "Hunmin"
prog_trainer = Target.ProgressiveTrainer(config, subject=SUBJECT)
Init_acc_all, Prev_acc_all, Trained_acc_all = prog_trainer.run(plot_learning_curve=False)
pd.DataFrame(Trained_acc_all).to_csv(f'../../Results/Results_Hunmin/Train_Test_per_sessions_K1_10.csv', index=False)
# Out:
# ===========================================
# Dataset 1/66 - Session Exp_2025-05-27/E8331D05289A/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.31%
# Maximum validation accuracy : 92.77%
#
# ===========================================
# Dataset 2/66 - Session Exp_2025-06-18/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.31%
# Maximum validation accuracy : 89.47%
#
# ===========================================
# Dataset 3/66 - Session Exp_2025-06-20-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.82%
# Maximum validation accuracy : 89.5%
#
# ===========================================
# Dataset 4/66 - Session Exp_2025-06-20-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.2%
# Maximum validation accuracy : 91.83%
#
# ===========================================
# Dataset 5/66 - Session Exp_2025-06-20-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 79.34%
# Maximum validation accuracy : 84.0%
#
# ===========================================
# Dataset 6/66 - Session Exp_2025-06-20-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.5%
# Maximum validation accuracy : 87.32%
#
# ===========================================
# Dataset 7/66 - Session Exp_2025-06-20-v5/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.71%
# Maximum validation accuracy : 90.55%
#
# ===========================================
# Dataset 8/66 - Session Exp_2025-06-20-v6/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 73.6%
# Maximum validation accuracy : 74.31%
#
# ===========================================
# Dataset 9/66 - Session Exp_2025-06-20-v7/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.94%
# Maximum validation accuracy : 90.26%
#
# ===========================================
# Dataset 10/66 - Session Exp_2025-06-20-v8/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 83.02%
# Maximum validation accuracy : 87.98%
#
# ===========================================
# Dataset 11/66 - Session Exp_2025-06-23-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.46%
# Maximum validation accuracy : 93.04%
#
# ===========================================
# Dataset 12/66 - Session Exp_2025-06-23-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.13%
# Maximum validation accuracy : 91.22%
#
# ===========================================
# Dataset 13/66 - Session Exp_2025-06-23-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.49%
# Maximum validation accuracy : 88.84%
#
# ===========================================
# Dataset 14/66 - Session Exp_2025-06-23-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.24%
# Maximum validation accuracy : 92.28%
#
# ===========================================
# Dataset 15/66 - Session Exp_2025-06-24-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.62%
# Maximum validation accuracy : 90.6%
#
# ===========================================
# Dataset 16/66 - Session Exp_2025-06-24-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.4%
# Maximum validation accuracy : 90.52%
#
# ===========================================
# Dataset 17/66 - Session Exp_2025-06-24-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.17%
# Maximum validation accuracy : 87.7%
#
# ===========================================
# Dataset 18/66 - Session Exp_2025-06-24-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.87%
# Maximum validation accuracy : 94.9%
#
# ===========================================
# Dataset 19/66 - Session Exp_2025-06-26-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.06%
# Maximum validation accuracy : 91.56%
#
# ===========================================
# Dataset 20/66 - Session Exp_2025-06-26-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.38%
# Maximum validation accuracy : 84.01%
#
# ===========================================
# Dataset 21/66 - Session Exp_2025-06-26-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.28%
# Maximum validation accuracy : 91.44%
#
# ===========================================
# Dataset 22/66 - Session Exp_2025-06-26-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.61%
# Maximum validation accuracy : 90.72%
#
# ===========================================
# Dataset 23/66 - Session Exp_2025-06-27-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.14%
# Maximum validation accuracy : 82.11%
#
# ===========================================
# Dataset 24/66 - Session Exp_2025-06-27-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.64%
# Maximum validation accuracy : 92.33%
#
# ===========================================
# Dataset 25/66 - Session Exp_2025-06-27-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.44%
# Maximum validation accuracy : 91.49%
#
# ===========================================
# Dataset 26/66 - Session Exp_2025-06-27-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.53%
# Maximum validation accuracy : 91.02%
#
# ===========================================
# Dataset 27/66 - Session Exp_2025-06-30-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.45%
# Maximum validation accuracy : 93.65%
#
# ===========================================
# Dataset 28/66 - Session Exp_2025-06-30-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.55%
# Maximum validation accuracy : 94.62%
#
# ===========================================
# Dataset 29/66 - Session Exp_2025-06-30-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.66%
# Maximum validation accuracy : 87.61%
#
# ===========================================
# Dataset 30/66 - Session Exp_2025-06-30-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.14%
# Maximum validation accuracy : 94.28%
#
# ===========================================
# Dataset 31/66 - Session Exp_2025-07-01-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 85.81%
# Maximum validation accuracy : 89.06%
#
# ===========================================
# Dataset 32/66 - Session Exp_2025-07-01-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.31%
# Maximum validation accuracy : 85.13%
#
# ===========================================
# Dataset 33/66 - Session Exp_2025-07-01-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.38%
# Maximum validation accuracy : 88.45%
#
# ===========================================
# Dataset 34/66 - Session Exp_2025-07-01-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 82.26%
# Maximum validation accuracy : 84.54%
#
# ===========================================
# Dataset 35/66 - Session Exp_2025-07-02-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.75%
# Maximum validation accuracy : 91.42%
#
# ===========================================
# Dataset 36/66 - Session Exp_2025-07-07-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.67%
# Maximum validation accuracy : 91.92%
#
# ===========================================
# Dataset 37/66 - Session Exp_2025-07-07-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.19%
# Maximum validation accuracy : 90.8%
#
# ===========================================
# Dataset 38/66 - Session Exp_2025-07-07-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.97%
# Maximum validation accuracy : 90.23%
#
# ===========================================
# Dataset 39/66 - Session Exp_2025-07-07-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.03%
# Maximum validation accuracy : 90.27%
#
# ===========================================
# Dataset 40/66 - Session Exp_2025-07-09-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.45%
# Maximum validation accuracy : 88.65%
#
# ===========================================
# Dataset 41/66 - Session Exp_2025-07-09-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 87.81%
# Maximum validation accuracy : 87.97%
#
# ===========================================
# Dataset 42/66 - Session Exp_2025-07-09-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 86.23%
# Maximum validation accuracy : 86.44%
#
# ===========================================
# Dataset 43/66 - Session Exp_2025-07-09-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.12%
# Maximum validation accuracy : 89.72%
#
# ===========================================
# Dataset 44/66 - Session Exp_2025-07-10-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.88%
# Maximum validation accuracy : 91.23%
#
# ===========================================
# Dataset 45/66 - Session Exp_2025-07-10-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.17%
# Maximum validation accuracy : 90.47%
#
# ===========================================
# Dataset 46/66 - Session Exp_2025-07-10-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.65%
# Maximum validation accuracy : 90.18%
#
# ===========================================
# Dataset 47/66 - Session Exp_2025-07-10-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.08%
# Maximum validation accuracy : 89.66%
#
# ===========================================
# Dataset 48/66 - Session Exp_2025-07-11-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.4%
# Maximum validation accuracy : 88.85%
#
# ===========================================
# Dataset 49/66 - Session Exp_2025-07-11-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.05%
# Maximum validation accuracy : 89.23%
#
# ===========================================
# Dataset 50/66 - Session Exp_2025-07-11-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.7%
# Maximum validation accuracy : 90.33%
#
# ===========================================
# Dataset 51/66 - Session Exp_2025-07-11-v4/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.23%
# Maximum validation accuracy : 89.25%
#
# ===========================================
# Dataset 52/66 - Session Exp_2025-07-17-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.88%
# Maximum validation accuracy : 89.81%
#
# ===========================================
# Dataset 53/66 - Session Exp_2025-07-17-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.73%
# Maximum validation accuracy : 90.27%
#
# ===========================================
# Dataset 54/66 - Session Exp_2025-07-17-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.91%
# Maximum validation accuracy : 91.72%
#
# ===========================================
# Dataset 55/66 - Session Exp_2025-07-23-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.64%
# Maximum validation accuracy : 89.64%
#
# ===========================================
# Dataset 56/66 - Session Exp_2025-07-23-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.73%
# Maximum validation accuracy : 88.18%
#
# ===========================================
# Dataset 57/66 - Session Exp_2025-07-23-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.64%
# Maximum validation accuracy : 92.29%
#
# ===========================================
# Dataset 58/66 - Session Exp_2025-07-24-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.73%
# Maximum validation accuracy : 89.03%
#
# ===========================================
# Dataset 59/66 - Session Exp_2025-07-24-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.87%
# Maximum validation accuracy : 89.02%
#
# ===========================================
# Dataset 60/66 - Session Exp_2025-07-24-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.74%
# Maximum validation accuracy : 90.98%
#
# ===========================================
# Dataset 61/66 - Session Exp_2025-07-25-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.11%
# Maximum validation accuracy : 89.11%
#
# ===========================================
# Dataset 62/66 - Session Exp_2025-07-25-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.01%
# Maximum validation accuracy : 89.4%
#
# ===========================================
# Dataset 63/66 - Session Exp_2025-07-25-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 88.95%
# Maximum validation accuracy : 90.06%
#
# ===========================================
# Dataset 64/66 - Session Exp_2025-08-01-v1/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 91.26%
# Maximum validation accuracy : 91.36%
#
# ===========================================
# Dataset 65/66 - Session Exp_2025-08-01-v2/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 90.16%
# Maximum validation accuracy : 91.35%
#
# ===========================================
# Dataset 66/66 - Session Exp_2025-08-01-v3/E9AD0E7DCC2B/
# ===========================================
# Start Training (total epochs: 50)...
# Finish Training! (Model is NOT saved)
#
# Maximum training accuracy : 89.95%
# Maximum validation accuracy : 90.28%

# %%
for idx, x in enumerate([Init_acc_all, Prev_acc_all, Trained_acc_all]):
    if idx==0:
        print(f"Average of acc without training anything (should be random): {np.mean(x)*100:.2f}%")
    elif idx==1:
        print(f"Average of acc using previous test data after training: {np.mean(x)*100:.2f}%")
    elif idx==2:
        print(f"Average of acc using current test data after training: {np.mean(x)*100:.2f}%")
for idx, b in enumerate(baselines):
    val = float(np.mean(pd.read_csv(baselines[idx])['Accuracy'][int(baseline_K[idx]):]))
    print(f"K-{baseline_K[idx]}: {val:.2f}% | Target: {np.mean(Trained_acc_all[int(baseline_K[idx]):])*100:.2f}")
# Out:
# Average of acc without training anything (should be random): 16.82%
# Average of acc using previous test data after training: 77.08%
# Average of acc using current test data after training: 90.12%
# K-1: 82.19% | Target: 90.12
# K-11: 90.64% | Target: 90.59
# K-21: 91.87% | Target: 90.30
# K-31: 92.00% | Target: 90.13
# K-41: 92.50% | Target: 90.39
# K-51: 92.43% | Target: 90.41
# K-61: 93.75% | Target: 91.49

# %%
for idx, x in enumerate([Init_acc_all, Prev_acc_all, Trained_acc_all]):
    if idx==0:
        print(f"Average of acc without training anything (should be random): {np.mean(x)*100:.2f}%")
    elif idx==1:
        print(f"Average of acc using previous test data after training: {np.mean(x)*100:.2f}%")
    elif idx==2:
        print(f"Average of acc using current test data after training: {np.mean(x)*100:.2f}%")
for idx, b in enumerate(baselines):
    val = float(np.mean(pd.read_csv(baselines[idx])['Accuracy'][int(baseline_K[idx]):]))
    print(f"K-{baseline_K[idx]}: {val:.2f}% | Target: {np.mean(Trained_acc_all[int(baseline_K[idx]):])*100:.2f}")
# Out:
# Average of acc without training anything (should be random): 12.90%
# Average of acc using previous test data after training: 76.99%
# Average of acc using current test data after training: 89.67%
# K-1: 83.47% | Target: 89.62
# K-4: 86.68% | Target: 89.59
# K-7: 88.78% | Target: 89.71
# K-10: 90.12% | Target: 90.00
# K-13: 90.53% | Target: 89.95

# %% [markdown]
# Average of acc without training anything (should be random): 16.82%
# Average of acc using previous test data after training: 77.08%
# Average of acc using current test data after training: 90.12%
# K-1: 82.19% | Target: 90.12
# K-11: 90.64% | Target: 90.59
# K-21: 91.87% | Target: 90.30
# K-31: 92.00% | Target: 90.13
# K-41: 92.50% | Target: 90.39
# K-51: 92.43% | Target: 90.41
# K-61: 93.75% | Target: 91.49

# %%
Trained_acc_all
# Out:
# [0.9037792682647705,
#  0.8840176463127136,
#  0.8607358932495117,
#  0.9198978543281555,
#  0.7717928886413574,
#  0.8730011582374573,
#  0.938300371170044,
#  0.8471160531044006,
#  0.8972570896148682,
#  0.8645325899124146,
#  0.8923148512840271,
#  0.9035354852676392,
#  0.8530306816101074,
#  0.9225684404373169,
#  0.9363487958908081,
#  0.9387993216514587,
#  0.9363086819648743,
#  0.9222248792648315,
#  0.9043620228767395,
#  0.9395283460617065,
#  0.9342013597488403,
#  0.8649964928627014,
#  0.8966420292854309,
#  0.905677855014801,
#  0.8910960555076599,
#  0.9078640937805176,
#  0.9256373643875122,
#  0.9583430290222168,
#  0.9348549842834473,
#  0.9165689945220947,
#  0.8878569602966309,
#  0.9041985869407654,
#  0.8798422813415527,
#  0.8567448258399963,
#  0.9363086819648743,
#  0.9501044154167175,
#  0.860653817653656,
#  0.9029744863510132,
#  0.9052143692970276,
#  0.8732916116714478,
#  0.8804171681404114,
#  0.9026939272880554,
#  0.9085224866867065,
#  0.9231662154197693,
#  0.9049385786056519,
#  0.9015784859657288,
#  0.8950173854827881,
#  0.9117305278778076,
#  0.8862845301628113,
#  0.903038740158081,
#  0.8990273475646973,
#  0.9011451005935669,
#  0.9161635041236877,
#  0.878629207611084,
#  0.8892243504524231,
#  0.8921864032745361,
#  0.8956784605979919,
#  0.8979781270027161,
#  0.9057348370552063,
#  0.9090909361839294,
#  0.9005793929100037,
#  0.9035474061965942,
#  0.926569402217865,
#  0.9272305965423584,
#  0.913013219833374,
#  0.9041985869407654]

# %%
import matplotlib.pyplot as plt

Trained_acc_all_stored = [0.9037792682647705, 0.8840176463127136, 0.8607358932495117, 0.9198978543281555, 0.7717928886413574, 0.8730011582374573, 0.938300371170044, 0.8471160531044006, 0.8972570896148682, 0.8645325899124146, 0.8923148512840271, 0.9035354852676392, 0.8530306816101074, 0.9225684404373169, 0.9363487958908081, 0.9387993216514587, 0.9363086819648743, 0.9222248792648315, 0.9043620228767395, 0.9395283460617065, 0.9342013597488403, 0.8649964928627014, 0.8966420292854309, 0.905677855014801, 0.8910960555076599, 0.9078640937805176, 0.9256373643875122, 0.9583430290222168, 0.9348549842834473, 0.9165689945220947, 0.8878569602966309, 0.9041985869407654, 0.8798422813415527, 0.8567448258399963, 0.9363086819648743, 0.9501044154167175, 0.860653817653656, 0.9029744863510132, 0.9052143692970276, 0.8732916116714478, 0.8804171681404114, 0.9026939272880554, 0.9085224866867065, 0.9231662154197693, 0.9049385786056519, 0.9015784859657288, 0.8950173854827881, 0.9117305278778076, 0.8862845301628113, 0.903038740158081, 0.8990273475646973, 0.9011451005935669, 0.9161635041236877, 0.878629207611084, 0.8892243504524231, 0.8921864032745361, 0.8956784605979919, 0.8979781270027161, 0.9057348370552063, 0.9090909361839294, 0.9005793929100037, 0.9035474061965942, 0.926569402217865]#, 0.9272305965423584, 0.913013219833374, 0.9041985869407654]

# -C: Chair / -C-L: Chair Leg crossed / -F: Floor
'''
X_labels = ['Stand (5/27)', 'Stand (6/18)',
            'Stand (6/20)', 'Sit-C (6/20)', 'Sit-C-L (6/20)', 'Sit-F (6/20)',
            'Stand (6/21)', 'Sit-C (6/21)', 'Sit-C-L (6/21)', 'Sit-F (6/21)',
            'Stand (6/23)', 'Sit-C (6/23)', 'Sit-C-L (6/23)', 'Sit-F (6/23)',
            'Stand (6/24)', 'Sit-C (6/24)', 'Sit-C-L (6/24)', 'Sit-F (6/24)',
            'Stand (6/26)', 'Sit-C (6/26)', 'Sit-C-L (6/26)', 'Sit-F (6/26)',
            'Stand (6/27)', 'Sit-C (6/27)', 'Sit-C-L (6/27)', 'Sit-F (6/27)',
            'Stand (6/30)', 'Sit-C (6/30)', 'Sit-C-L (6/30)', 'Sit-F (6/30)',
            'Stand (7/1)',  'Sit-C (7/1)',  'Sit-C-L (7/1)', 'Sit-F (7/1)',
            'Stand (7/2)',
            'Stand (7/7)',  'Sit-C (7/7)',  'Sit-C-L (7/7)', 'Sit-F (7/7)',
            'Stand (7/9)',  'Sit-C (7/9)',  'Sit-C-L (7/9)', 'Sit-F (7/9)',
            'Stand (7/10)', 'Sit-C (7/10)', 'Sit-C-L (7/10)', 'Sit-F (7/10)',
            'Stand (7/11)', 'Sit-C (7/11)', 'Sit-C-L (7/11)', 'Sit-F (7/11)',
            'Stand (7/17)', 'Sit-C (7/17)', 'Sit-F (7/17)', 'Stand (7/23)', 'Sit-C (7/23)', 'Sit-F (7/23)',
            'Stand (7/24)', 'Sit-C (7/24)', 'Sit-F (7/24)', 'Stand (7/25)', 'Sit-C (7/25)', 'Sit-F (7/25)',
            'Stand (8/1)',  'Sit-C (8/1)', 'Sit-F (8/1)']
            '''

X_labels = ['Stand (5/27)', 'Stand (6/18)',
            'Stand (6/19)', 'Sit-C (6/19)', 'Stand (6/20)', 'Sit-C (6/20)',
            'Stand (6/21)', 'Sit-C (6/21)', 'Stand (6/22)', 'Sit-C (6/22)',
            'Stand (6/23)', 'Sit-C (6/23)', 'Stand (6/24)', 'Sit-C (6/24)',
            'Stand (6/26)', 'Sit-C (6/26)', 'Stand (6/26)', 'Sit-C (6/26)',
            'Stand (6/27)', 'Sit-C (6/27)', 'Stand (6/28)', 'Sit-C (6/28)',
            'Stand (6/29)', 'Sit-C (6/29)', 'Stand (6/30)', 'Sit-C (6/30)',
            'Stand (7/1)',  'Sit-C (7/1)',  'Stand (7/2)', 'Sit-C (7/2)',
            'Stand (7/2)',
            'Stand (7/3)',  'Sit-C (7/3)',  'Stand (7/4)', 'Sit-C (7/4)',
            'Stand (7/5)',  'Sit-C (7/5)',  'Stand (7/6)', 'Sit-C (7/6)',
            'Stand (7/7)',  'Sit-C (7/7)',  'Stand (7/8)', 'Sit-C (7/8)',
            'Stand (7/9)',  'Sit-C (7/9)',  'Stand (7/10)', 'Sit-C (7/10)',
            'Stand (7/11)', 'Sit-C (7/11)', 'Stand (7/14)', 'Sit-C (7/14)',
            'Stand (7/17)', 'Sit-C (7/17)', 'Sit-F (7/17)', 'Stand (7/23)', 'Sit-C (7/23)', 'Sit-F (7/23)',
            'Stand (7/24)', 'Sit-C (7/24)', 'Sit-F (7/24)', 'Stand (7/25)', 'Sit-C (7/25)', 'Sit-F (7/25)',
            'Stand (8/1)',  'Sit-C (8/1)', 'Sit-F (8/1)']


plt.rcParams['font.family'] = 'Times New Roman'

plt.figure(figsize=(14, 7), dpi=150)
#plt.title('Training from scratch every time', fontsize=15)
plt.plot(Trained_acc_all_stored, c='red', label='Train/Test in same session', marker='o', linestyle='--')
for idx, base in enumerate(baselines):
    baseline_result = pd.read_csv(base)
    plt.plot(X_labels, baseline_result['Accuracy'] / 100, marker='^', label=f'K={baseline_K[idx]}', linestyle='-')

plt.ylim([0, 1])
#plt.ylim([0.6, 1])
plt.xlabel('Date (Sessions)', fontsize=14)
plt.ylabel('Test Accuracy', fontsize=14)
plt.xticks(rotation=90, fontsize=10)
plt.legend(fontsize=16, ncol=1)
plt.grid(True, linestyle='--', color='lightgrey')
plt.tight_layout()
plt.show()
